# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import matplotlib.dates as mdates
# %matplotlib inline

# %%
dataset_ATR = pd.read_csv('../../indata/ATR_20220101_20221114.csv', sep=',')
dataset_ATR.head()
# Out:
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_3948/2678732647.py:1: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_ATR = pd.read_csv('../../indata/ATR_20220101_20221114.csv', sep=',')
#          Trafikföretag  Trafikföretagsnr  Linje  Estimated  \
# 0  Transdev Norrköping              9003      2          1
# 1  Transdev Norrköping              9003      2          1
# 2  Transdev Norrköping              9003      2          1
# 3  Transdev Norrköping              9003      2          1
# 4  Transdev Norrköping              9003      2          1
#
#               Tidpunkt Hållplatstid  Timme Halvtimme     Kvart  \
# 0  2022-01-01 05:27:00        05:27    5.0  05:00:00  05:15:00
# 1  2022-01-01 05:30:42        05:30    5.0  05:30:00  05:30:00
# 2  2022-01-01 05:35:59        05:35    5.0  05:30:00  05:30:00
# 3  2022-01-01 05:39:59        05:39    5.0  05:30:00  05:30:00
# 4  2022-01-01 05:49:10        05:49    5.0  05:30:00  05:45:00
#
#    SequenceInJourney  ... Hållplatsnr  Omlopp Påstigande  Avstigande  Ombord  \
# 0                  7  ...           6     620        1.0         3.0     3.0
# 1                 10  ...           1     620        4.0         0.0     7.0
# 2                 13  ...        1019     620        1.0         1.0     7.0
# 3                 17  ...        1009     620        4.0         0.0    15.0
# 4                 21  ...        1129     620        2.0         0.0    17.0
#
#   Passagerare sittande Beläggning  Beläggning turer       Datum  \
# 0          Okänt antal        NaN               NaN  2022-01-01
# 1          Okänt antal        NaN               NaN  2022-01-01
# 2          Okänt antal        NaN               NaN  2022-01-01
# 3          Okänt antal        NaN               NaN  2022-01-01
# 4          Okänt antal        NaN               NaN  2022-01-01
#
#          JourneyGID
# 0  9015005000200701
# 1  9015005000200701
# 2  9015005000200701
# 3  9015005000200701
# 4  9015005000200701
#
# [5 rows x 28 columns]

# %%
dataset_ATR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000000 entries, 0 to 3999999
# Data columns (total 28 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Trafikföretag         object
#  1   Trafikföretagsnr      int64
#  2   Linje                 int64
#  3   Estimated             int64
#  4   Tidpunkt              object
#  5   Hållplatstid          object
#  6   Timme                 float64
#  7   Halvtimme             object
#  8   Kvart                 object
#  9   SequenceInJourney     int64
#  10  Avg.tid               object
#  11  Turnr                 int64
#  12  Mot                   object
#  13  VehicleGID            float64
#  14  Fordon                float64
#  15  Hållplatsnamn         object
#  16  Hållplatsläge         object
#  17  StopPointGID          int64
#  18  Hållplatsnr           int64
#  19  Omlopp                int64
#  20  Påstigande            float64
#  21  Avstigande            float64
#  22  Ombord                float64
#  23  Passagerare sittande  object
#  24  Beläggning            object
#  25  Beläggning turer      object
#  26  Datum                 object
#  27  JourneyGID            int64
# dtypes: float64(6), int64(9), object(13)
# memory usage: 854.5+ MB

# %%
# Filtrera bort de parametrar som inte har relevans 
dataset_ATR_selection = dataset_ATR[['Datum', 'Tidpunkt', 'Linje', 'Hållplatstid', 'Hållplatsnamn', 'Påstigande', 'Avstigande', 'Ombord']]
# 21            Ljura Centrum         0.0         2.0    19.0
# 22  Norrköpings resecentrum         0.0         3.0     1.0
# 23              Atriumhusen         5.0         0.0    24.0
# 24          Trumpetaregatan         1.0         0.0    25.0
# 25     Vårdcentralen Hageby         8.0         8.0    21.0
# 26           Broocmans plan         2.0         2.0    19.0
# 27                Fridvalla         0.0         1.0    -4.0
# 28              Kvarnberget         0.0         0.0     0.0
# 29      Ringdansens centrum        19.0         0.0    19.0

# %%
dataset_ATR_selection = dataset_ATR_selection.dropna()
dataset_ATR_selection
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 0        2022-01-01  2022-01-01 05:27:00      2        05:27
# 1        2022-01-01  2022-01-01 05:30:42      2        05:30
# 2        2022-01-01  2022-01-01 05:35:59      2        05:35
# 3        2022-01-01  2022-01-01 05:39:59      2        05:39
# 4        2022-01-01  2022-01-01 05:49:10      2        05:49
# ...             ...                  ...    ...          ...
# 3999995  2022-03-25  2022-03-25 17:56:23    113        17:56
# 3999996  2022-03-25  2022-03-25 17:47:34    113        17:47
# 3999997  2022-03-25  2022-03-25 17:49:04    113        17:49
# 3999998  2022-03-25  2022-03-25 17:25:30    113        17:25
# 3999999  2022-03-25  2022-03-25 17:53:30    113        17:53
#
#             Hållplatsnamn  Påstigande  Avstigande  Ombord
# 0              Hagaskolan         1.0         3.0     3.0
# 1               Norr Tull         4.0         0.0     7.0
# 2              Nya torget         1.0         1.0     7.0
# 3              Stortorget         4.0         0.0    15.0
# 4           Ljura Centrum         2.0         0.0    17.0
# ...                   ...         ...         ...     ...
# 3999995   Blockstensgatan         0.0         3.0     1.0
# 3999996            Spiran         0.0         6.0    10.0
# 3999997        Söder Tull         0.0         3.0     7.0
# 3999998    Koppargatan 30         2.0         0.0     4.0
# 3999999  Kättsättersgatan         1.0         0.0     2.0
#
# [3035820 rows x 8 columns]

# %%
# Hitta de index med maximal belastning
dataset_ATR_selection[['Ombord']].idxmax()
# Out:
# Ombord    493927
# dtype: int64

# %%
dataset_ATR_selection['Linje'].iloc[493927]
# Out:
# 2

# %%
# Få ut en lista på alla "Linjer"
dataset_ATR_selection_linje = dataset_ATR_selection.groupby('Linje').mean()
dataset_ATR_selection_linje.info()

# 95 rader data som inte är NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 2 to 617
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Påstigande  79 non-null     float64
#  1   Avstigande  79 non-null     float64
#  2   Ombord      79 non-null     float64
# dtypes: float64(3)
# memory usage: 2.5 KB

# %%
# Få ut en lista på alla "Linjer"
dataset_ATR_selection_linje = dataset_ATR_selection.groupby('Linje').mean()
dataset_ATR_selection_linje
# Out:
#        Påstigande  Avstigande     Ombord
# Linje
# 2        2.284240    2.334001  16.553633
# 3        2.206089    2.248103  12.400501
# 40       1.780581    1.743186  10.434620
# 41       2.556905    2.519084  11.015267
# 42       1.712310    1.716459   9.371369
# ...           ...         ...        ...
# 530      1.584677    1.584677   9.637097
# 572      1.079937    1.106744   4.645390
# 577      1.319149    1.382979   4.773050
# 616      1.273077    1.300000   6.865385
# 617      1.546218    1.592437   8.739496
#
# [79 rows x 3 columns]

# %%
# Hitta de index med maximal belastning
index_max = dataset_ATR_selection_linje[['Ombord']].idxmax()

# %%
dataset_ATR_selection['Linje'].iloc[index_max]
# Out:
# 250    2
# Name: Linje, dtype: int64

# %%
lines_list = dataset_ATR_selection_linje.index.values.tolist()
lines_list
# Out:
# [2,
#  3,
#  40,
#  41,
#  42,
#  45,
#  46,
#  58,
#  59,
#  70,
#  71,
#  74,
#  75,
#  110,
#  111,
#  112,
#  113,
#  120,
#  121,
#  141,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  220,
#  221,
#  222,
#  223,
#  226,
#  232,
#  241,
#  249,
#  250,
#  301,
#  302,
#  303,
#  304,
#  305,
#  308,
#  309,
#  310,
#  410,
#  412,
#  416,
#  429,
#  430,
#  432,
#  433,
#  440,
#  441,
#  444,
#  450,
#  452,
#  457,
#  459,
#  464,
#  480,
#  482,
#  483,
#  484,
#  486,
#  521,
#  522,
#  530,
#  572,
#  577,
#  616,
#  617]

# %%
# Gör en enklare analys av linje 40 då denna linje ser ut att ha ett högt medelvärde map överbelastning 
# (räknat att ett fordon tar 50 passagerare)

# Filtrera på en linje - 2
line = 210
filter_dataset_ATR_selection_line = dataset_ATR_selection['Linje'].values == line
dataset_ATR_selection_linje_line = dataset_ATR_selection.loc[filter_dataset_ATR_selection_line]
dataset_ATR_selection_linje_line.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100608 entries, 12568 to 3955574
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Datum          100608 non-null  object
#  1   Tidpunkt       100608 non-null  object
#  2   Linje          100608 non-null  int64
#  3   Hållplatstid   100608 non-null  object
#  4   Hållplatsnamn  100608 non-null  object
#  5   Påstigande     100608 non-null  float64
#  6   Avstigande     100608 non-null  float64
#  7   Ombord         100608 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 6.9+ MB

# %%
dataset_ATR_selection_linje_line
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 12568    2022-01-01  2022-01-01 05:57:10    210        05:57
# 12569    2022-01-01  2022-01-01 06:40:21    210        06:40
# 12570    2022-01-01  2022-01-01 06:05:59    210        06:05
# 12571    2022-01-01  2022-01-01 06:27:38    210        06:27
# 12572    2022-01-01  2022-01-01 06:30:38    210        06:30
# ...             ...                  ...    ...          ...
# 3955570  2022-03-24  2022-03-24 08:00:36    210        08:00
# 3955571  2022-03-24  2022-03-24 07:51:41    210        07:51
# 3955572  2022-03-24  2022-03-24 08:04:12    210        08:04
# 3955573  2022-03-24  2022-03-24 07:38:27    210        07:38
# 3955574  2022-03-24  2022-03-24 07:46:47    210        07:46
#
#                   Hållplatsnamn  Påstigande  Avstigande  Ombord
# 12568             Kråkbärsvägen         1.0         1.0     0.0
# 12569                   Roxtuna         0.0         0.0     0.0
# 12570                   Roxtuna         0.0         0.0     0.0
# 12571          Tinnerbäcksbadet         3.0         0.0     8.0
# 12572            Risbrinksgatan         1.0         3.0     1.0
# ...                         ...         ...         ...     ...
# 3955570        Tinnerbäcksbadet         0.0         1.0    15.0
# 3955571  Ekholmen Brokindsleden         0.0         3.0    15.0
# 3955572              Kungsgatan         0.0        10.0     5.0
# 3955573           Kråkbärsvägen         1.0         1.0     0.0
# 3955574               Harvestad         4.0         0.0    16.0
#
# [100608 rows x 8 columns]

# %%
firstValue = dataset_ATR_selection_linje_line['Ombord'].iloc[0]
firstValue
# Out:
# 0.0

# %%
testOmbord = []
testOmbord.append(firstValue)
testOmbord
# Out:
# [0.0]

# %%
onGoing = dataset_ATR_selection_linje_line['Påstigande'].values
onGoing
# Out:
# array([1., 0., 0., ..., 0., 1., 4.])

# %%
offGoing = dataset_ATR_selection_linje_line['Avstigande'].values
offGoing
# Out:
# array([ 1.,  0.,  0., ..., 10.,  1.,  0.])

# %%
onBoard = dataset_ATR_selection_linje_line['Ombord'].values
onBoard
# Out:
# array([ 0.,  0.,  0., ...,  5.,  0., 16.])

# %%
for i in range(0, len(onGoing) - 1):
    testOnBuss = testOmbord[i] + onGoing[i + 1] - offGoing[i + 1]
    if testOnBuss < 0:
        testOmbord.append(0)
    else:
        testOmbord.append(testOnBuss)
len(testOmbord)
# Out:
# 100608

# %%
dataset_ATR_selection_linje_line['TestOmbord'] = testOmbord
dataset_ATR_selection_linje_line.head(40)
# Out:
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_3948/613332633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_ATR_selection_linje_line['TestOmbord'] = testOmbord
#             Datum             Tidpunkt  Linje Hållplatstid  \
# 12568  2022-01-01  2022-01-01 05:57:10    210        05:57
# 12569  2022-01-01  2022-01-01 06:40:21    210        06:40
# 12570  2022-01-01  2022-01-01 06:05:59    210        06:05
# 12571  2022-01-01  2022-01-01 06:27:38    210        06:27
# 12572  2022-01-01  2022-01-01 06:30:38    210        06:30
# 12573  2022-01-01  2022-01-01 06:37:42    210        06:37
# 12574  2022-01-01  2022-01-01 06:26:10    210        06:26
# 12575  2022-01-01  2022-01-01 06:46:31    210        06:46
# 12576  2022-01-01  2022-01-01 06:22:31    210        06:22
# 12577  2022-01-01  2022-01-01 06:29:13    210        06:29
# 12578  2022-01-01  2022-01-01 07:07:42    210        07:07
# 12579  2022-01-01  2022-01-01 07:25:21    210        07:25
# 12580  2022-01-01  2022-01-01 07:30:50    210        07:30
# 12581  2022-01-01  2022-01-01 07:32:55    210        07:32
# 12582  2022-01-01  2022-01-01 07:16:07    210        07:16
# 12583  2022-01-01  2022-01-01 07:17:24    210        07:17
# 12584  2022-01-01  2022-01-01 07:21:19    210        07:21
# 12585  2022-01-01  2022-01-01 07:29:29    210        07:29
# 12586  2022-01-01  2022-01-01 07:49:41    210        07:49
# 12587  2022-01-01  2022-01-01 07:35:05    210        07:35
# 12588  2022-01-01  2022-01-01 07:38:11    210        07:38
# 12589  2022-01-01  2022-01-01 07:44:17    210        07:44
# 12590  2022-01-01  2022-01-01 07:49:06    210        07:49
# 12591  2022-01-01  2022-01-01 07:14:06    210        07:14
# 12592  2022-01-01  2022-01-01 07:30:08    210        07:30
# 12593  2022-01-01  2022-01-01 07:32:15    210        07:32
# 12594  2022-01-01  2022-01-01 07:52:37    210        07:52
# 12595  2022-01-01  2022-01-01 08:15:40    210        08:15
# 12589             0.0
# 12590            -1.0
# 12591             0.0
# 12592             0.0
# 12593             0.0
# 12594            -4.0
# 12595            -1.0
# 12596             0.0
# 12597             1.0
# 12598            -1.0
# 12599            -1.0
# 12600             0.0
# 12601            -1.0
# 12602             0.0
# 12603            -1.0
# 12604            -1.0
# 12605            -1.0
# 12606             0.0
# 12607            -1.0

# %%
# Få ut en lista på alla datum --> 83 dagar --> relativt lite erfarenhet
dataset_ATR_selection_datum = dataset_ATR_selection_linje_line.groupby('Datum').mean()
dataset_ATR_selection_datum
# Out:
#             Linje  Påstigande  Avstigande    Ombord  TestOmbord  \
# Datum
# 2022-01-01  210.0    0.874317    0.874317  2.686703    7.351548
# 2022-01-02  210.0    0.958692    0.969019  2.993115   12.323580
# 2022-01-03  210.0    1.070598    1.072259  4.158638   15.055648
# 2022-01-04  210.0    1.053601    1.062814  3.948911   18.199330
# 2022-01-05  210.0    0.994108    1.012626  3.680976   10.117845
# ...           ...         ...         ...       ...         ...
# 2022-03-20  210.0    1.015625    1.035937  3.767187   10.339063
# 2022-03-21  210.0    1.735758    1.750172  8.429650   22.746054
# 2022-03-22  210.0    1.830940    1.845300  9.184726   33.226501
# 2022-03-23  210.0    1.804730    1.825000  8.864865   30.485811
# 2022-03-24  210.0    1.797510    1.788991  9.299476   34.321756
#
#             TestOmbordDiff
# Datum
# 2022-01-01       -4.664845
# 2022-01-02       -9.330465
# 2022-01-03      -10.897010
# 2022-01-04      -14.250419
# 2022-01-05       -6.436869
# ...                    ...
# 2022-03-20       -6.571875
# 2022-03-21      -14.316404
# 2022-03-22      -24.041775
# 2022-03-23      -21.620946
# 2022-03-24      -25.022280
#
# [83 rows x 6 columns]

# %%
# Hitta de index med maximal belastning
dataset_ATR_selection_linje_line[['Ombord']].idxmax()
# Out:
# Ombord    3954929
# dtype: int64

# %%
def plot_passengersOnboard(dataset):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(dataset['TestOmbord'].values)
    ax.grid(True)

    plt.title('2022-03-08 Linje 210')
    #plt.xlabel(dataset['Tidpunkt'].values)
    plt.ylabel('Antal Passagerare')

plot_passengersOnboard(dataset_ATR_selection_linje_line)

# %%
# Select all values  less than 0 (all negative values) - how can this value be negative?
filter_dataset_negative_values = dataset_ATR_selection_linje_line['Ombord'].values <= -1
dataset_ATR_selection_negatives = dataset_ATR_selection_linje_line.loc[filter_dataset_negative_values]
dataset_ATR_selection_negatives
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 12590    2022-01-01  2022-01-01 07:49:06    210        07:49
# 12594    2022-01-01  2022-01-01 07:52:37    210        07:52
# 12625    2022-01-01  2022-01-01 10:18:16    210        10:18
# 12628    2022-01-01  2022-01-01 10:11:26    210        10:11
# 12656    2022-01-01  2022-01-01 11:27:05    210        11:27
# ...             ...                  ...    ...          ...
# 3955433  2022-03-24  2022-03-24 21:18:57    210        21:18
# 3955435  2022-03-24  2022-03-24 21:20:06    210        21:20
# 3955442  2022-03-24  2022-03-24 21:14:07    210        21:14
# 3955539  2022-03-24  2022-03-24 07:40:32    210        07:40
# 3955568  2022-03-24  2022-03-24 08:09:21    210        08:09
#
#                   Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 12590         Sturefors centrum         0.0         1.0    -1.0         0.0
# 12594             Kråkbärsvägen         0.0         1.0    -2.0         2.0
# 12625                   Roxtuna         0.0         1.0    -2.0         1.0
# 12628                Bryggvägen         0.0         1.0    -1.0         2.0
# 12656             Kråkbärsvägen         0.0         0.0    -1.0         2.0
# ...                         ...         ...         ...     ...         ...
# 3955433              Vist skola         0.0         1.0    -1.0        45.0
# 3955435           Kråkbärsvägen         0.0         0.0    -1.0        45.0
# 3955442                 Roxtuna         0.0         3.0    -1.0        43.0
# 3955539  Linköpings resecentrum         0.0        29.0    -1.0        33.0
# 3955568  Linköpings resecentrum         0.0         6.0    -1.0        56.0
#
#          TestOmbordDiff
# 12590              -1.0
# 12594              -4.0
# 12625              -3.0
# 12628              -3.0
# 12656              -3.0
# ...                 ...
# 3955433           -46.0
# 3955435           -46.0
# 3955442           -44.0
# 3955539           -34.0
# 3955568           -57.0
#
# [4038 rows x 10 columns]

# %%
len(dataset_ATR_selection_negatives) / len(dataset_ATR_selection_linje_line)
# Out:
# 0.04013597328244275

# %%
# Select a day where negative values are presented and try to see why the value is negative
filter_dataset_negative_date = dataset_ATR_selection_linje_line['Datum'].values == '2022-01-01'
dataset_ATR_selection_negatives_date = dataset_ATR_selection_linje_line.loc[filter_dataset_negative_date]
dataset_ATR_selection_negatives_date.head(40)
# Out:
#             Datum             Tidpunkt  Linje Hållplatstid  \
# 12568  2022-01-01  2022-01-01 05:57:10    210        05:57
# 12569  2022-01-01  2022-01-01 06:40:21    210        06:40
# 12570  2022-01-01  2022-01-01 06:05:59    210        06:05
# 12571  2022-01-01  2022-01-01 06:27:38    210        06:27
# 12572  2022-01-01  2022-01-01 06:30:38    210        06:30
# 12573  2022-01-01  2022-01-01 06:37:42    210        06:37
# 12574  2022-01-01  2022-01-01 06:26:10    210        06:26
# 12575  2022-01-01  2022-01-01 06:46:31    210        06:46
# 12576  2022-01-01  2022-01-01 06:22:31    210        06:22
# 12577  2022-01-01  2022-01-01 06:29:13    210        06:29
# 12578  2022-01-01  2022-01-01 07:07:42    210        07:07
# 12579  2022-01-01  2022-01-01 07:25:21    210        07:25
# 12580  2022-01-01  2022-01-01 07:30:50    210        07:30
# 12581  2022-01-01  2022-01-01 07:32:55    210        07:32
# 12582  2022-01-01  2022-01-01 07:16:07    210        07:16
# 12583  2022-01-01  2022-01-01 07:17:24    210        07:17
# 12584  2022-01-01  2022-01-01 07:21:19    210        07:21
# 12585  2022-01-01  2022-01-01 07:29:29    210        07:29
# 12586  2022-01-01  2022-01-01 07:49:41    210        07:49
# 12587  2022-01-01  2022-01-01 07:35:05    210        07:35
# 12588  2022-01-01  2022-01-01 07:38:11    210        07:38
# 12597               Stångebro         0.0         1.0     2.0         1.0
# 12598           Kråkbärsvägen         1.0         0.0     1.0         2.0
# 12599                 Roxtuna         0.0         0.0     1.0         2.0
# 12600  Linköpings resecentrum         2.0         1.0     3.0         3.0
# 12601             Hallonvägen         0.0         1.0     1.0         2.0
# 12602               Jakobsdal         1.0         0.0     3.0         3.0
# 12603               Harvestad         0.0         1.0     1.0         2.0
# 12604              Vist skola         0.0         1.0     0.0         1.0
# 12605                 Roxtuna         1.0         1.0     0.0         1.0
# 12606        Tinnerbäcksbadet         1.0         0.0     2.0         2.0
# 12607       Sturefors centrum         0.0         0.0     1.0         2.0
#
#        TestOmbordDiff
# 12568             0.0
# 12569             0.0
# 12570             0.0
# 12571             5.0
# 12572             0.0
# 12573             0.0
# 12574             4.0
# 12575            -1.0
# 12576            -1.0
# 12577             3.0
# 12578             0.0
# 12579             3.0
# 12580             1.0
# 12581             0.0
# 12582             0.0
# 12583             0.0
# 12584             0.0
# 12585             0.0
# 12586            -2.0
# 12587             1.0
# 12588             1.0
# 12589             0.0
# 12590            -1.0
# 12591             0.0
# 12592             0.0
# 12593             0.0
# 12594            -4.0
# 12595            -1.0
# 12596             0.0
# 12597             1.0
# 12598            -1.0
# 12599            -1.0
# 12600             0.0
# 12601            -1.0
# 12602             0.0
# 12603            -1.0
# 12604            -1.0
# 12605            -1.0
# 12606             0.0
# 12607            -1.0

# %%
data_ai = dataset_ATR_selection_linje_line['TestOmbord'].values.reshape(-1, 1)
data_ai
# Out:
# array([[ 0.],
#        [ 0.],
#        [ 0.],
#        ...,
#        [44.],
#        [44.],
#        [48.]])

# %%
# Scaling the training_set (use standardisation or normalization)
# Since our output signal is continous (sigmoid function)
# --> NORMALIZATION is recommended
from sklearn.preprocessing import StandardScaler

# Implement a scaler with value (range) between 0 and 1
scaler = StandardScaler()

# %%
# Apply scaler in training set
training_set_scaled = scaler.fit_transform(data_ai)
training_set_scaled
# Out:
# array([[-2.07324579],
#        [-2.07324579],
#        [-2.07324579],
#        ...,
#        [ 1.25641541],
#        [ 1.25641541],
#        [ 1.55911188]])

# %%
# Convert series to supervised learning - input predicting pollution outputs
from pandas import concat

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# Frame as supervised learning
supervised_data = series_to_supervised(training_set_scaled, 1, 1)
supervised_data
# Out:
#         var1(t-1)   var1(t)
# 1       -2.073246 -2.073246
# 2       -2.073246 -2.073246
# 3       -2.073246 -1.846223
# 4       -1.846223 -1.997572
# 5       -1.997572 -2.073246
# ...           ...       ...
# 100603   2.315853  2.240179
# 100604   2.240179  2.013157
# 100605   2.013157  1.256415
# 100606   1.256415  1.256415
# 100607   1.256415  1.559112
#
# [100607 rows x 2 columns]

# %%
# 80% data for training and 20% data for test 
# Training --> 12327 * 0.8 = 9862
# Test --> 12327 - 9861 = 2465
supervised_values = supervised_data.values

# %%
# 80% data for training and 20% data for test 
# Training --> 12327 * 0.8 = 9861
# Test --> 12327 - 9861 = 2466
n_train_time = round(len(supervised_values) * 0.8)
n_train_time
# Out:
# 80486

# %%
# Trainingset --> 20210101 to 20220206
train = supervised_values[:n_train_time, :]
len(train)
# Out:
# 80486

# %%
# Testing 20% --> 1 114 476 to 1 393 094
n_test_stop = len(supervised_values)
test = supervised_values[n_train_time:n_test_stop, :]
len(test)
# Out:
# 20121

# %%
# Split into input and outputs --> all values exept the last column is X, the last column is y
train_X, train_y = train[:, :-1], train[:, -1]
len(train_y)
# Out:
# 80486

# %%
# This is where it becomes different when we dont have any data to validate our result wiht
# Then we only have text_X
test_X, test_y = test[:, :-1], test[:, -1]
len(test_X)
# Out:
# 20121

# %%
# Reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (80486, 1, 1) (80486,) (20121, 1, 1) (20121,)

# %%
# Neural network
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
'''
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
'''
neurons = 50
# Initializing the RNN 
# The output is continous value --> use regression
regressor = Sequential()

# Add the first layer to the neural network
regressor.add(LSTM(units = neurons, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))

# Dropout regulation (use to be 20%)
# --> this is the number of neurons to be ignored
regressor.add(Dropout(0.2))

# Add more layers to the neural network
# Second layer
regressor.add(LSTM(units = neurons, return_sequences = True))
regressor.add(Dropout(0.2))

# Third layer
regressor.add(LSTM(units = neurons, return_sequences = True))
regressor.add(Dropout(0.2))

# Forth layer - last layer before output  layer
regressor.add(LSTM(units = neurons))
regressor.add(Dropout(0.2))

# Output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
# NOTE: Optimizer - RMSprops is recommended for RNN but Adam was detected to 
# be a better choice for this problem
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error') #mean_squared_error

# %%
# Training the network
history = regressor.fit(train_X, train_y, epochs=20, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/20
# 2516/2516 - 29s - loss: 0.1383 - val_loss: 0.1147 - 29s/epoch - 11ms/step
# Epoch 2/20
# 2516/2516 - 24s - loss: 0.0970 - val_loss: 0.1183 - 24s/epoch - 10ms/step
# Epoch 3/20
# 2516/2516 - 23s - loss: 0.0930 - val_loss: 0.1257 - 23s/epoch - 9ms/step
# Epoch 4/20
# 2516/2516 - 23s - loss: 0.0913 - val_loss: 0.1213 - 23s/epoch - 9ms/step
# Epoch 5/20
# 2516/2516 - 24s - loss: 0.0902 - val_loss: 0.1204 - 24s/epoch - 9ms/step
# Epoch 6/20
# 2516/2516 - 23s - loss: 0.0894 - val_loss: 0.1199 - 23s/epoch - 9ms/step
# Epoch 7/20
# 2516/2516 - 23s - loss: 0.0887 - val_loss: 0.1195 - 23s/epoch - 9ms/step
# Epoch 8/20
# 2516/2516 - 23s - loss: 0.0879 - val_loss: 0.1172 - 23s/epoch - 9ms/step
# Epoch 9/20
# 2516/2516 - 23s - loss: 0.0877 - val_loss: 0.1198 - 23s/epoch - 9ms/step
# Epoch 10/20
# 2516/2516 - 23s - loss: 0.0874 - val_loss: 0.1191 - 23s/epoch - 9ms/step
# Epoch 11/20
# 2516/2516 - 23s - loss: 0.0867 - val_loss: 0.1176 - 23s/epoch - 9ms/step
# Epoch 12/20
# 2516/2516 - 23s - loss: 0.0870 - val_loss: 0.1180 - 23s/epoch - 9ms/step
# Epoch 13/20
# 2516/2516 - 23s - loss: 0.0871 - val_loss: 0.1173 - 23s/epoch - 9ms/step
# Epoch 14/20
# 2516/2516 - 23s - loss: 0.0862 - val_loss: 0.1203 - 23s/epoch - 9ms/step
# Epoch 15/20
# 2516/2516 - 22s - loss: 0.0865 - val_loss: 0.1173 - 22s/epoch - 9ms/step
# Epoch 16/20
# 2516/2516 - 23s - loss: 0.0868 - val_loss: 0.1158 - 23s/epoch - 9ms/step
# Epoch 17/20
# 2516/2516 - 22s - loss: 0.0861 - val_loss: 0.1154 - 22s/epoch - 9ms/step
# Epoch 18/20
# 2516/2516 - 24s - loss: 0.0862 - val_loss: 0.1192 - 24s/epoch - 10ms/step
# Epoch 19/20
# 2516/2516 - 25s - loss: 0.0858 - val_loss: 0.1168 - 25s/epoch - 10ms/step
# Epoch 20/20

# %%
'''
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
'''

# %%
# Plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
y_prediction = regressor.predict(test_X)
y_prediction
# Out:
# array([[3.0096815 ],
#        [3.0797338 ],
#        [3.0443797 ],
#        ...,
#        [0.17230214],
#        [0.5548485 ],
#        [0.77728444]], dtype=float32)

# %%
y_prediction = y_prediction.reshape(-1,1)
y_prediction_retrans = scaler.inverse_transform(y_prediction).round()
y_prediction_retrans
# Out:
# array([[112.],
#        [114.],
#        [113.],
#        ...,
#        [ 38.],
#        [ 48.],
#        [ 54.]], dtype=float32)

# %%
test_y = test_y.reshape(-1,1)
test_y_retrans = scaler.inverse_transform(test_y).round()
test_y_retrans
# Out:
# array([[118.],
#        [117.],
#        [118.],
#        ...,
#        [ 49.],
#        [ 55.],
#        [ 65.]])

# %%
def plot_result_prediction(y_prediction, y_test):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(y_prediction_retrans, label='Predicted passengers')
    ax.plot((-1*test_y_retrans), label='Actual passengers')
    #ax.plot((y_prediction_retrans - test_y_retrans), label='Error')
    ax.grid(True)

    plt.title('Prediktion Antal Passagerare 2022-10-01')
    plt.xlabel('Time')
    plt.ylabel('Antal passagerare')
    plt.legend(['Prediktion passagerare', 'Faktiska passagerare', 'Error'])

plot_result_prediction(y_prediction_retrans, test_y_retrans)

# %%
errorList = []
for i in range(0, len(y_prediction_retrans)):
    y_pred = y_prediction_retrans[i]
    y_test = test_y_retrans[i]
    if y_pred < 0:
        y_pred = -1*y_pred
    if y_test < 0:
        y_test = -1*y_test
    error = y_pred - y_test
    if error < 0:
        error = error *-1
    errorList.append(error)
errorList
# Out:
# [array([6.]),
#  array([3.]),
#  array([5.]),
#  array([7.]),
#  array([26.]),
#  array([9.]),
#  array([4.]),
#  array([3.]),
#  array([14.]),
#  array([5.]),
#  array([10.]),
#  array([6.]),
#  array([19.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([0.]),
#  array([3.]),
#  array([4.]),
#  array([2.]),
#  array([4.]),
#  array([8.]),
#  array([3.]),
#  array([3.]),
#  array([9.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([4.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([9.]),
#  array([4.]),
#  array([1.]),
#  array([10.]),
#  array([21.]),
#  array([7.]),
#  array([15.]),
#  array([8.]),
#  array([12.]),
#  array([5.]),
#  array([2.]),
#  array([27.]),
#  array([5.]),
#  array([8.]),
#  array([0.]),
#  array([3.]),
#  array([53.]),
#  array([2.]),
#  array([0.]),
#  array([5.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([5.]),
#  array([1.]),
#  array([7.]),
#  array([5.]),
#  array([0.]),
#  array([6.]),
#  array([1.]),
#  array([3.]),
#  array([5.]),
#  array([3.]),
#  array([1.]),
#  array([4.]),
#  array([8.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([6.]),
#  array([4.]),
#  array([9.]),
#  array([0.]),
#  array([14.]),
#  array([1.]),
#  array([5.]),
#  array([4.]),
#  array([7.]),
#  array([5.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([1.]),
#  array([11.]),
#  array([2.]),
#  array([30.]),
#  array([5.]),
#  array([50.]),
#  array([4.]),
#  array([11.]),
#  array([13.]),
#  array([4.]),
#  array([3.]),
#  array([4.]),
#  array([3.]),
#  array([16.]),
#  array([4.]),
#  array([5.]),
#  array([5.]),
#  array([0.]),
#  array([1.]),
#  array([11.]),
#  array([12.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([4.]),
#  array([3.]),
#  array([4.]),
#  array([10.]),
#  array([7.]),
#  array([2.]),
#  array([4.]),
#  array([1.]),
#  array([11.]),
#  array([12.]),
#  array([1.]),
#  array([4.]),
#  array([7.]),
#  array([6.]),
#  array([10.]),
#  array([22.]),
#  array([24.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([4.]),
#  array([7.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([22.]),
#  array([2.]),
#  array([3.]),
#  array([5.]),
#  array([9.]),
#  array([11.]),
#  array([9.]),
#  array([4.]),
#  array([0.]),
#  array([5.]),
#  array([0.]),
#  array([5.]),
#  array([0.]),
#  array([11.]),
#  array([14.]),
#  array([3.]),
#  array([1.]),
#  array([2.]),
#  array([6.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([2.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([6.]),
#  array([9.]),
#  array([3.]),
#  array([5.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([9.]),
#  array([1.]),
#  array([0.]),
#  array([30.]),
#  array([4.]),
#  array([4.]),
#  array([1.]),
#  array([19.]),
#  array([3.]),
#  array([2.]),
#  array([11.]),
#  array([0.]),
#  array([4.]),
#  array([5.]),
#  array([14.]),
#  array([2.]),
#  array([1.]),
#  array([6.]),
#  array([7.]),
#  array([14.]),
#  array([17.]),
#  array([0.]),
#  array([0.]),
#  array([5.]),
#  array([1.]),
#  array([12.]),
#  array([2.]),
#  array([6.]),
#  array([2.]),
#  array([6.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([6.]),
#  array([4.]),
#  array([3.]),
#  array([6.]),
#  array([2.]),
#  array([0.]),
#  array([1.]),
#  array([6.]),
#  array([2.]),
#  array([6.]),
#  array([6.]),
#  array([3.]),
#  array([1.]),
#  array([3.]),
#  array([12.]),
#  array([36.]),
#  array([3.]),
#  array([3.]),
#  array([5.]),
#  array([11.]),
#  array([5.]),
#  array([9.]),
#  array([19.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([16.]),
#  array([1.]),
#  array([2.]),
#  array([6.]),
#  array([2.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([9.]),
#  array([2.]),
#  array([5.]),
#  array([7.]),
#  array([0.]),
#  array([2.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([6.]),
#  array([1.]),
#  array([6.]),
#  array([2.]),
#  array([12.]),
#  array([18.]),
#  array([4.]),
#  array([3.]),
#  array([6.]),
#  array([11.]),
#  array([4.]),
#  array([10.]),
#  array([3.]),
#  array([0.]),
#  array([10.]),
#  array([11.]),
#  array([8.]),
#  array([13.]),
#  array([2.]),
#  array([0.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([13.]),
#  array([2.]),
#  array([2.]),
#  array([8.]),
#  array([10.]),
#  array([2.]),
#  array([2.]),
#  array([4.]),
#  array([4.]),
#  array([0.]),
#  array([10.]),
#  array([27.]),
#  array([5.]),
#  array([2.]),
#  array([8.]),
#  array([15.]),
#  array([10.]),
#  array([4.]),
#  array([0.]),
#  array([2.]),
#  array([0.]),
#  array([3.]),
#  array([6.]),
#  array([1.]),
#  array([13.]),
#  array([8.]),
#  array([4.]),
#  array([4.]),
#  array([5.]),
#  array([1.]),
#  array([7.]),
#  array([24.]),
#  array([3.]),
#  array([4.]),
#  array([0.]),
#  array([2.]),
#  array([5.]),
#  array([3.]),
#  array([19.]),
#  array([19.]),
#  array([2.]),
#  array([6.]),
#  array([9.]),
#  array([3.]),
#  array([2.]),
#  array([2.]),
#  array([5.]),
#  array([9.]),
#  array([5.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([5.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([6.]),
#  array([1.]),
#  array([2.]),
#  array([5.]),
#  array([1.]),
#  array([3.]),
#  array([7.]),
#  array([2.]),
#  array([8.]),
#  array([8.]),
#  array([3.]),
#  array([2.]),
#  array([3.]),
#  array([8.]),
#  array([2.]),
#  array([7.]),
#  array([3.]),
#  array([6.]),
#  array([5.]),
#  array([5.]),
#  array([10.]),
#  array([1.]),
#  array([20.]),
#  array([0.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([0.]),
#  array([33.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([12.]),
#  array([0.]),
#  array([11.]),
#  array([5.]),
#  array([6.]),
#  array([4.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([8.]),
#  array([0.]),
#  array([4.]),
#  array([3.]),
#  array([0.]),
#  array([8.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([6.]),
#  array([2.]),
#  array([1.]),
#  array([7.]),
#  array([7.]),
#  array([1.]),
#  array([1.]),
#  array([7.]),
#  array([11.]),
#  array([2.]),
#  array([4.]),
#  array([18.]),
#  array([7.]),
#  array([2.]),
#  array([1.]),
#  array([6.]),
#  array([14.]),
#  array([2.]),
#  array([4.]),
#  array([1.]),
#  array([0.]),
#  array([10.]),
#  array([1.]),
#  array([18.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([5.]),
#  array([0.]),
#  array([4.]),
#  array([5.]),
#  array([5.]),
#  array([2.]),
#  array([6.]),
#  array([5.]),
#  array([1.]),
#  array([24.]),
#  array([9.]),
#  array([0.]),
#  array([0.]),
#  array([5.]),
#  array([4.]),
#  array([3.]),
#  array([3.]),
#  array([5.]),
#  array([9.]),
#  array([12.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([26.]),
#  array([1.]),
#  array([1.]),
#  array([7.]),
#  array([4.]),
#  array([12.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([12.]),
#  array([1.]),
#  array([10.]),
#  array([0.]),
#  array([24.]),
#  array([12.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([16.]),
#  array([2.]),
#  array([8.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([2.]),
#  array([1.]),
#  array([12.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([3.]),
#  array([9.]),
#  array([0.]),
#  array([10.]),
#  array([4.]),
#  array([3.]),
#  array([2.]),
#  array([4.]),
#  array([7.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([5.]),
#  array([30.]),
#  array([10.]),
#  array([6.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([11.]),
#  array([3.]),
#  array([4.]),
#  array([8.]),
#  array([6.]),
#  array([10.]),
#  array([0.]),
#  array([3.]),
#  array([1.]),
#  array([2.]),
#  array([18.]),
#  array([6.]),
#  array([1.]),
#  array([7.]),
#  array([4.]),
#  array([2.]),
#  array([2.]),
#  array([7.]),
#  array([6.]),
#  array([2.]),
#  array([2.]),
#  array([4.]),
#  array([2.]),
#  array([3.]),
#  array([7.]),
#  array([13.]),
#  array([2.]),
#  array([2.]),
#  array([4.]),
#  array([8.]),
#  array([2.]),
#  array([0.]),
#  array([1.]),
#  array([8.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([3.]),
#  array([2.]),
#  array([5.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([12.]),
#  array([1.]),
#  array([2.]),
#  array([6.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([0.]),
#  array([3.]),
#  array([3.]),
#  array([6.]),
#  array([1.]),
#  array([4.]),
#  array([0.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([6.]),
#  array([3.]),
#  array([6.]),
#  array([5.]),
#  array([2.]),
#  array([4.]),
#  array([3.]),
#  array([5.]),
#  array([8.]),
#  array([2.]),
#  array([5.]),
#  array([4.]),
#  array([4.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([6.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([10.]),
#  array([5.]),
#  array([6.]),
#  array([3.]),
#  array([4.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([13.]),
#  array([6.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([5.]),
#  array([1.]),
#  array([4.]),
#  array([2.]),
#  array([4.]),
#  array([3.]),
#  array([2.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([5.]),
#  array([11.]),
#  array([2.]),
#  array([0.]),
#  array([5.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([2.]),
#  array([6.]),
#  array([10.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([3.]),
#  array([13.]),
#  array([4.]),
#  array([2.]),
#  array([1.]),
#  array([8.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([4.]),
#  array([3.]),
#  array([3.]),
#  array([7.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([8.]),
#  array([0.]),
#  array([2.]),
#  array([4.]),
#  array([0.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([12.]),
#  array([7.]),
#  array([4.]),
#  array([7.]),
#  array([0.]),
#  array([0.]),
#  array([2.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([8.]),
#  array([5.]),
#  array([3.]),
#  array([1.]),
#  array([7.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([6.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([1.]),
#  array([0.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([0.]),
#  array([4.]),
#  array([4.]),
#  array([3.]),
#  array([10.]),
#  array([6.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([6.]),
#  array([2.]),
#  array([0.]),
#  array([1.]),
#  array([2.]),
#  array([9.]),
#  array([2.]),
#  array([9.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([5.]),
#  array([4.]),
#  array([12.]),
#  array([5.]),
#  array([2.]),
#  array([4.]),
#  array([4.]),
#  array([4.]),
#  array([11.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([4.]),
#  array([3.]),
#  array([2.]),
#  array([3.]),
#  array([3.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([7.]),
#  array([4.]),
#  array([1.]),
#  array([7.]),
#  array([13.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([6.]),
#  array([0.]),
#  array([5.]),
#  array([2.]),
#  array([3.]),
#  array([4.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([9.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([3.]),
#  array([14.]),
#  array([1.]),
#  array([4.]),
#  array([3.]),
#  array([2.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([1.]),
#  array([7.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([5.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([10.]),
#  array([13.]),
#  array([20.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([12.]),
#  array([3.]),
#  array([3.]),
#  array([4.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([0.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([3.]),
#  array([0.]),
#  array([2.]),
#  array([1.]),
#  array([5.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([5.]),
#  array([4.]),
#  array([9.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([0.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([3.]),
#  array([5.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([5.]),
#  array([2.]),
#  array([8.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([8.]),
#  array([1.]),
#  array([6.]),
#  array([4.]),
#  array([3.]),
#  array([6.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([7.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([6.]),
#  array([6.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([7.]),
#  array([0.]),
#  array([5.]),
#  array([0.]),
#  array([7.]),
#  array([2.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([5.]),
#  array([3.]),
#  array([1.]),
#  array([5.]),
#  array([19.]),
#  array([11.]),
#  array([4.]),
#  array([0.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([2.]),
#  array([2.]),
#  array([6.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([0.]),
#  array([2.]),
#  array([0.]),
#  array([4.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([5.]),
#  array([2.]),
#  array([2.]),
#  array([4.]),
#  array([8.]),
#  array([3.]),
#  array([0.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([2.]),
#  array([4.]),
#  array([7.]),
#  array([1.]),
#  array([0.]),
#  array([4.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([3.]),
#  array([5.]),
#  array([5.]),
#  array([1.]),
#  array([4.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([5.]),
#  array([7.]),
#  array([1.]),
#  array([4.]),
#  array([13.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([5.]),
#  array([6.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([4.]),
#  array([4.]),
#  array([4.]),
#  array([2.]),
#  array([3.]),
#  array([6.]),
#  array([1.]),
#  array([5.]),
#  array([4.]),
#  array([0.]),
#  array([2.]),
#  array([4.]),
#  array([8.]),
#  array([2.]),
#  array([10.]),
#  array([2.]),
#  array([5.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([18.]),
#  array([1.]),
#  array([5.]),
#  array([2.]),
#  array([3.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  ...]

# %%
# Visualising the results      
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.autofmt_xdate(rotation=45)
ax.plot(errorList, label='Error')
ax.grid(True)

plt.title('Felet i uppskattat antal passagerare')
plt.xlabel('Time')
plt.ylabel('Antal passagerare')
plt.legend(['Error'])

# %%
len(y_prediction)
# Out:
# 66292

# %%
# Pick out day 13 - 14 of november as test values
day_2022_03_24 = dataset_ATR_selection_linje_2[dataset_ATR_selection_linje_2['Datum'] == "2022-03-24"]
day_2022_03_25 = dataset_ATR_selection_linje_2[dataset_ATR_selection_linje_2['Datum'] == "2022-03-25"]
frames = [day_2022_03_24, 
          day_2022_03_25,
          ]
validation_x = pd.concat(frames)
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff
# 3923170           -78.0
# 3923171           -78.0
# 3923172           -78.0
# 3923173           -78.0
# 3923174           -77.0
# ...                 ...
# 3986489             7.0
# 3986490            25.0
# 3986491           -28.0
# 3986492           -24.0
# 3986493           -55.0
#
# [8618 rows x 10 columns]

# %%
last_values = len(y_prediction_retrans) - len(validation_x)
y_pred_03_24_to_03_25 = y_prediction_retrans[last_values:]
len(y_pred_03_24_to_03_25)
# Out:
# 8618

# %%
validation_x['Prediction'] = y_pred_03_24_to_03_25 * -1
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff  Prediction
# 3923170           -78.0       -77.0
# 3923171           -78.0       -77.0
# 3923172           -78.0       -77.0
# 3923173           -78.0       -76.0
# 3923174           -77.0       -76.0
# ...                 ...         ...
# 3986489             7.0       -15.0
# 3986490            25.0       -19.0
# 3986491           -28.0       -38.0
# 3986492           -24.0       -48.0
# 3986493           -55.0       -54.0
#
# [8618 rows x 11 columns]

# %%
test_y_03_24_to_03_25 = test_y_retrans[last_values:]
len(test_y_03_24_to_03_25)
# Out:
# 8618

# %%
validation_x['test_y'] = test_y_03_24_to_03_25
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff  Prediction  test_y
# 3923170           -78.0       -77.0    78.0
# 3923171           -78.0       -77.0    78.0
# 3923172           -78.0       -77.0    77.0
# 3923173           -78.0       -76.0    77.0
# 3923174           -77.0       -76.0    77.0
# ...                 ...         ...     ...
# 3986489             7.0       -15.0    18.0
# 3986490            25.0       -19.0    38.0
# 3986491           -28.0       -38.0    49.0
# 3986492           -24.0       -48.0    55.0
# 3986493           -55.0       -54.0    65.0
#
# [8618 rows x 12 columns]

# %%
validation_x['Error'] = (-1* validation_x['Prediction']) - validation_x['test_y']
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff  Prediction  test_y  Error
# 3923170           -78.0       -77.0    78.0   -1.0
# 3923171           -78.0       -77.0    78.0   -1.0
# 3923172           -78.0       -77.0    77.0    0.0
# 3923173           -78.0       -76.0    77.0   -1.0
# 3923174           -77.0       -76.0    77.0   -1.0
# ...                 ...         ...     ...    ...
# 3986489             7.0       -15.0    18.0   -3.0
# 3986490            25.0       -19.0    38.0  -19.0
# 3986491           -28.0       -38.0    49.0  -11.0
# 3986492           -24.0       -48.0    55.0   -7.0
# 3986493           -55.0       -54.0    65.0  -11.0
#
# [8618 rows x 13 columns]

# %%
validation_x.round(decimals = 1)
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff  Prediction  test_y  Error
# 3923170           -78.0       -77.0    78.0   -1.0
# 3923171           -78.0       -77.0    78.0   -1.0
# 3923172           -78.0       -77.0    77.0    0.0
# 3923173           -78.0       -76.0    77.0   -1.0
# 3923174           -77.0       -76.0    77.0   -1.0
# ...                 ...         ...     ...    ...
# 3986489             7.0       -15.0    18.0   -3.0
# 3986490            25.0       -19.0    38.0  -19.0
# 3986491           -28.0       -38.0    49.0  -11.0
# 3986492           -24.0       -48.0    55.0   -7.0
# 3986493           -55.0       -54.0    65.0  -11.0
#
# [8618 rows x 13 columns]

# %%
date_time = pd.to_datetime(validation_x['Tidpunkt'])
date_time
# Out:
# 3923170   2022-03-24 04:45:00
# 3923171   2022-03-24 04:48:52
# 3923172   2022-03-24 04:52:03
# 3923173   2022-03-24 04:55:53
# 3923174   2022-03-24 04:47:04
#                   ...
# 3986489   2022-03-25 07:36:18
# 3986490   2022-03-25 07:42:28
# 3986491   2022-03-25 07:34:47
# 3986492   2022-03-25 07:37:28
# 3986493   2022-03-25 07:33:06
# Name: Tidpunkt, Length: 8618, dtype: datetime64[ns]

# %%
# Visualising the results      
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.autofmt_xdate(rotation=45)
ax.plot(date_time, validation_x['Prediction'])
ax.plot(date_time, validation_x['test_y'])
xftm = mdates.DateFormatter('%y-%m-%d %H:%M')
ax.xaxis.set_major_formatter(xftm)

ax.grid(True)

plt.title('Prediktion Antal passagerare 24-25 mars (Linje 40)')
plt.xlabel('Time')
plt.ylabel('Antal passagerare')
plt.legend(['Prediktion passagerare', 'Faktiska passagerare'])

# %%
# Visualising the results      
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.autofmt_xdate(rotation=45)
ax.plot(date_time, validation_x['Error'])
xftm = mdates.DateFormatter('%y-%m-%d %H:%M')
ax.xaxis.set_major_formatter(xftm)

ax.grid(True)

plt.title('ERROR Antal passagerare 24-25 mars (Linje 40)')
plt.xlabel('Time')
plt.ylabel('Antal passagerare')
plt.legend(['Uppskattat fel'])
