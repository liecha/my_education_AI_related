# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import matplotlib.dates as mdates
# %matplotlib inline

# %%
dataset_ATR = pd.read_csv('../../indata/ATR_203_20200101_20230115/ATR_203_20200101_20230115.csv', sep=',')
dataset_ATR.head()
# Out:
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_7000/1161598619.py:1: DtypeWarning: Columns (26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_ATR = pd.read_csv('../../indata/ATR_203_20200101_20230115/ATR_203_20200101_20230115.csv', sep=',')
#       Trafikföretag  Trafikföretagsnr  Linje  Estimated       Datum  \
# 0  Nobina Linköping              9205    203          1  2020-06-15
# 1  Nobina Linköping              9205    203          1  2020-06-15
# 2  Nobina Linköping              9205    203          1  2020-06-15
# 3  Nobina Linköping              9205    203          1  2020-06-15
# 4  Nobina Linköping              9205    203          1  2020-06-15
#
#               Tidpunkt Hållplatstid  Timme Halvtimme     Kvart  ...  \
# 0  2020-06-15 05:24:55        05:24    5.0  05:00:00  05:15:00  ...
# 1  2020-06-15 05:43:00        05:43    5.0  05:30:00  05:30:00  ...
# 2  2020-06-15 05:40:52        05:40    5.0  05:30:00  05:30:00  ...
# 3  2020-06-15 05:23:00        05:23    5.0  05:00:00  05:15:00  ...
# 4  2020-06-15 04:49:07        04:49    4.0  04:30:00  04:45:00  ...
#
#    Hållplatsläge      StopPointGID  Hållplatsnr  Omlopp Påstigande  \
# 0              A  9022005001243001         1243     503        1.0
# 1              A  9022005000219001          219     503        0.0
# 2              B  9022005001338002         1338     503        0.0
# 3             A5  9022005000050005           50     503        1.0
# 4              A  9022005001338001         1338     503        1.0
#
#    Avstigande  Ombord Passagerare sittande Beläggning  Beläggning turer
# 0         0.0     2.0          Okänt antal        NaN               NaN
# 1         0.0     0.0          Okänt antal        NaN               NaN
# 2         2.0     0.0          Okänt antal        NaN               NaN
# 3         0.0     1.0          Okänt antal        NaN               NaN
# 4         0.0     6.0          Okänt antal        NaN               NaN
#
# [5 rows x 28 columns]

# %%
dataset_ATR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407756 entries, 0 to 1407755
# Data columns (total 28 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Trafikföretag         1407756 non-null  object
#  1   Trafikföretagsnr      1407756 non-null  int64
#  2   Linje                 1407756 non-null  int64
#  3   Estimated             1407756 non-null  int64
#  4   Datum                 1407756 non-null  object
#  5   Tidpunkt              1394326 non-null  object
#  6   Hållplatstid          1394326 non-null  object
#  7   Timme                 1394326 non-null  float64
#  8   Halvtimme             1394326 non-null  object
#  9   Kvart                 1394326 non-null  object
#  10  SequenceInJourney     1407756 non-null  int64
#  11  Avg.tid               1407756 non-null  object
#  12  JourneyGID            1407756 non-null  int64
#  13  Turnr                 1407756 non-null  int64
#  14  Mot                   1407756 non-null  object
#  15  VehicleGID            1395710 non-null  float64
#  16  Fordon                318059 non-null   float64
#  17  Hållplatsnamn         1407756 non-null  object
#  18  Hållplatsläge         1407756 non-null  object
#  19  StopPointGID          1407756 non-null  int64
#  20  Hållplatsnr           1407756 non-null  int64
#  21  Omlopp                1407756 non-null  int64
#  22  Påstigande            1394326 non-null  float64
#  23  Avstigande            1394326 non-null  float64
#  24  Ombord                1394326 non-null  float64
#  25  Passagerare sittande  1407756 non-null  object
#  26  Beläggning            317930 non-null   object
#  27  Beläggning turer      317930 non-null   object
# dtypes: float64(6), int64(9), object(13)
# memory usage: 300.7+ MB

# %%
# Filtrera bort de parametrar som inte har relevans 
# Centrala parametrar: tur, linje, sträcka (hållplatser)
dataset_ATR_selection = dataset_ATR[['SequenceInJourney', 'JourneyGID', 'VehicleGID', 'Hållplatsnamn', 'Tidpunkt', 'Ombord', 'Påstigande', 'Avstigande' ]]
dataset_ATR_selection.head()
# Out:
#    SequenceInJourney        JourneyGID    VehicleGID            Hållplatsnamn  \
# 0                  2  9015005020300001  9.031006e+15               Kungsgatan
# 1                 14  9015005020300001  9.031006e+15  Rydsvägens ändhållplats
# 2                 12  9015005020300001  9.031006e+15           Alsättersgatan
# 3                  1  9015005020300001  9.031006e+15   Linköpings resecentrum
# 4                  3  9015005020300002  9.031006e+15           Alsättersgatan
#
#               Tidpunkt  Ombord  Påstigande  Avstigande
# 0  2020-06-15 05:24:55     2.0         1.0         0.0
# 1  2020-06-15 05:43:00     0.0         0.0         0.0
# 2  2020-06-15 05:40:52     0.0         0.0         2.0
# 3  2020-06-15 05:23:00     1.0         1.0         0.0
# 4  2020-06-15 04:49:07     6.0         1.0         0.0

# %%
dataset_ATR_selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407756 entries, 0 to 1407755
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   SequenceInJourney  1407756 non-null  int64
#  1   JourneyGID         1407756 non-null  int64
#  2   VehicleGID         1395710 non-null  float64
#  3   Hållplatsnamn      1407756 non-null  object
#  4   Tidpunkt           1394326 non-null  object
#  5   Ombord             1394326 non-null  float64
#  6   Påstigande         1394326 non-null  float64
#  7   Avstigande         1394326 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 85.9+ MB

# %%
# It looks like we have 1407756 - 1394326 = 12 430 rows of NaN values
((1407756 - 1394326)/1407756) * 100
# Out:
# 0.9540005512318896

# %%
dataset_ATR_selection = dataset_ATR_selection.dropna()
dataset_ATR_selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1394326 entries, 0 to 1407755
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   SequenceInJourney  1394326 non-null  int64
#  1   JourneyGID         1394326 non-null  int64
#  2   VehicleGID         1394326 non-null  float64
#  3   Hållplatsnamn      1394326 non-null  object
#  4   Tidpunkt           1394326 non-null  object
#  5   Ombord             1394326 non-null  float64
#  6   Påstigande         1394326 non-null  float64
#  7   Avstigande         1394326 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 95.7+ MB

# %%
# Få ut en lista på alla "JourneyGID"
dataset_ATR_selection_journeyGid = dataset_ATR_selection.groupby('JourneyGID').sum()
dataset_ATR_selection_journeyGid.head()
# Out:
#                   SequenceInJourney    VehicleGID   Ombord  Påstigande  \
# JourneyGID
# 9015005020300001              28563  3.450747e+19   7896.0      3014.0
# 9015005020300002              46131  5.585677e+19  48485.0      9642.0
# 9015005020300003              26825  3.703616e+19   9352.0      3541.0
# 9015005020300004              41082  5.211794e+19  38335.0      8137.0
# 9015005020300005              28046  3.617821e+19  11442.0      3626.0
#
#                   Avstigande
# JourneyGID
# 9015005020300001      3037.0
# 9015005020300002      9960.0
# 9015005020300003      3609.0
# 9015005020300004      8184.0
# 9015005020300005      3788.0

# %%
def plot_passengersOnboard(dataset, param, journeGID):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(dataset[param].values)
    ax.grid(True)

    title = 'Passagerare Ombord journeGID ' + str(journeGID)
    plt.title(title)
    #plt.xlabel(dataset['Tidpunkt'].values)
    plt.ylabel('Antal Passagerare')

# %%
# Hitta de index med maximal sekvens
index_max = dataset_ATR_selection[['SequenceInJourney']].idxmax()
max_sequence = int(dataset_ATR_selection.iloc[index_max]['SequenceInJourney'])
max_sequence
# Out:
# 14

# %%
# Hitta de index med minimal sekvens
index_min = dataset_ATR_selection[['SequenceInJourney']].idxmin()
min_sequence = int(dataset_ATR_selection.iloc[index_min]['SequenceInJourney'])
min_sequence
# Out:
# 1

# %%
# Filtrera på en JourneyGID - 9015005020300030
journeyGID = 9015005020300030
filter_journeyGID = dataset_ATR_selection['JourneyGID'] == journeyGID
data_filter_journeyGID = dataset_ATR_selection.loc[filter_journeyGID]
data_filter_journeyGID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7935 entries, 266 to 1405995
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SequenceInJourney  7935 non-null   int64
#  1   JourneyGID         7935 non-null   int64
#  2   VehicleGID         7935 non-null   float64
#  3   Hållplatsnamn      7935 non-null   object
#  4   Tidpunkt           7935 non-null   object
#  5   Ombord             7935 non-null   float64
#  6   Påstigande         7935 non-null   float64
#  7   Avstigande         7935 non-null   float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 557.9+ KB

# %%
data_journeyGID_sorted = data_filter_journeyGID.sort_values(by=['Tidpunkt'])
data_journeyGID_sorted.head()
# Out:
#      SequenceInJourney        JourneyGID    VehicleGID  \
# 272                  1  9015005020300030  9.031006e+15
# 269                  4  9015005020300030  9.031006e+15
# 273                  5  9015005020300030  9.031006e+15
# 270                  6  9015005020300030  9.031006e+15
# 266                  7  9015005020300030  9.031006e+15
#
#                Hållplatsnamn             Tidpunkt  Ombord  Påstigande  \
# 272  Rydsvägens ändhållplats  2020-06-15 09:36:36     3.0         3.0
# 269            Rydsvägen 236  2020-06-15 09:38:58     6.0         3.0
# 273           Mårdtorpsgatan  2020-06-15 09:41:04     8.0         2.0
# 270              Ryd centrum  2020-06-15 09:42:47    17.0         9.0
# 266                  Solhaga  2020-06-15 09:44:32    18.0         1.0
#
#      Avstigande
# 272         1.0
# 269         0.0
# 273         0.0
# 270         0.0
# 266         0.0

# %%
plot_passengersOnboard(data_journeyGID_sorted, 'Ombord', 9015005020300030)

# %%
# Adjustment 1 - inga avstigande vid startstation
for i, j in data_journeyGID_sorted.iterrows():
    if j.SequenceInJourney == min_sequence:
        data_journeyGID_sorted._set_value(i,'Avstigande', 0.0)
        data_journeyGID_sorted._set_value(i,'Ombord', j.Påstigande)

# %%
# Adjustment 2 - inga påstigande vid endstation
for i, j in data_journeyGID_sorted.iterrows():
    if j.SequenceInJourney == max_sequence:
        data_journeyGID_sorted._set_value(i,'Påstigande', 0.0)
        data_journeyGID_sorted._set_value(i,'Ombord', 0.0)
data_journeyGID_sorted.head()
# Out:
#      SequenceInJourney        JourneyGID    VehicleGID  \
# 272                  1  9015005020300030  9.031006e+15
# 269                  4  9015005020300030  9.031006e+15
# 273                  5  9015005020300030  9.031006e+15
# 270                  6  9015005020300030  9.031006e+15
# 266                  7  9015005020300030  9.031006e+15
#
#                Hållplatsnamn             Tidpunkt  Ombord  Påstigande  \
# 272  Rydsvägens ändhållplats  2020-06-15 09:36:36     3.0         3.0
# 269            Rydsvägen 236  2020-06-15 09:38:58     6.0         3.0
# 273           Mårdtorpsgatan  2020-06-15 09:41:04     8.0         2.0
# 270              Ryd centrum  2020-06-15 09:42:47    17.0         9.0
# 266                  Solhaga  2020-06-15 09:44:32    18.0         1.0
#
#      Avstigande
# 272         0.0
# 269         0.0
# 273         0.0
# 270         0.0
# 266         0.0

# %%
firstValue = data_journeyGID_sorted['Påstigande'].values[0]
firstValue
# Out:
# 3.0

# %%
onBoard_1 = []
onGoing = data_journeyGID_sorted['Påstigande'].values
offGoing = data_journeyGID_sorted['Avstigande'].values
for i in range(0, len(onGoing) - 1):
    if i == 0:
        print('--- first value ---')
        print(onGoing[i])
        newValue = onGoing[i]
        onBoard_1.append(newValue)
    else:
        print('--- new stop ---')  
        newValue = onGoing[i] - (offGoing[i])
        onBoard_1.append(newValue) 
        print(str(onBoard_1[i - 1]) + ' + ' + str(onGoing[i]) + ' - ' + str(offGoing[i]) + ' = ' + str(onBoard_1[i]))
# Out:
# --- first value ---
# 3.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_7000/2061020201.py in <module>
#      10     else:
#      11         #print('--- new stop ---')
# ---> 12         newValue = onGoing[i] - offGoing[i] + onBoard_1[i - 1]
#      13         if newValue < 0:
#      14             onBoard_1.append(0)
#
# IndexError: list index out of range

# %%
data_journeyGID_sorted['berOmbord'] = onBoard_1
data_journeyGID_sorted.head(25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_7000/538460756.py in <module>
# ----> 1 data_journeyGID_sorted['berOmbord'] = onBoard_1
#       2 data_journeyGID_sorted.head(25)
#
# ~\Anaconda3\envs\cuda_environment\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\Anaconda3\envs\cuda_environment\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\Anaconda3\envs\cuda_environment\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4527
#    4528         if is_list_like(value):
# -> 4529             com.require_length_match(value, self.index)
#    4530         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4531
#
# ~\Anaconda3\envs\cuda_environment\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (21) does not match length of index (7935)

# %%
# Adjustment 2 - inga påstigande vid endstation
for i, j in data_journeyGID_sorted.iterrows():
    if j.SequenceInJourney == max_sequence:
        data_journeyGID_sorted._set_value(i,'berOmbord', 0.0)
data_journeyGID_sorted.head(20)
# Out:
#       SequenceInJourney        JourneyGID    VehicleGID  \
# 272                   1  9015005020300030  9.031006e+15
# 269                   4  9015005020300030  9.031006e+15
# 273                   5  9015005020300030  9.031006e+15
# 270                   6  9015005020300030  9.031006e+15
# 266                   7  9015005020300030  9.031006e+15
# 267                   8  9015005020300030  9.031006e+15
# 274                  10  9015005020300030  9.031006e+15
# 268                  11  9015005020300030  9.031006e+15
# 275                  12  9015005020300030  9.031006e+15
# 276                  13  9015005020300030  9.031006e+15
# 271                  14  9015005020300030  9.031006e+15
# 1298                  1  9015005020300030  9.031006e+15
# 1294                  2  9015005020300030  9.031006e+15
# 1299                  3  9015005020300030  9.031006e+15
# 1297                  4  9015005020300030  9.031006e+15
# 1302                  6  9015005020300030  9.031006e+15
# 1303                  7  9015005020300030  9.031006e+15
# 1296                  8  9015005020300030  9.031006e+15
# 1295                  9  9015005020300030  9.031006e+15
# 1300                 11  9015005020300030  9.031006e+15
#
#                 Hållplatsnamn             Tidpunkt  Ombord  Påstigande  \
# 272   Rydsvägens ändhållplats  2020-06-15 09:36:36     3.0         3.0
# 269             Rydsvägen 236  2020-06-15 09:38:58     6.0         3.0
# 273            Mårdtorpsgatan  2020-06-15 09:41:04     8.0         2.0
# 270               Ryd centrum  2020-06-15 09:42:47    17.0         9.0
# 266                   Solhaga  2020-06-15 09:44:32    18.0         1.0
# 267           Gamla Linköping  2020-06-15 09:47:03    17.0         0.0
# 274                 Parkgatan  2020-06-15 09:49:17    18.0         1.0
# 268             Barnhemsgatan  2020-06-15 09:50:44    18.0         0.0
# 275           Trädgårdstorget  2020-06-15 09:54:45    10.0         2.0
# 276                Kungsgatan  2020-06-15 09:56:01     8.0         0.0
# 271    Linköpings resecentrum  2020-06-15 10:00:38     0.0         0.0
# 1298  Rydsvägens ändhållplats  2020-06-16 09:36:53     3.0         3.0
# 1294         Björnkärrsskolan  2020-06-16 09:37:42     4.0         1.0
# 1299           Alsättersgatan  2020-06-16 09:39:14     7.0         3.0
# 1297                 Hangaren  2020-06-16 09:40:13     9.0         2.0
# 1302              Ryd centrum  2020-06-16 09:42:54    14.0         7.0
# 1303                  Solhaga  2020-06-16 09:44:34    12.0         0.0
# 1296          Gamla Linköping  2020-06-16 09:47:03    12.0         0.0
# 1295                Vallaplan  2020-06-16 09:48:26    15.0         3.0
# 1300            Barnhemsgatan  2020-06-16 09:50:37    15.0         1.0
#
#       Avstigande  berOmbord
# 272          0.0        3.0
# 269          0.0        6.0
# 273          0.0        8.0
# 270          0.0       17.0
# 266          0.0       18.0
# 267          1.0       17.0
# 274          0.0       18.0
# 268          0.0       18.0
# 275         10.0       10.0
# 276          2.0        8.0
# 271          7.0        0.0
# 1298         0.0        4.0
# 1294         0.0        5.0
# 1299         0.0        8.0
# 1297         0.0       10.0
# 1302         2.0       15.0
# 1303         2.0       13.0
# 1296         0.0       13.0
# 1295         0.0       16.0
# 1300         1.0       16.0

# %%
# Adjustment 3 - inga på buss vid startposition
for i, j in data_journeyGID_sorted.iterrows():
    if j.SequenceInJourney == min_sequence:
        data_journeyGID_sorted._set_value(i,'berOmbord', j.Påstigande)
data_journeyGID_sorted.head(100)
# Out:
#        SequenceInJourney        JourneyGID    VehicleGID  \
# 272                    1  9015005020300030  9.031006e+15
# 269                    4  9015005020300030  9.031006e+15
# 273                    5  9015005020300030  9.031006e+15
# 270                    6  9015005020300030  9.031006e+15
# 266                    7  9015005020300030  9.031006e+15
# ...                  ...               ...           ...
# 10216                 12  9015005020300030  9.031006e+15
# 10211                 14  9015005020300030  9.031006e+15
# 12618                  1  9015005020300030  9.031006e+15
# 12623                  2  9015005020300030  9.031006e+15
# 12628                  4  9015005020300030  9.031006e+15
#
#                  Hållplatsnamn             Tidpunkt  Ombord  Påstigande  \
# 272    Rydsvägens ändhållplats  2020-06-15 09:36:36     3.0         3.0
# 269              Rydsvägen 236  2020-06-15 09:38:58     6.0         3.0
# 273             Mårdtorpsgatan  2020-06-15 09:41:04     8.0         2.0
# 270                Ryd centrum  2020-06-15 09:42:47    17.0         9.0
# 266                    Solhaga  2020-06-15 09:44:32    18.0         1.0
# ...                        ...                  ...     ...         ...
# 10216          Trädgårdstorget  2020-06-26 09:55:50    18.0         7.0
# 10211   Linköpings resecentrum  2020-06-26 10:03:06     0.0         0.0
# 12618  Rydsvägens ändhållplats  2020-06-29 09:36:34     3.0         3.0
# 12623         Björnkärrsskolan  2020-06-29 09:38:52     8.0         2.0
# 12628                 Hangaren  2020-06-29 09:40:09     9.0         1.0
#
#        Avstigande  berOmbord
# 272           0.0        3.0
# 269           0.0        6.0
# 273           0.0        8.0
# 270           0.0       17.0
# 266           0.0       18.0
# ...           ...        ...
# 10216         8.0       27.0
# 10211        14.0        0.0
# 12618         0.0        3.0
# 12623         0.0       18.0
# 12628         0.0       19.0
#
# [100 rows x 9 columns]

# %%
plot_passengersOnboard(data_journeyGID_sorted, 'berOmbord', 9015005020300030)

# %%
for i, j in data_journeyGID_sorted.iterrows():
    if j.berOmbord < 0:
        print(i, j)
        print()
# Out:
# 108064 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505670.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-09-18 07:57:46
# Ombord                               8.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                           -1.0
# Name: 108064, dtype: object
#
# 119171 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505678.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-09-25 07:54:35
# Ombord                               4.0
# Påstigande                           0.0
# Avstigande                          12.0
# berOmbord                           -2.0
# Name: 119171, dtype: object
#
# 119173 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505678.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-09-25 07:57:20
# Ombord                               1.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                           -5.0
# Name: 119173, dtype: object
#
# 125021 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-09-29 07:54:47
# Ombord                               9.0
# Påstigande                           0.0
# Avstigande                          11.0
# berOmbord                           -1.0
# Name: 125021, dtype: object
#
# 125022 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-09-29 07:57:09
# Ombord                               7.0
# Påstigande                           1.0
# Avstigande                           3.0
# berOmbord                           -3.0
# Name: 125022, dtype: object
#
# 126813 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505670.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-09-30 07:53:07
# Ombord                               8.0
# Påstigande                           1.0
# Avstigande                           6.0
# berOmbord                           -5.0
# Name: 126813, dtype: object
#
# 126814 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505670.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-09-30 07:54:40
# Ombord                               7.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                           -6.0
# Name: 126814, dtype: object
#
# 128611 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505674.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-01 07:38:26
# Ombord                              14.0
# Påstigande                           9.0
# Avstigande                           0.0
# berOmbord                           -1.0
# Name: 128611, dtype: object
#
# 128615 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505674.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-01 07:54:08
# Ombord                              11.0
# Påstigande                           0.0
# Avstigande                           7.0
# berOmbord                           -4.0
# Name: 128615, dtype: object
#
# 128607 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505674.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-01 07:55:55
# Ombord                               9.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                           -6.0
# Name: 128607, dtype: object
#
# 130447 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-02 07:57:26
# Ombord                              13.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                           -2.0
# Name: 130447, dtype: object
#
# 134475 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-05 07:38:52
# Ombord                              14.0
# Påstigande                          10.0
# Avstigande                           1.0
# berOmbord                           -3.0
# Name: 134475, dtype: object
#
# 134467 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-05 07:39:47
# Ombord                              16.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -1.0
# Name: 134467, dtype: object
#
# 134471 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-10-05 07:52:44
# Ombord                              13.0
# Påstigande                           0.0
# Avstigande                           4.0
# berOmbord                           -4.0
# Name: 134471, dtype: object
#
# 134472 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-05 07:54:49
# Ombord                               5.0
# Påstigande                           0.0
# Avstigande                           8.0
# berOmbord                          -12.0
# Name: 134472, dtype: object
#
# 136280 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505684.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-06 07:56:29
# Ombord                              10.0
# Påstigande                           0.0
# Avstigande                          16.0
# berOmbord                           -9.0
# Name: 136280, dtype: object
#
# 136281 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505684.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-06 07:57:56
# Ombord                               6.0
# Påstigande                           0.0
# Avstigande                           4.0
# berOmbord                          -13.0
# Name: 136281, dtype: object
#
# 138104 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505676.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-07 07:39:46
# Ombord                              14.0
# Påstigande                          11.0
# Avstigande                           0.0
# berOmbord                           -7.0
# Name: 138104, dtype: object
#
# 138094 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505676.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-07 07:41:01
# Ombord                              18.0
# Påstigande                           4.0
# Avstigande                           0.0
# berOmbord                           -3.0
# Name: 138094, dtype: object
#
# 138095 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505676.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-07 07:57:14
# Ombord                              15.0
# Påstigande                           0.0
# Avstigande                           7.0
# berOmbord                           -6.0
# Name: 138095, dtype: object
#
# 138105 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505676.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-07 07:58:50
# Ombord                              13.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                           -8.0
# Name: 138105, dtype: object
#
# 139909 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505684.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-08 07:38:28
# Ombord                              17.0
# Påstigande                           6.0
# Avstigande                           1.0
# berOmbord                           -7.0
# Name: 139909, dtype: object
#
# 139910 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505684.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-08 07:39:23
# Ombord                              20.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                           -4.0
# Name: 139910, dtype: object
#
# 139906 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505684.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-08 07:53:01
# Ombord                              16.0
# Påstigande                           0.0
# Avstigande                          12.0
# berOmbord                           -8.0
# Name: 139906, dtype: object
#
# 139908 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505684.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-08 07:55:02
# Ombord                              14.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                          -10.0
# Name: 139908, dtype: object
#
# 160543 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-21 07:39:16
# Ombord                               6.0
# Påstigande                           6.0
# Avstigande                           0.0
# berOmbord                           -9.0
# Name: 160543, dtype: object
#
# 160550 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-21 07:40:24
# Ombord                               8.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -7.0
# Name: 160550, dtype: object
#
# 160544 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2020-10-21 07:41:44
# Ombord                              12.0
# Påstigande                           4.0
# Avstigande                           0.0
# berOmbord                           -3.0
# Name: 160544, dtype: object
#
# 160553 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-21 07:56:39
# Ombord                               7.0
# Påstigande                           0.0
# Avstigande                          14.0
# berOmbord                           -8.0
# Name: 160553, dtype: object
#
# 160542 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-21 07:58:44
# Ombord                               6.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                           -9.0
# Name: 160542, dtype: object
#
# 162417 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505678.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-22 07:39:14
# Ombord                              10.0
# Påstigande                           8.0
# Avstigande                           0.0
# berOmbord                           -6.0
# Name: 162417, dtype: object
#
# 162418 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505678.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-22 07:40:07
# Ombord                              12.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -4.0
# Name: 162418, dtype: object
#
# 162410 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505678.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2020-10-22 07:41:14
# Ombord                              14.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -2.0
# Name: 162410, dtype: object
#
# 162420 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505678.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-22 07:55:14
# Ombord                               9.0
# Påstigande                           0.0
# Avstigande                           7.0
# berOmbord                           -7.0
# Name: 162420, dtype: object
#
# 164255 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-23 07:39:02
# Ombord                              13.0
# Påstigande                           8.0
# Avstigande                           0.0
# berOmbord                           -5.0
# Name: 164255, dtype: object
#
# 164261 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-23 07:39:47
# Ombord                              14.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                           -4.0
# Name: 164261, dtype: object
#
# 164257 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-23 07:53:51
# Ombord                               9.0
# Påstigande                           0.0
# Avstigande                          10.0
# berOmbord                           -9.0
# Name: 164257, dtype: object
#
# 164256 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-23 07:55:45
# Ombord                               7.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                          -11.0
# Name: 164256, dtype: object
#
# 168226 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-26 07:38:32
# Ombord                               2.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -19.0
# Name: 168226, dtype: object
#
# 168224 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-26 07:39:29
# Ombord                               5.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                          -16.0
# Name: 168224, dtype: object
#
# 168231 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2020-10-26 07:40:32
# Ombord                               7.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -14.0
# Name: 168231, dtype: object
#
# 168227 SequenceInJourney                      5
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Mårdtorpsgatan
# Tidpunkt             2020-10-26 07:42:18
# Ombord                               9.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -12.0
# Name: 168227, dtype: object
#
# 168223 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2020-10-26 07:43:37
# Ombord                              16.0
# Påstigande                           7.0
# Avstigande                           0.0
# berOmbord                           -5.0
# Name: 168223, dtype: object
#
# 168228 SequenceInJourney                      7
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                    Solhaga
# Tidpunkt             2020-10-26 07:45:22
# Ombord                              17.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                           -4.0
# Name: 168228, dtype: object
#
# 168225 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-10-26 07:51:11
# Ombord                              16.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                           -5.0
# Name: 168225, dtype: object
#
# 168233 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-26 07:52:58
# Ombord                               6.0
# Påstigande                           0.0
# Avstigande                          10.0
# berOmbord                          -15.0
# Name: 168233, dtype: object
#
# 168229 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-26 07:54:51
# Ombord                               3.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                          -18.0
# Name: 168229, dtype: object
#
# 169966 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-27 07:38:52
# Ombord                               3.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -18.0
# Name: 169966, dtype: object
#
# 169967 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-27 07:39:47
# Ombord                               5.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -16.0
# Name: 169967, dtype: object
#
# 169964 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2020-10-27 07:43:15
# Ombord                              15.0
# Påstigande                          10.0
# Avstigande                           0.0
# berOmbord                           -6.0
# Name: 169964, dtype: object
#
# 169965 SequenceInJourney                      7
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn                    Solhaga
# Tidpunkt             2020-10-27 07:45:05
# Ombord                              18.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                           -3.0
# Name: 169965, dtype: object
#
# 169962 SequenceInJourney                      8
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn            Gamla Linköping
# Tidpunkt             2020-10-27 07:47:33
# Ombord                              19.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                           -2.0
# Name: 169962, dtype: object
#
# 169958 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-10-27 07:50:11
# Ombord                              17.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                           -4.0
# Name: 169958, dtype: object
#
# 169959 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-27 07:52:08
# Ombord                               6.0
# Påstigande                           0.0
# Avstigande                          11.0
# berOmbord                          -15.0
# Name: 169959, dtype: object
#
# 169960 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-10-27 07:54:02
# Ombord                               5.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                          -16.0
# Name: 169960, dtype: object
#
# 171680 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-28 07:38:53
# Ombord                               7.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                          -15.0
# Name: 171680, dtype: object
#
# 171686 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-28 07:39:56
# Ombord                              10.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                          -12.0
# Name: 171686, dtype: object
#
# 171681 SequenceInJourney                      5
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Mårdtorpsgatan
# Tidpunkt             2020-10-28 07:42:26
# Ombord                              12.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -10.0
# Name: 171681, dtype: object
#
# 171679 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2020-10-28 07:43:54
# Ombord                              16.0
# Påstigande                           4.0
# Avstigande                           0.0
# berOmbord                           -6.0
# Name: 171679, dtype: object
#
# 171688 SequenceInJourney                      7
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                    Solhaga
# Tidpunkt             2020-10-28 07:45:48
# Ombord                              18.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -4.0
# Name: 171688, dtype: object
#
# 171685 SequenceInJourney                      8
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn            Gamla Linköping
# Tidpunkt             2020-10-28 07:48:34
# Ombord                              16.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                           -6.0
# Name: 171685, dtype: object
#
# 171683 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-10-28 07:52:12
# Ombord                              15.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                           -7.0
# Name: 171683, dtype: object
#
# 171684 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-28 07:53:53
# Ombord                               4.0
# Påstigande                           0.0
# Avstigande                          11.0
# berOmbord                          -18.0
# Name: 171684, dtype: object
#
# 173382 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-10-29 07:38:23
# Ombord                               4.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -18.0
# Name: 173382, dtype: object
#
# 173384 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-29 07:39:26
# Ombord                               5.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                          -17.0
# Name: 173384, dtype: object
#
# 173386 SequenceInJourney                      5
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn             Mårdtorpsgatan
# Tidpunkt             2020-10-29 07:41:44
# Ombord                               4.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                          -18.0
# Name: 173386, dtype: object
#
# 173383 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2020-10-29 07:43:01
# Ombord                               8.0
# Påstigande                           4.0
# Avstigande                           0.0
# berOmbord                          -14.0
# Name: 173383, dtype: object
#
# 173392 SequenceInJourney                      7
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn                    Solhaga
# Tidpunkt             2020-10-29 07:44:58
# Ombord                              11.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                          -11.0
# Name: 173392, dtype: object
#
# 173391 SequenceInJourney                      8
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn            Gamla Linköping
# Tidpunkt             2020-10-29 07:47:30
# Ombord                               9.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                          -13.0
# Name: 173391, dtype: object
#
# 173387 SequenceInJourney                     10
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn                  Parkgatan
# Tidpunkt             2020-10-29 07:49:53
# Ombord                               8.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                          -14.0
# Name: 173387, dtype: object
#
# 173389 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-10-29 07:52:03
# Ombord                               9.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                          -13.0
# Name: 173389, dtype: object
#
# 173390 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-29 07:55:05
# Ombord                               4.0
# Påstigande                           0.0
# Avstigande                           5.0
# berOmbord                          -18.0
# Name: 173390, dtype: object
#
# 175093 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505660.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-10-30 07:39:20
# Ombord                               6.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -18.0
# Name: 175093, dtype: object
#
# 175097 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505660.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2020-10-30 07:40:17
# Ombord                               7.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                          -17.0
# Name: 175097, dtype: object
#
# 175094 SequenceInJourney                      5
# JourneyGID              9015005020300030
# VehicleGID            9031005920505660.0
# Hållplatsnamn             Mårdtorpsgatan
# Tidpunkt             2020-10-30 07:41:56
# Ombord                               8.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                          -16.0
# Name: 175094, dtype: object
#
# 175091 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505660.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2020-10-30 07:43:09
# Ombord                              15.0
# Påstigande                           7.0
# Avstigande                           0.0
# berOmbord                           -9.0
# Name: 175091, dtype: object
#
# 175095 SequenceInJourney                      7
# JourneyGID              9015005020300030
# VehicleGID            9031005920505660.0
# Hållplatsnamn                    Solhaga
# Tidpunkt             2020-10-30 07:44:45
# Ombord                              15.0
# Påstigande                           1.0
# Avstigande                           1.0
# berOmbord                           -9.0
# Name: 175095, dtype: object
#
# 175089 SequenceInJourney                      8
# JourneyGID              9015005020300030
# VehicleGID            9031005920505660.0
# Hållplatsnamn            Gamla Linköping
# Tidpunkt             2020-10-30 07:47:06
# Ombord                              14.0
# Påstigande                           1.0
# Avstigande                           2.0
# berOmbord                          -10.0
# Name: 175089, dtype: object
#
# 175096 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505660.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-10-30 07:51:14
# Ombord                               5.0
# Påstigande                           0.0
# Avstigande                           9.0
# berOmbord                          -19.0
# Name: 175096, dtype: object
#
# 178845 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505668.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-11-02 07:53:11
# Ombord                              12.0
# Påstigande                           1.0
# Avstigande                           9.0
# berOmbord                           -6.0
# Name: 178845, dtype: object
#
# 178841 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505668.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-11-02 07:54:53
# Ombord                               9.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                           -9.0
# Name: 178841, dtype: object
#
# 180603 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-11-03 07:39:54
# Ombord                              10.0
# Påstigande                           6.0
# Avstigande                           0.0
# berOmbord                          -10.0
# Name: 180603, dtype: object
#
# 180594 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-11-03 07:41:14
# Ombord                              19.0
# Påstigande                           9.0
# Avstigande                           0.0
# berOmbord                           -1.0
# Name: 180594, dtype: object
#
# 180602 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-11-03 07:57:21
# Ombord                              16.0
# Påstigande                           1.0
# Avstigande                          18.0
# berOmbord                           -4.0
# Name: 180602, dtype: object
#
# 180600 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-11-03 07:59:18
# Ombord                              12.0
# Påstigande                           0.0
# Avstigande                           4.0
# berOmbord                           -8.0
# Name: 180600, dtype: object
#
# 182308 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-11-04 07:38:32
# Ombord                               9.0
# Påstigande                           6.0
# Avstigande                           0.0
# berOmbord                          -13.0
# Name: 182308, dtype: object
#
# 182310 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-11-04 07:39:34
# Ombord                              12.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                          -10.0
# Name: 182310, dtype: object
#
# 182301 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2020-11-04 07:40:45
# Ombord                              14.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -8.0
# Name: 182301, dtype: object
#
# 182309 SequenceInJourney                      5
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn             Mårdtorpsgatan
# Tidpunkt             2020-11-04 07:42:53
# Ombord                              15.0
# Påstigande                           3.0
# Avstigande                           2.0
# berOmbord                           -7.0
# Name: 182309, dtype: object
#
# 182304 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-11-04 07:54:53
# Ombord                              21.0
# Påstigande                           0.0
# Avstigande                          12.0
# berOmbord                           -1.0
# Name: 182304, dtype: object
#
# 182305 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-11-04 07:56:40
# Ombord                               8.0
# Påstigande                           0.0
# Avstigande                          13.0
# berOmbord                          -14.0
# Name: 182305, dtype: object
#
# 182303 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505652.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-11-04 07:59:03
# Ombord                               6.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                          -16.0
# Name: 182303, dtype: object
#
# 184047 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-11-05 07:39:28
# Ombord                              17.0
# Påstigande                          11.0
# Avstigande                           0.0
# berOmbord                           -5.0
# Name: 184047, dtype: object
#
# 184054 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-11-05 07:40:47
# Ombord                              20.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                           -2.0
# Name: 184054, dtype: object
#
# 184050 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-11-05 07:54:15
# Ombord                              15.0
# Påstigande                           0.0
# Avstigande                          14.0
# berOmbord                           -7.0
# Name: 184050, dtype: object
#
# 184053 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-11-05 07:56:02
# Ombord                               6.0
# Påstigande                           0.0
# Avstigande                           9.0
# berOmbord                          -16.0
# Name: 184053, dtype: object
#
# 184043 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505672.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-11-05 07:57:43
# Ombord                               3.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                          -19.0
# Name: 184043, dtype: object
#
# 185759 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505646.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-11-06 07:39:00
# Ombord                              13.0
# Påstigande                           6.0
# Avstigande                           0.0
# berOmbord                          -11.0
# Name: 185759, dtype: object
#
# 185760 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505646.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-11-06 07:40:05
# Ombord                              16.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                           -8.0
# Name: 185760, dtype: object
#
# 185753 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505646.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2020-11-06 07:41:18
# Ombord                              21.0
# Påstigande                           5.0
# Avstigande                           0.0
# berOmbord                           -3.0
# Name: 185753, dtype: object
#
# 185761 SequenceInJourney                     10
# JourneyGID              9015005020300030
# VehicleGID            9031005920505646.0
# Hållplatsnamn                  Parkgatan
# Tidpunkt             2020-11-06 07:52:27
# Ombord                              21.0
# Påstigande                           0.0
# Avstigande                          19.0
# berOmbord                           -3.0
# Name: 185761, dtype: object
#
# 185754 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505646.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-11-06 07:54:02
# Ombord                              19.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                           -5.0
# Name: 185754, dtype: object
#
# 185762 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505646.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-11-06 07:56:26
# Ombord                               3.0
# Påstigande                           0.0
# Avstigande                          16.0
# berOmbord                          -21.0
# Name: 185762, dtype: object
#
# 185763 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505646.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-11-06 07:58:19
# Ombord                               0.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                          -24.0
# Name: 185763, dtype: object
#
# 189456 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505682.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-11-09 07:38:26
# Ombord                               9.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                          -21.0
# Name: 189456, dtype: object
#
# 189450 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505682.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-11-09 07:39:16
# Ombord                              10.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                          -20.0
# Name: 189450, dtype: object
#
# 189448 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505682.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2020-11-09 07:43:15
# Ombord                              19.0
# Påstigande                           9.0
# Avstigande                           0.0
# berOmbord                          -11.0
# Name: 189448, dtype: object
#
# 189455 SequenceInJourney                      7
# JourneyGID              9015005020300030
# VehicleGID            9031005920505682.0
# Hållplatsnamn                    Solhaga
# Tidpunkt             2020-11-09 07:45:01
# Ombord                              20.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                          -10.0
# Name: 189455, dtype: object
#
# 189449 SequenceInJourney                      8
# JourneyGID              9015005020300030
# VehicleGID            9031005920505682.0
# Hållplatsnamn            Gamla Linköping
# Tidpunkt             2020-11-09 07:47:34
# Ombord                              19.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                          -11.0
# Name: 189449, dtype: object
#
# 189453 SequenceInJourney                     10
# JourneyGID              9015005020300030
# VehicleGID            9031005920505682.0
# Hållplatsnamn                  Parkgatan
# Tidpunkt             2020-11-09 07:50:03
# Ombord                               9.0
# Påstigande                           0.0
# Avstigande                          10.0
# berOmbord                          -21.0
# Name: 189453, dtype: object
#
# 189454 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505682.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2020-11-09 07:53:57
# Ombord                               4.0
# Påstigande                           0.0
# Avstigande                           5.0
# berOmbord                          -26.0
# Name: 189454, dtype: object
#
# 189447 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505682.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2020-11-09 07:55:47
# Ombord                               1.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                          -29.0
# Name: 189447, dtype: object
#
# 191143 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2020-11-10 07:38:31
# Ombord                              14.0
# Påstigande                          10.0
# Avstigande                           0.0
# berOmbord                          -16.0
# Name: 191143, dtype: object
#
# 191135 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2020-11-10 07:39:28
# Ombord                              16.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -14.0
# Name: 191135, dtype: object
#
# 191134 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2020-11-10 07:40:42
# Ombord                              22.0
# Påstigande                           6.0
# Avstigande                           0.0
# berOmbord                           -8.0
# Name: 191134, dtype: object
#
# 191144 SequenceInJourney                      5
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn             Mårdtorpsgatan
# Tidpunkt             2020-11-10 07:42:16
# Ombord                              26.0
# Påstigande                           4.0
# Avstigande                           0.0
# berOmbord                           -4.0
# Name: 191144, dtype: object
#
# 191133 SequenceInJourney                     10
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn                  Parkgatan
# Tidpunkt             2020-11-10 07:50:16
# Ombord                              27.0
# Påstigande                           1.0
# Avstigande                          19.0
# berOmbord                           -3.0
# Name: 191133, dtype: object
#
# 191138 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2020-11-10 07:52:22
# Ombord                              24.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                           -6.0
# Name: 191138, dtype: object
#
# 191137 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505648.0
# Hållplatsnamn               Stora Torget
# ...
# Avstigande                           5.0
# berOmbord                          -15.0
# Name: 1390626, dtype: object
#
# 1390629 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505698.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2023-01-03 07:55:45
# Ombord                               1.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                          -18.0
# Name: 1390629, dtype: object
#
# 1392465 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2023-01-04 07:42:14
# Ombord                               9.0
# Påstigande                           8.0
# Avstigande                           0.0
# berOmbord                          -10.0
# Name: 1392465, dtype: object
#
# 1392463 SequenceInJourney                      7
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                    Solhaga
# Tidpunkt             2023-01-04 07:44:04
# Ombord                              11.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -8.0
# Name: 1392463, dtype: object
#
# 1392466 SequenceInJourney                      8
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn            Gamla Linköping
# Tidpunkt             2023-01-04 07:46:34
# Ombord                              11.0
# Påstigande                           1.0
# Avstigande                           1.0
# berOmbord                           -8.0
# Name: 1392466, dtype: object
#
# 1392467 SequenceInJourney                      9
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                  Vallaplan
# Tidpunkt             2023-01-04 07:47:35
# Ombord                              12.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                           -7.0
# Name: 1392467, dtype: object
#
# 1392470 SequenceInJourney                     10
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                  Parkgatan
# Tidpunkt             2023-01-04 07:48:38
# Ombord                              12.0
# Påstigande                           1.0
# Avstigande                           1.0
# berOmbord                           -7.0
# Name: 1392470, dtype: object
#
# 1392468 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2023-01-04 07:52:39
# Ombord                               6.0
# Påstigande                           0.0
# Avstigande                           6.0
# berOmbord                          -13.0
# Name: 1392468, dtype: object
#
# 1392469 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2023-01-04 07:54:50
# Ombord                               5.0
# Påstigande                           0.0
# Avstigande                           1.0
# berOmbord                          -14.0
# Name: 1392469, dtype: object
#
# 1394298 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505698.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2023-01-05 07:39:56
# Ombord                               7.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                          -11.0
# Name: 1394298, dtype: object
#
# 1394301 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505698.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2023-01-05 07:40:54
# Ombord                               9.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -9.0
# Name: 1394301, dtype: object
#
# 1394302 SequenceInJourney                      5
# JourneyGID              9015005020300030
# VehicleGID            9031005920505698.0
# Hållplatsnamn             Mårdtorpsgatan
# Tidpunkt             2023-01-05 07:43:35
# Ombord                              10.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                           -8.0
# Name: 1394302, dtype: object
#
# 1394299 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505698.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2023-01-05 07:56:03
# Ombord                               8.0
# Påstigande                           0.0
# Avstigande                          13.0
# berOmbord                          -10.0
# Name: 1394299, dtype: object
#
# 1399828 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2023-01-09 07:44:12
# Ombord                              11.0
# Påstigande                           6.0
# Avstigande                           0.0
# berOmbord                           -7.0
# Name: 1399828, dtype: object
#
# 1399826 SequenceInJourney                      7
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn                    Solhaga
# Tidpunkt             2023-01-09 07:46:18
# Ombord                              14.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                           -4.0
# Name: 1399826, dtype: object
#
# 1399830 SequenceInJourney                      8
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn            Gamla Linköping
# Tidpunkt             2023-01-09 07:49:38
# Ombord                              15.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                           -3.0
# Name: 1399830, dtype: object
#
# 1399831 SequenceInJourney                      9
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn                  Vallaplan
# Tidpunkt             2023-01-09 07:51:33
# Ombord                              16.0
# Påstigande                           2.0
# Avstigande                           1.0
# berOmbord                           -2.0
# Name: 1399831, dtype: object
#
# 1399832 SequenceInJourney                     10
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn                  Parkgatan
# Tidpunkt             2023-01-09 07:52:36
# Ombord                              14.0
# Påstigande                           1.0
# Avstigande                           3.0
# berOmbord                           -4.0
# Name: 1399832, dtype: object
#
# 1399833 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2023-01-09 07:54:58
# Ombord                              10.0
# Påstigande                           0.0
# Avstigande                           4.0
# berOmbord                           -8.0
# Name: 1399833, dtype: object
#
# 1399827 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2023-01-09 07:57:34
# Ombord                               6.0
# Påstigande                           0.0
# Avstigande                           4.0
# berOmbord                          -12.0
# Name: 1399827, dtype: object
#
# 1399825 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505664.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2023-01-09 07:59:31
# Ombord                               4.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                          -14.0
# Name: 1399825, dtype: object
#
# 1401846 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2023-01-10 07:39:52
# Ombord                               9.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                          -10.0
# Name: 1401846, dtype: object
#
# 1401854 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2023-01-10 07:41:37
# Ombord                              10.0
# Påstigande                           1.0
# Avstigande                           0.0
# berOmbord                           -9.0
# Name: 1401854, dtype: object
#
# 1401845 SequenceInJourney                      6
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                Ryd centrum
# Tidpunkt             2023-01-10 07:44:29
# Ombord                              15.0
# Påstigande                           5.0
# Avstigande                           0.0
# berOmbord                           -4.0
# Name: 1401845, dtype: object
#
# 1401848 SequenceInJourney                      8
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn            Gamla Linköping
# Tidpunkt             2023-01-10 07:49:48
# Ombord                              15.0
# Påstigande                           0.0
# Avstigande                           5.0
# berOmbord                           -4.0
# Name: 1401848, dtype: object
#
# 1401852 SequenceInJourney                      9
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                  Vallaplan
# Tidpunkt             2023-01-10 07:51:39
# Ombord                              18.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                           -1.0
# Name: 1401852, dtype: object
#
# 1401849 SequenceInJourney                     10
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                  Parkgatan
# Tidpunkt             2023-01-10 07:52:46
# Ombord                              16.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                           -3.0
# Name: 1401849, dtype: object
#
# 1401850 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2023-01-10 07:55:25
# Ombord                              13.0
# Påstigande                           1.0
# Avstigande                           4.0
# berOmbord                           -6.0
# Name: 1401850, dtype: object
#
# 1401853 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2023-01-10 07:58:19
# Ombord                              10.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                           -9.0
# Name: 1401853, dtype: object
#
# 1401843 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2023-01-10 08:00:03
# Ombord                               8.0
# Påstigande                           0.0
# Avstigande                           2.0
# berOmbord                          -11.0
# Name: 1401843, dtype: object
#
# 1403917 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2023-01-11 07:38:46
# Ombord                               8.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -9.0
# Name: 1403917, dtype: object
#
# 1403918 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2023-01-11 07:39:58
# Ombord                              11.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                           -6.0
# Name: 1403918, dtype: object
#
# 1403910 SequenceInJourney                      4
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                   Hangaren
# Tidpunkt             2023-01-11 07:41:17
# Ombord                              14.0
# Påstigande                           3.0
# Avstigande                           0.0
# berOmbord                           -3.0
# Name: 1403910, dtype: object
#
# 1403914 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2023-01-11 07:56:42
# Ombord                              14.0
# Påstigande                           0.0
# Avstigande                           8.0
# berOmbord                           -3.0
# Name: 1403914, dtype: object
#
# 1403915 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2023-01-11 07:59:00
# Ombord                              11.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                           -6.0
# Name: 1403915, dtype: object
#
# 1405994 SequenceInJourney                      2
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn           Björnkärrsskolan
# Tidpunkt             2023-01-12 07:39:39
# Ombord                              16.0
# Påstigande                           7.0
# Avstigande                           4.0
# berOmbord                           -5.0
# Name: 1405994, dtype: object
#
# 1405993 SequenceInJourney                      3
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn             Alsättersgatan
# Tidpunkt             2023-01-12 07:40:31
# Ombord                              18.0
# Påstigande                           2.0
# Avstigande                           0.0
# berOmbord                           -3.0
# Name: 1405993, dtype: object
#
# 1405988 SequenceInJourney                     11
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn              Barnhemsgatan
# Tidpunkt             2023-01-12 07:53:23
# Ombord                              20.0
# Påstigande                           0.0
# Avstigande                          10.0
# berOmbord                           -1.0
# Name: 1405988, dtype: object
#
# 1405987 SequenceInJourney                     12
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn               Stora Torget
# Tidpunkt             2023-01-12 07:55:52
# Ombord                              12.0
# Påstigande                           0.0
# Avstigande                           8.0
# berOmbord                           -9.0
# Name: 1405987, dtype: object
#
# 1405985 SequenceInJourney                     13
# JourneyGID              9015005020300030
# VehicleGID            9031005920505662.0
# Hållplatsnamn                 Kungsgatan
# Tidpunkt             2023-01-12 07:58:07
# Ombord                               9.0
# Påstigande                           0.0
# Avstigande                           3.0
# berOmbord                          -12.0
# Name: 1405985, dtype: object

# %%
# Adjustment 2 - avstigande > ombord  --> avtigande == ombord
# ADjustment 3 - ombord > avstigande  --> ombord == avstigande
# Adjustment 3 - inga avstigande vid startstation
'''
for i, j in data_journeyGID_sorted.iterrows():
    if j.SequenceInJourney == max_sequence:
        data_journeyGID_sorted._set_value(i,'Påstigande', 0.0)
        if j.Avstigande > j.twisted_onBoard:
            data_journeyGID_sorted._set_value(i,'Avstigande', j.twisted_onBoard)
            #print(i, j)
            #print()
        if j.Avstigande < j.twisted_onBoard:
            data_journeyGID_sorted._set_value(i,'twisted_onBoard', j.Avstigande)
            #print(i, j)
            #print()
data_journeyGID_sorted.head(50)
'''
# Out:
# "\nfor i, j in data_journeyGID_sorted.iterrows():\n    if j.SequenceInJourney == max_sequence:\n        data_journeyGID_sorted._set_value(i,'Påstigande', 0.0)\n        if j.Avstigande > j.twisted_onBoard:\n            data_journeyGID_sorted._set_value(i,'Avstigande', j.twisted_onBoard)\n            #print(i, j)\n            #print()\n        if j.Avstigande < j.twisted_onBoard:\n            data_journeyGID_sorted._set_value(i,'twisted_onBoard', j.Avstigande)\n            #print(i, j)\n            #print()\ndata_journeyGID_sorted.head(50)\n"

# %%
'''
for i, j in data_journeyGID_sorted.iterrows():
    if -2 <= j.Ombord < 0:
        data_journeyGID_sorted._set_value(i,'Ombord', 0.0)
        #print(i, j)
        #print()
    if j.Ombord < -2:
        print(i, j)
        print()
'''
# Out:
# "\nfor i, j in data_journeyGID_sorted.iterrows():\n    if -2 <= j.Ombord < 0:\n        data_journeyGID_sorted._set_value(i,'Ombord', 0.0)\n        #print(i, j)\n        #print()\n    if j.Ombord < -2:\n        print(i, j)\n        print()\n"

# %%
'''
for i, j in data_journeyGID_sorted.iterrows():
    if j.SequenceInJourney == min_sequence:
        data_journeyGID_sorted._set_value(i,'Avstigande', 0.0)
        newValue = j.Påstigande
        data_journeyGID_sorted._set_value(i,'Ombord', newValue)
        #print(i, j)
        #print()
    if j.SequenceInJourney == max_sequence:
        data_journeyGID_sorted._set_value(i,'Ombord', 0.0)
        #print(i, j)
        #print()

data_journeyGID_sorted.head(50)
'''
# Out:
# "\nfor i, j in data_journeyGID_sorted.iterrows():\n    if j.SequenceInJourney == min_sequence:\n        data_journeyGID_sorted._set_value(i,'Avstigande', 0.0)\n        newValue = j.Påstigande\n        data_journeyGID_sorted._set_value(i,'Ombord', newValue)\n        #print(i, j)\n        #print()\n    if j.SequenceInJourney == max_sequence:\n        data_journeyGID_sorted._set_value(i,'Ombord', 0.0)\n        #print(i, j)\n        #print()\n\ndata_journeyGID_sorted.head(50)\n"

# %%
'''
78892    Rydsvägens ändhållplats
78898           Björnkärrsskolan
78888             Alsättersgatan
78895                   Hangaren
78889             Mårdtorpsgatan
78896                Ryd centrum
78887                    Solhaga
78897            Gamla Linköping
78890                  Vallaplan
78894                  Parkgatan
78891              Barnhemsgatan
78886               Stora Torget
78885                 Kungsgatan
78893     Linköpings resecentrum
'''
# Out:
# '\n78892    Rydsvägens ändhållplats\n78898           Björnkärrsskolan\n78888             Alsättersgatan\n78895                   Hangaren\n78889             Mårdtorpsgatan\n78896                Ryd centrum\n78887                    Solhaga\n78897            Gamla Linköping\n78890                  Vallaplan\n78894                  Parkgatan\n78891              Barnhemsgatan\n78886               Stora Torget\n78885                 Kungsgatan\n78893     Linköpings resecentrum\n'

# %%
data_ai = data_journeyGID_sorted['Ombord'].values.reshape(-1, 1)
data_ai
# Out:
# array([[ 3.],
#        [ 6.],
#        [ 8.],
#        ...,
#        [12.],
#        [ 9.],
#        [ 0.]])

# %%
# Scaling the training_set (use standardisation or normalization)
# Since our output signal is continous (sigmoid function)
# --> NORMALIZATION is recommended
from sklearn.preprocessing import StandardScaler

# Implement a scaler with value (range) between 0 and 1
scaler = StandardScaler()

# %%
# Apply scaler in training set
training_set_scaled = scaler.fit_transform(data_ai)
training_set_scaled
# Out:
# array([[-1.02776461],
#        [-0.86556062],
#        [-0.75742464],
#        ...,
#        [-0.54115266],
#        [-0.70335664],
#        [-1.18996859]])

# %%
# Convert series to supervised learning - input predicting pollution outputs
from pandas import concat

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# Frame as supervised learning
supervised_data = series_to_supervised(training_set_scaled, 1, 1)
supervised_data
# Out:
#       var1(t-1)   var1(t)
# 1     -1.027765 -0.865561
# 2     -0.865561 -0.757425
# 3     -0.757425 -0.270813
# 4     -0.270813 -0.216745
# 5     -0.216745 -0.270813
# ...         ...       ...
# 7887   0.756479  0.432071
# 7888   0.432071 -0.108609
# 7889  -0.108609 -0.541153
# 7890  -0.541153 -0.703357
# 7891  -0.703357 -1.189969
#
# [7891 rows x 2 columns]

# %%
7904*0.2
# Out:
# 1580.8000000000002

# %%
# 80% data for training and 20% data for test 
# Training --> 7904 * 0.8 = 6323
# Test --> 7904 - 6323 = 1580
supervised_values = supervised_data.values

# %%
n_train_time = round(len(supervised_values) * 0.8)
n_train_time
# Out:
# 6313

# %%
# Trainingset --> 20210101 to 20220206
train = supervised_values[:n_train_time, :]
len(train)
# Out:
# 6313

# %%
# Testing 20% --> 1 114 476 to 1 393 094
n_test_stop = len(supervised_values)
test = supervised_values[n_train_time:n_test_stop, :]
len(test)
# Out:
# 1578

# %%
# Split into input and outputs --> all values exept the last column is X, the last column is y
train_X, train_y = train[:, :-1], train[:, -1]
len(train_y)
# Out:
# 6313

# %%
# This is where it becomes different when we dont have any data to validate our result wiht
# Then we only have text_X
test_X, test_y = test[:, :-1], test[:, -1]
len(test_X)
# Out:
# 1578

# %%
# Reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (6313, 1, 1) (6313,) (1578, 1, 1) (1578,)

# %%
# Neural network
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
'''
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
'''
neurons = 50
# Initializing the RNN 
# The output is continous value --> use regression
regressor = Sequential()

# Add the first layer to the neural network
regressor.add(LSTM(units = neurons, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))

# Dropout regulation (use to be 20%)
# --> this is the number of neurons to be ignored
regressor.add(Dropout(0.2))

# Add more layers to the neural network
# Second layer
regressor.add(LSTM(units = neurons, return_sequences = True))
regressor.add(Dropout(0.2))

# Third layer
regressor.add(LSTM(units = neurons, return_sequences = True))
regressor.add(Dropout(0.2))

# Forth layer - last layer before output  layer
regressor.add(LSTM(units = neurons))
regressor.add(Dropout(0.2))

# Output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
# NOTE: Optimizer - RMSprops is recommended for RNN but Adam was detected to 
# be a better choice for this problem
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error') #mean_squared_error

# %%
# Training the network
history = regressor.fit(train_X, train_y, epochs=20, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/20
# 198/198 - 5s - loss: 0.3894 - val_loss: 0.3327 - 5s/epoch - 27ms/step
# Epoch 2/20
# 198/198 - 1s - loss: 0.2235 - val_loss: 0.3230 - 1s/epoch - 6ms/step
# Epoch 3/20
# 198/198 - 1s - loss: 0.2270 - val_loss: 0.3264 - 1s/epoch - 6ms/step
# Epoch 4/20
# 198/198 - 1s - loss: 0.2258 - val_loss: 0.3298 - 1s/epoch - 6ms/step
# Epoch 5/20
# 198/198 - 1s - loss: 0.2256 - val_loss: 0.3267 - 1s/epoch - 6ms/step
# Epoch 6/20
# 198/198 - 1s - loss: 0.2249 - val_loss: 0.3151 - 1s/epoch - 6ms/step
# Epoch 7/20
# 198/198 - 1s - loss: 0.2257 - val_loss: 0.3276 - 1s/epoch - 6ms/step
# Epoch 8/20
# 198/198 - 1s - loss: 0.2268 - val_loss: 0.3168 - 1s/epoch - 6ms/step
# Epoch 9/20
# 198/198 - 1s - loss: 0.2275 - val_loss: 0.3370 - 1s/epoch - 6ms/step
# Epoch 10/20
# 198/198 - 1s - loss: 0.2234 - val_loss: 0.3124 - 1s/epoch - 6ms/step
# Epoch 11/20
# 198/198 - 1s - loss: 0.2230 - val_loss: 0.3295 - 1s/epoch - 6ms/step
# Epoch 12/20
# 198/198 - 1s - loss: 0.2213 - val_loss: 0.3300 - 1s/epoch - 6ms/step
# Epoch 13/20
# 198/198 - 1s - loss: 0.2252 - val_loss: 0.3208 - 1s/epoch - 6ms/step
# Epoch 14/20
# 198/198 - 1s - loss: 0.2239 - val_loss: 0.3215 - 1s/epoch - 6ms/step
# Epoch 15/20
# 198/198 - 1s - loss: 0.2253 - val_loss: 0.3311 - 1s/epoch - 6ms/step
# Epoch 16/20
# 198/198 - 1s - loss: 0.2257 - val_loss: 0.3342 - 1s/epoch - 6ms/step
# Epoch 17/20
# 198/198 - 1s - loss: 0.2246 - val_loss: 0.3352 - 1s/epoch - 6ms/step
# Epoch 18/20
# 198/198 - 1s - loss: 0.2249 - val_loss: 0.3294 - 1s/epoch - 6ms/step
# Epoch 19/20
# 198/198 - 1s - loss: 0.2237 - val_loss: 0.3372 - 1s/epoch - 6ms/step
# Epoch 20/20
# 198/198 - 1s - loss: 0.2261 - val_loss: 0.3261 - 1s/epoch - 6ms/step

# %%
# Plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
y_prediction = regressor.predict(test_X)
y_prediction
# Out:
# array([[-0.42056882],
#        [-0.34053499],
#        [-0.2129474 ],
#        ...,
#        [-0.16864862],
#        [-0.49615568],
#        [-0.60104495]], dtype=float32)

# %%
y_prediction = y_prediction.reshape(-1,1)
y_prediction_retrans = scaler.inverse_transform(y_prediction).round()
y_prediction_retrans
# Out:
# array([[14.],
#        [16.],
#        [18.],
#        ...,
#        [19.],
#        [13.],
#        [11.]], dtype=float32)

# %%
test_y = test_y.reshape(-1,1)
test_y_retrans = scaler.inverse_transform(test_y).round()
test_y_retrans
# Out:
# array([[16.],
#        [19.],
#        [35.],
#        ...,
#        [12.],
#        [ 9.],
#        [ 0.]])

# %%
def plot_result_prediction(y_prediction, y_test):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(y_prediction_retrans, label='Predicted passengers')
    ax.plot((-1*test_y_retrans), label='Actual passengers')
    #ax.plot((y_prediction_retrans - test_y_retrans), label='Error')
    ax.grid(True)

    plt.title('Prediktion Antal Passagerare 2022-03-10 till 2022-03-25')
    plt.xlabel('Time')
    plt.ylabel('Antal passagerare')
    plt.legend(['Prediktion passagerare', 'Faktiska passagerare', 'Error'])

plot_result_prediction(y_prediction_retrans, test_y_retrans)
