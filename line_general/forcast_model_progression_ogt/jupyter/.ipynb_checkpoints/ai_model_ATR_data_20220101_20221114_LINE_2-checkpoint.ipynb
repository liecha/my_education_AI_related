# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import matplotlib.dates as mdates
# %matplotlib inline

# %%
dataset_ATR = pd.read_csv('../../indata/ATR_20220101_20221114.csv', sep=',')
dataset_ATR.head()
# Out:
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_3800/2678732647.py:1: DtypeWarning: Columns (24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_ATR = pd.read_csv('../../indata/ATR_20220101_20221114.csv', sep=',')
#          Trafikföretag  Trafikföretagsnr  Linje  Estimated  \
# 0  Transdev Norrköping              9003      2          1
# 1  Transdev Norrköping              9003      2          1
# 2  Transdev Norrköping              9003      2          1
# 3  Transdev Norrköping              9003      2          1
# 4  Transdev Norrköping              9003      2          1
#
#               Tidpunkt Hållplatstid  Timme Halvtimme     Kvart  \
# 0  2022-01-01 05:27:00        05:27    5.0  05:00:00  05:15:00
# 1  2022-01-01 05:30:42        05:30    5.0  05:30:00  05:30:00
# 2  2022-01-01 05:35:59        05:35    5.0  05:30:00  05:30:00
# 3  2022-01-01 05:39:59        05:39    5.0  05:30:00  05:30:00
# 4  2022-01-01 05:49:10        05:49    5.0  05:30:00  05:45:00
#
#    SequenceInJourney  ... Hållplatsnr  Omlopp Påstigande  Avstigande  Ombord  \
# 0                  7  ...           6     620        1.0         3.0     3.0
# 1                 10  ...           1     620        4.0         0.0     7.0
# 2                 13  ...        1019     620        1.0         1.0     7.0
# 3                 17  ...        1009     620        4.0         0.0    15.0
# 4                 21  ...        1129     620        2.0         0.0    17.0
#
#   Passagerare sittande Beläggning  Beläggning turer       Datum  \
# 0          Okänt antal        NaN               NaN  2022-01-01
# 1          Okänt antal        NaN               NaN  2022-01-01
# 2          Okänt antal        NaN               NaN  2022-01-01
# 3          Okänt antal        NaN               NaN  2022-01-01
# 4          Okänt antal        NaN               NaN  2022-01-01
#
#          JourneyGID
# 0  9015005000200701
# 1  9015005000200701
# 2  9015005000200701
# 3  9015005000200701
# 4  9015005000200701
#
# [5 rows x 28 columns]

# %%
dataset_ATR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000000 entries, 0 to 3999999
# Data columns (total 28 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Trafikföretag         object
#  1   Trafikföretagsnr      int64
#  2   Linje                 int64
#  3   Estimated             int64
#  4   Tidpunkt              object
#  5   Hållplatstid          object
#  6   Timme                 float64
#  7   Halvtimme             object
#  8   Kvart                 object
#  9   SequenceInJourney     int64
#  10  Avg.tid               object
#  11  Turnr                 int64
#  12  Mot                   object
#  13  VehicleGID            float64
#  14  Fordon                float64
#  15  Hållplatsnamn         object
#  16  Hållplatsläge         object
#  17  StopPointGID          int64
#  18  Hållplatsnr           int64
#  19  Omlopp                int64
#  20  Påstigande            float64
#  21  Avstigande            float64
#  22  Ombord                float64
#  23  Passagerare sittande  object
#  24  Beläggning            object
#  25  Beläggning turer      object
#  26  Datum                 object
#  27  JourneyGID            int64
# dtypes: float64(6), int64(9), object(13)
# memory usage: 854.5+ MB

# %%
# Filtrera bort de parametrar som inte har relevans 
dataset_ATR_selection = dataset_ATR[['Datum', 'Tidpunkt', 'Linje', 'Hållplatstid', 'Hållplatsnamn', 'Påstigande', 'Avstigande', 'Ombord']]
dataset_ATR_selection.head(30)
# Out:
#          Datum             Tidpunkt  Linje Hållplatstid  \
# 0   2022-01-01  2022-01-01 05:27:00      2        05:27
# 1   2022-01-01  2022-01-01 05:30:42      2        05:30
# 2   2022-01-01  2022-01-01 05:35:59      2        05:35
# 3   2022-01-01  2022-01-01 05:39:59      2        05:39
# 4   2022-01-01  2022-01-01 05:49:10      2        05:49
# 5   2022-01-01  2022-01-01 05:56:34      2        05:56
# 6   2022-01-01  2022-01-01 06:02:00      2        06:02
# 7   2022-01-01  2022-01-01 05:21:05      2        05:21
# 8   2022-01-01  2022-01-01 05:38:09      2        05:38
# 9   2022-01-01  2022-01-01 05:39:21      2        05:39
# 10  2022-01-01  2022-01-01 05:47:15      2        05:47
# 11  2022-01-01  2022-01-01 05:58:33      2        05:58
# 12  2022-01-01  2022-01-01 05:20:00      2        05:20
# 13  2022-01-01  2022-01-01 05:45:00      2        05:45
# 14  2022-01-01  2022-01-01 05:51:15      2        05:51
# 15  2022-01-01  2022-01-01 05:52:31      2        05:52
# 16  2022-01-01  2022-01-01 05:54:00      2        05:54
# 17  2022-01-01  2022-01-01 05:33:00      2        05:33
# 18  2022-01-01  2022-01-01 05:34:37      2        05:34
# 19  2022-01-01  2022-01-01 05:46:23      2        05:46
# 20  2022-01-01  2022-01-01 05:34:11      2        05:34
# 21  2022-01-01  2022-01-01 05:38:23      2        05:38
# 22  2022-01-01  2022-01-01 05:55:57      2        05:55
# 23  2022-01-01  2022-01-01 05:31:14      2        05:31
# 24  2022-01-01  2022-01-01 05:32:32      2        05:32
# 25  2022-01-01  2022-01-01 05:36:48      2        05:36
# 26  2022-01-01  2022-01-01 05:41:07      2        05:41
# 27  2022-01-01  2022-01-01 06:07:09      2        06:07
# 28  2022-01-01  2022-01-01 05:27:59      2        05:27
# 29  2022-01-01  2022-01-01 05:29:43      2        05:29
#
#               Hållplatsnamn  Påstigande  Avstigande  Ombord
# 0                Hagaskolan         1.0         3.0     3.0
# 1                 Norr Tull         4.0         0.0     7.0
# 2                Nya torget         1.0         1.0     7.0
# 3                Stortorget         4.0         0.0    15.0
# 4             Ljura Centrum         2.0         0.0    17.0
# 5               Atriumhusen         0.0         4.0    10.0
# 6               Kvarnberget         0.0         0.0     4.0
# 7          Heleneborgsgatan         1.0         0.0     5.0
# 8         Djäkneparksskolan         1.0         0.0     8.0
# 9              Centralbadet         3.0         0.0    11.0
# 10            Albrektsvägen         0.0         1.0    15.0
# 11      Ringdansens centrum         0.0         6.0     4.0
# 12                Fridvalla         4.0         0.0     4.0
# 13               Söder Tull         3.0         4.0    14.0
# 14     Vårdcentralen Hageby         0.0         2.0    15.0
# 15           Hageby centrum         1.0         4.0    12.0
# 16             Hyvlaregatan         2.0         0.0    14.0
# 17  Norrköpings resecentrum         2.0         0.0     9.0
# 18                 Rådhuset         0.0         2.0     7.0
# 19           Broocmans plan         3.0         1.0    16.0
# 20             Hyvlaregatan         2.0         8.0    19.0
# 21            Ljura Centrum         0.0         2.0    19.0
# 22  Norrköpings resecentrum         0.0         3.0     1.0
# 23              Atriumhusen         5.0         0.0    24.0
# 24          Trumpetaregatan         1.0         0.0    25.0
# 25     Vårdcentralen Hageby         8.0         8.0    21.0
# 26           Broocmans plan         2.0         2.0    19.0
# 27                Fridvalla         0.0         1.0    -4.0
# 28              Kvarnberget         0.0         0.0     0.0
# 29      Ringdansens centrum        19.0         0.0    19.0

# %%
dataset_ATR_selection = dataset_ATR_selection.dropna()
dataset_ATR_selection
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 0        2022-01-01  2022-01-01 05:27:00      2        05:27
# 1        2022-01-01  2022-01-01 05:30:42      2        05:30
# 2        2022-01-01  2022-01-01 05:35:59      2        05:35
# 3        2022-01-01  2022-01-01 05:39:59      2        05:39
# 4        2022-01-01  2022-01-01 05:49:10      2        05:49
# ...             ...                  ...    ...          ...
# 3999995  2022-03-25  2022-03-25 17:56:23    113        17:56
# 3999996  2022-03-25  2022-03-25 17:47:34    113        17:47
# 3999997  2022-03-25  2022-03-25 17:49:04    113        17:49
# 3999998  2022-03-25  2022-03-25 17:25:30    113        17:25
# 3999999  2022-03-25  2022-03-25 17:53:30    113        17:53
#
#             Hållplatsnamn  Påstigande  Avstigande  Ombord
# 0              Hagaskolan         1.0         3.0     3.0
# 1               Norr Tull         4.0         0.0     7.0
# 2              Nya torget         1.0         1.0     7.0
# 3              Stortorget         4.0         0.0    15.0
# 4           Ljura Centrum         2.0         0.0    17.0
# ...                   ...         ...         ...     ...
# 3999995   Blockstensgatan         0.0         3.0     1.0
# 3999996            Spiran         0.0         6.0    10.0
# 3999997        Söder Tull         0.0         3.0     7.0
# 3999998    Koppargatan 30         2.0         0.0     4.0
# 3999999  Kättsättersgatan         1.0         0.0     2.0
#
# [3035820 rows x 8 columns]

# %%
# Hitta de index med maximal belastning
dataset_ATR_selection[['Ombord']].idxmax()
# Out:
# Ombord    493927
# dtype: int64

# %%
dataset_ATR_selection['Linje'].iloc[493927]
# Out:
# 2

# %%
# Få ut en lista på alla "Linjer"
dataset_ATR_selection_linje = dataset_ATR_selection.groupby('Linje').mean()
dataset_ATR_selection_linje.info()

# 95 rader data som inte är NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 2 to 617
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Påstigande  79 non-null     float64
#  1   Avstigande  79 non-null     float64
#  2   Ombord      79 non-null     float64
# dtypes: float64(3)
# memory usage: 2.5 KB

# %%
# Få ut en lista på alla "Linjer"
dataset_ATR_selection_linje = dataset_ATR_selection.groupby('Linje').mean()
dataset_ATR_selection_linje
# Out:
#        Påstigande  Avstigande     Ombord
# Linje
# 2        2.284240    2.334001  16.553633
# 3        2.206089    2.248103  12.400501
# 40       1.780581    1.743186  10.434620
# 41       2.556905    2.519084  11.015267
# 42       1.712310    1.716459   9.371369
# ...           ...         ...        ...
# 530      1.584677    1.584677   9.637097
# 572      1.079937    1.106744   4.645390
# 577      1.319149    1.382979   4.773050
# 616      1.273077    1.300000   6.865385
# 617      1.546218    1.592437   8.739496
#
# [79 rows x 3 columns]

# %%
# Hitta de index med maximal belastning
index_max = dataset_ATR_selection_linje[['Ombord']].idxmax()

# %%
dataset_ATR_selection['Linje'].iloc[index_max]
# Out:
# 250    2
# Name: Linje, dtype: int64

# %%
lines_list = dataset_ATR_selection_linje.index.values.tolist()
lines_list
# Out:
# [2,
#  3,
#  40,
#  41,
#  42,
#  45,
#  46,
#  58,
#  59,
#  70,
#  71,
#  74,
#  75,
#  110,
#  111,
#  112,
#  113,
#  120,
#  121,
#  141,
#  201,
#  202,
#  203,
#  204,
#  205,
#  206,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  218,
#  220,
#  221,
#  222,
#  223,
#  226,
#  232,
#  241,
#  249,
#  250,
#  301,
#  302,
#  303,
#  304,
#  305,
#  308,
#  309,
#  310,
#  410,
#  412,
#  416,
#  429,
#  430,
#  432,
#  433,
#  440,
#  441,
#  444,
#  450,
#  452,
#  457,
#  459,
#  464,
#  480,
#  482,
#  483,
#  484,
#  486,
#  521,
#  522,
#  530,
#  572,
#  577,
#  616,
#  617]

# %%
# Gör en enklare analys av linje 40 då denna linje ser ut att ha ett högt medelvärde map överbelastning 
# (räknat att ett fordon tar 50 passagerare)

# Filtrera på en linje - 2
line = 2
filter_dataset_ATR_selection_line = dataset_ATR_selection['Linje'].values == line
dataset_ATR_selection_linje_line = dataset_ATR_selection.loc[filter_dataset_ATR_selection_line]
dataset_ATR_selection_linje_line.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331463 entries, 0 to 3986493
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Datum          331463 non-null  object
#  1   Tidpunkt       331463 non-null  object
#  2   Linje          331463 non-null  int64
#  3   Hållplatstid   331463 non-null  object
#  4   Hållplatsnamn  331463 non-null  object
#  5   Påstigande     331463 non-null  float64
#  6   Avstigande     331463 non-null  float64
#  7   Ombord         331463 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 22.8+ MB

# %%
dataset_ATR_selection_linje_line
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 0        2022-01-01  2022-01-01 05:27:00      2        05:27
# 1        2022-01-01  2022-01-01 05:30:42      2        05:30
# 2        2022-01-01  2022-01-01 05:35:59      2        05:35
# 3        2022-01-01  2022-01-01 05:39:59      2        05:39
# 4        2022-01-01  2022-01-01 05:49:10      2        05:49
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord
# 0                  Hagaskolan         1.0         3.0     3.0
# 1                   Norr Tull         4.0         0.0     7.0
# 2                  Nya torget         1.0         1.0     7.0
# 3                  Stortorget         4.0         0.0    15.0
# 4               Ljura Centrum         2.0         0.0    17.0
# ...                       ...         ...         ...     ...
# 3986489           Atriumhusen         4.0         0.0    25.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0
# 3986493           Kvarnberget        10.0         0.0    10.0
#
# [331463 rows x 8 columns]

# %%
firstValue = dataset_ATR_selection_linje_line['Ombord'].iloc[0]
firstValue
# Out:
# 3.0

# %%
testOmbord = []
testOmbord.append(firstValue)
testOmbord
# Out:
# [3.0]

# %%
onGoing = dataset_ATR_selection_linje_line['Påstigande'].values
onGoing
# Out:
# array([ 1.,  4.,  1., ..., 11.,  7., 10.])

# %%
offGoing = dataset_ATR_selection_linje_line['Avstigande'].values
offGoing
# Out:
# array([3., 0., 1., ..., 0., 1., 0.])

# %%
onBoard = dataset_ATR_selection_linje_line['Ombord'].values
onBoard
# Out:
# array([ 3.,  7.,  7., ..., 21., 31., 10.])

# %%
for i in range(0, len(onGoing) - 1):
    testOnBuss = testOmbord[i] + onGoing[i + 1] - offGoing[i + 1]
    if testOnBuss < 0:
        testOmbord.append(0)
    else:
        testOmbord.append(testOnBuss)
len(testOmbord)
# Out:
# 331463

# %%
dataset_ATR_selection_linje_line['TestOmbord'] = testOmbord
dataset_ATR_selection_linje_line.head(40)
# Out:
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_3800/613332633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_ATR_selection_linje_line['TestOmbord'] = testOmbord
#          Datum             Tidpunkt  Linje Hållplatstid  \
# 0   2022-01-01  2022-01-01 05:27:00      2        05:27
# 1   2022-01-01  2022-01-01 05:30:42      2        05:30
# 2   2022-01-01  2022-01-01 05:35:59      2        05:35
# 3   2022-01-01  2022-01-01 05:39:59      2        05:39
# 4   2022-01-01  2022-01-01 05:49:10      2        05:49
# 5   2022-01-01  2022-01-01 05:56:34      2        05:56
# 6   2022-01-01  2022-01-01 06:02:00      2        06:02
# 7   2022-01-01  2022-01-01 05:21:05      2        05:21
# 8   2022-01-01  2022-01-01 05:38:09      2        05:38
# 9   2022-01-01  2022-01-01 05:39:21      2        05:39
# 10  2022-01-01  2022-01-01 05:47:15      2        05:47
# 11  2022-01-01  2022-01-01 05:58:33      2        05:58
# 12  2022-01-01  2022-01-01 05:20:00      2        05:20
# 13  2022-01-01  2022-01-01 05:45:00      2        05:45
# 14  2022-01-01  2022-01-01 05:51:15      2        05:51
# 15  2022-01-01  2022-01-01 05:52:31      2        05:52
# 16  2022-01-01  2022-01-01 05:54:00      2        05:54
# 17  2022-01-01  2022-01-01 05:33:00      2        05:33
# 18  2022-01-01  2022-01-01 05:34:37      2        05:34
# 19  2022-01-01  2022-01-01 05:46:23      2        05:46
# 20  2022-01-01  2022-01-01 05:34:11      2        05:34
# 21  2022-01-01  2022-01-01 05:38:23      2        05:38
# 22  2022-01-01  2022-01-01 05:55:57      2        05:55
# 23  2022-01-01  2022-01-01 05:31:14      2        05:31
# 24  2022-01-01  2022-01-01 05:32:32      2        05:32
# 25  2022-01-01  2022-01-01 05:36:48      2        05:36
# 26  2022-01-01  2022-01-01 05:41:07      2        05:41
# 27  2022-01-01  2022-01-01 06:07:09      2        06:07
# 28  2022-01-01  2022-01-01 05:27:59      2        05:27
# 29  2022-01-01  2022-01-01 05:29:43      2        05:29
# 30  2022-01-01  2022-01-01 05:46:35      2        05:46
# 31  2022-01-01  2022-01-01 05:54:12      2        05:54
# 32  2022-01-01  2022-01-01 05:57:32      2        05:57
# 33  2022-01-01  2022-01-01 06:03:22      2        06:03
# 34  2022-01-01  2022-01-01 05:35:30      2        05:35
# 35  2022-01-01  2022-01-01 05:45:32      2        05:45
# 36  2022-01-01  2022-01-01 05:48:42      2        05:48
# 37  2022-01-01  2022-01-01 05:52:16      2        05:52
# 38  2022-01-01  2022-01-01 06:05:32      2        06:05
# 39  2022-01-01  2022-01-01 06:20:43      2        06:20
#
#               Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord
# 0                Hagaskolan         1.0         3.0     3.0         3.0
# 1                 Norr Tull         4.0         0.0     7.0         7.0
# 2                Nya torget         1.0         1.0     7.0         7.0
# 3                Stortorget         4.0         0.0    15.0        11.0
# 4             Ljura Centrum         2.0         0.0    17.0        13.0
# 5               Atriumhusen         0.0         4.0    10.0         9.0
# 6               Kvarnberget         0.0         0.0     4.0         9.0
# 7          Heleneborgsgatan         1.0         0.0     5.0        10.0
# 8         Djäkneparksskolan         1.0         0.0     8.0        11.0
# 9              Centralbadet         3.0         0.0    11.0        14.0
# 10            Albrektsvägen         0.0         1.0    15.0        13.0
# 11      Ringdansens centrum         0.0         6.0     4.0         7.0
# 12                Fridvalla         4.0         0.0     4.0        11.0
# 13               Söder Tull         3.0         4.0    14.0        10.0
# 14     Vårdcentralen Hageby         0.0         2.0    15.0         8.0
# 15           Hageby centrum         1.0         4.0    12.0         5.0
# 16             Hyvlaregatan         2.0         0.0    14.0         7.0
# 17  Norrköpings resecentrum         2.0         0.0     9.0         9.0
# 18                 Rådhuset         0.0         2.0     7.0         7.0
# 19           Broocmans plan         3.0         1.0    16.0         9.0
# 20             Hyvlaregatan         2.0         8.0    19.0         3.0
# 21            Ljura Centrum         0.0         2.0    19.0         1.0
# 22  Norrköpings resecentrum         0.0         3.0     1.0         0.0
# 23              Atriumhusen         5.0         0.0    24.0         5.0
# 24          Trumpetaregatan         1.0         0.0    25.0         6.0
# 25     Vårdcentralen Hageby         8.0         8.0    21.0         6.0
# 26           Broocmans plan         2.0         2.0    19.0         6.0
# 27                Fridvalla         0.0         1.0    -4.0         5.0
# 28              Kvarnberget         0.0         0.0     0.0         5.0
# 29      Ringdansens centrum        19.0         0.0    19.0        24.0
# 30               Stortorget         0.0         1.0     9.0        23.0
# 31                 Rådhuset         0.0         4.0     4.0        19.0
# 32                Norr Tull         1.0         4.0    -2.0        16.0
# 33             Slåttergatan         0.0         1.0    -3.0        15.0
# 34           Hageby centrum         4.0         2.0    21.0        17.0
# 35               Söder Tull         2.0        11.0    10.0         8.0
# 36             Centralbadet         0.0         1.0     8.0         7.0
# 37               Nya torget         1.0         1.0     8.0         7.0
# 38                Fridvalla         0.0         0.0     0.0         7.0
# 39                 Rådhuset         1.0         0.0    12.0         8.0

# %%
dataset_ATR_selection_linje_line['TestOmbordDiff'] = dataset_ATR_selection_linje_line['Ombord'] - dataset_ATR_selection_linje_line['TestOmbord'] 
dataset_ATR_selection_linje_line.head(40)
# Out:
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_3800/84016548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_ATR_selection_linje_line['TestOmbordDiff'] = dataset_ATR_selection_linje_line['Ombord'] - dataset_ATR_selection_linje_line['TestOmbord']
#          Datum             Tidpunkt  Linje Hållplatstid  \
# 0   2022-01-01  2022-01-01 05:27:00      2        05:27
# 1   2022-01-01  2022-01-01 05:30:42      2        05:30
# 2   2022-01-01  2022-01-01 05:35:59      2        05:35
# 3   2022-01-01  2022-01-01 05:39:59      2        05:39
# 4   2022-01-01  2022-01-01 05:49:10      2        05:49
# 5   2022-01-01  2022-01-01 05:56:34      2        05:56
# 6   2022-01-01  2022-01-01 06:02:00      2        06:02
# 7   2022-01-01  2022-01-01 05:21:05      2        05:21
# 8   2022-01-01  2022-01-01 05:38:09      2        05:38
# 9   2022-01-01  2022-01-01 05:39:21      2        05:39
# 10  2022-01-01  2022-01-01 05:47:15      2        05:47
# 11  2022-01-01  2022-01-01 05:58:33      2        05:58
# 12  2022-01-01  2022-01-01 05:20:00      2        05:20
# 13  2022-01-01  2022-01-01 05:45:00      2        05:45
# 14  2022-01-01  2022-01-01 05:51:15      2        05:51
# 15  2022-01-01  2022-01-01 05:52:31      2        05:52
# 16  2022-01-01  2022-01-01 05:54:00      2        05:54
# 17  2022-01-01  2022-01-01 05:33:00      2        05:33
# 18  2022-01-01  2022-01-01 05:34:37      2        05:34
# 19  2022-01-01  2022-01-01 05:46:23      2        05:46
# 20  2022-01-01  2022-01-01 05:34:11      2        05:34
# 21  2022-01-01  2022-01-01 05:38:23      2        05:38
# 22  2022-01-01  2022-01-01 05:55:57      2        05:55
# 23  2022-01-01  2022-01-01 05:31:14      2        05:31
# 24  2022-01-01  2022-01-01 05:32:32      2        05:32
# 25  2022-01-01  2022-01-01 05:36:48      2        05:36
# 26  2022-01-01  2022-01-01 05:41:07      2        05:41
# 27  2022-01-01  2022-01-01 06:07:09      2        06:07
# 28  2022-01-01  2022-01-01 05:27:59      2        05:27
# 29  2022-01-01  2022-01-01 05:29:43      2        05:29
# 30  2022-01-01  2022-01-01 05:46:35      2        05:46
# 31  2022-01-01  2022-01-01 05:54:12      2        05:54
# 32  2022-01-01  2022-01-01 05:57:32      2        05:57
# 33  2022-01-01  2022-01-01 06:03:22      2        06:03
# 34  2022-01-01  2022-01-01 05:35:30      2        05:35
# 35  2022-01-01  2022-01-01 05:45:32      2        05:45
# 36  2022-01-01  2022-01-01 05:48:42      2        05:48
# 37  2022-01-01  2022-01-01 05:52:16      2        05:52
# 38  2022-01-01  2022-01-01 06:05:32      2        06:05
# 39  2022-01-01  2022-01-01 06:20:43      2        06:20
#
#               Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 0                Hagaskolan         1.0         3.0     3.0         3.0
# 1                 Norr Tull         4.0         0.0     7.0         7.0
# 2                Nya torget         1.0         1.0     7.0         7.0
# 3                Stortorget         4.0         0.0    15.0        11.0
# 4             Ljura Centrum         2.0         0.0    17.0        13.0
# 5               Atriumhusen         0.0         4.0    10.0         9.0
# 6               Kvarnberget         0.0         0.0     4.0         9.0
# 7          Heleneborgsgatan         1.0         0.0     5.0        10.0
# 8         Djäkneparksskolan         1.0         0.0     8.0        11.0
# 9              Centralbadet         3.0         0.0    11.0        14.0
# 10            Albrektsvägen         0.0         1.0    15.0        13.0
# 11      Ringdansens centrum         0.0         6.0     4.0         7.0
# 12                Fridvalla         4.0         0.0     4.0        11.0
# 13               Söder Tull         3.0         4.0    14.0        10.0
# 14     Vårdcentralen Hageby         0.0         2.0    15.0         8.0
# 15           Hageby centrum         1.0         4.0    12.0         5.0
# 16             Hyvlaregatan         2.0         0.0    14.0         7.0
# 17  Norrköpings resecentrum         2.0         0.0     9.0         9.0
# 18                 Rådhuset         0.0         2.0     7.0         7.0
# 19           Broocmans plan         3.0         1.0    16.0         9.0
# 20             Hyvlaregatan         2.0         8.0    19.0         3.0
# 21            Ljura Centrum         0.0         2.0    19.0         1.0
# 22  Norrköpings resecentrum         0.0         3.0     1.0         0.0
# 23              Atriumhusen         5.0         0.0    24.0         5.0
# 24          Trumpetaregatan         1.0         0.0    25.0         6.0
# 25     Vårdcentralen Hageby         8.0         8.0    21.0         6.0
# 26           Broocmans plan         2.0         2.0    19.0         6.0
# 27                Fridvalla         0.0         1.0    -4.0         5.0
# 28              Kvarnberget         0.0         0.0     0.0         5.0
# 29      Ringdansens centrum        19.0         0.0    19.0        24.0
# 30               Stortorget         0.0         1.0     9.0        23.0
# 31                 Rådhuset         0.0         4.0     4.0        19.0
# 32                Norr Tull         1.0         4.0    -2.0        16.0
# 33             Slåttergatan         0.0         1.0    -3.0        15.0
# 34           Hageby centrum         4.0         2.0    21.0        17.0
# 35               Söder Tull         2.0        11.0    10.0         8.0
# 36             Centralbadet         0.0         1.0     8.0         7.0
# 37               Nya torget         1.0         1.0     8.0         7.0
# 38                Fridvalla         0.0         0.0     0.0         7.0
# 39                 Rådhuset         1.0         0.0    12.0         8.0
#
#     TestOmbordDiff
# 0              0.0
# 1              0.0
# 2              0.0
# 3              4.0
# 4              4.0
# 5              1.0
# 6             -5.0
# 7             -5.0
# 8             -3.0
# 9             -3.0
# 10             2.0
# 11            -3.0
# 12            -7.0
# 13             4.0
# 14             7.0
# 15             7.0
# 16             7.0
# 17             0.0
# 18             0.0
# 19             7.0
# 20            16.0
# 21            18.0
# 22             1.0
# 23            19.0
# 24            19.0
# 25            15.0
# 26            13.0
# 27            -9.0
# 28            -5.0
# 29            -5.0
# 30           -14.0
# 31           -15.0
# 32           -18.0
# 33           -18.0
# 34             4.0
# 35             2.0
# 36             1.0
# 37             1.0
# 38            -7.0
# 39             4.0

# %%
# Få ut en lista på alla datum --> 83 dagar --> relativt lite erfarenhet
dataset_ATR_selection_datum = dataset_ATR_selection_linje_line.groupby('Datum').mean()
dataset_ATR_selection_datum
# Out:
#             Linje  Påstigande  Avstigande     Ombord  TestOmbord  \
# Datum
# 2022-01-01    2.0    1.372311    1.442315   6.770434   11.480641
# 2022-01-02    2.0    1.622484    1.643373   8.496012   20.042157
# 2022-01-03    2.0    1.725458    1.717614  15.643927   61.512955
# 2022-01-04    2.0    1.707975    1.744747  11.357211   29.633954
# 2022-01-05    2.0    1.654524    1.676236  15.671894   27.460314
# ...           ...         ...         ...        ...         ...
# 2022-03-21    2.0    2.668833    2.707100  19.264741   34.485439
# 2022-03-22    2.0    2.792833    2.837261  20.978154   32.480854
# 2022-03-23    2.0    2.741367    2.765182  20.492736   40.463920
# 2022-03-24    2.0    2.732075    2.744340  21.942453   45.943868
# 2022-03-25    2.0    3.058703    3.117862  20.143444   44.828460
#
#             TestOmbordDiff
# Datum
# 2022-01-01       -4.710207
# 2022-01-02      -11.546145
# 2022-01-03      -45.869028
# 2022-01-04      -18.276743
# 2022-01-05      -11.788420
# ...                    ...
# 2022-03-21      -15.220698
# 2022-03-22      -11.502700
# 2022-03-23      -19.971184
# 2022-03-24      -24.001415
# 2022-03-25      -24.685016
#
# [84 rows x 6 columns]

# %%
# Hitta de index med maximal belastning
dataset_ATR_selection_linje_line[['Ombord']].idxmax()
# Out:
# Ombord    493927
# dtype: int64

# %%
def plot_passengersOnboard(dataset):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(dataset['TestOmbord'].values)
    ax.grid(True)

    plt.title('2022-03-08 Linje 2')
    #plt.xlabel(dataset['Tidpunkt'].values)
    plt.ylabel('Antal Passagerare')

plot_passengersOnboard(dataset_ATR_selection_linje_line)

# %%
# Select all values  less than 0 (all negative values) - how can this value be negative?
filter_dataset_negative_values = dataset_ATR_selection_linje_line['Ombord'].values <= -1
dataset_ATR_selection_negatives = dataset_ATR_selection_linje_line.loc[filter_dataset_negative_values]
dataset_ATR_selection_negatives
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid    Hållplatsnamn  \
# 27       2022-01-01  2022-01-01 06:07:09      2        06:07        Fridvalla
# 32       2022-01-01  2022-01-01 05:57:32      2        05:57        Norr Tull
# 33       2022-01-01  2022-01-01 06:03:22      2        06:03     Slåttergatan
# 88       2022-01-01  2022-01-01 07:10:15      2        07:10  Trumpetaregatan
# 89       2022-01-01  2022-01-01 07:13:35      2        07:13      Kvarnberget
# ...             ...                  ...    ...          ...              ...
# 3986447  2022-03-25  2022-03-26 02:33:52      2        02:33         Rådhuset
# 3986448  2022-03-25  2022-03-26 02:32:10      2        02:32    Hörsalsparken
# 3986451  2022-03-25  2022-03-26 02:45:37      2        02:45    De Geersgatan
# 3986456  2022-03-25  2022-03-26 02:49:31      2        02:49        Fridvalla
# 3986483  2022-03-25  2022-03-26 03:23:53      2        03:23     Slåttergatan
#
#          Påstigande  Avstigande  Ombord  TestOmbord  TestOmbordDiff
# 27              0.0         1.0    -4.0         5.0            -9.0
# 32              1.0         4.0    -2.0        16.0           -18.0
# 33              0.0         1.0    -3.0        15.0           -18.0
# 88              0.0         1.0    -1.0        11.0           -12.0
# 89              0.0         1.0    -2.0        10.0           -12.0
# ...             ...         ...     ...         ...             ...
# 3986447         0.0         1.0    -2.0        15.0           -17.0
# 3986448         0.0         0.0    -1.0        15.0           -16.0
# 3986451         0.0         4.0    -2.0         9.0           -11.0
# 3986456         0.0         0.0    -2.0         7.0            -9.0
# 3986483         0.0         1.0    -1.0        14.0           -15.0
#
# [17041 rows x 10 columns]

# %%
len(dataset_ATR_selection_negatives) / len(dataset_ATR_selection_linje_line)
# Out:
# 0.05141146975680543

# %%
# Select a day where negative values are presented and try to see why the value is negative
filter_dataset_negative_date = dataset_ATR_selection_linje_line['Datum'].values == '2022-01-01'
dataset_ATR_selection_negatives_date = dataset_ATR_selection_linje_line.loc[filter_dataset_negative_date]
dataset_ATR_selection_negatives_date.head(40)
# Out:
#          Datum             Tidpunkt  Linje Hållplatstid  \
# 0   2022-01-01  2022-01-01 05:27:00      2        05:27
# 1   2022-01-01  2022-01-01 05:30:42      2        05:30
# 2   2022-01-01  2022-01-01 05:35:59      2        05:35
# 3   2022-01-01  2022-01-01 05:39:59      2        05:39
# 4   2022-01-01  2022-01-01 05:49:10      2        05:49
# 5   2022-01-01  2022-01-01 05:56:34      2        05:56
# 6   2022-01-01  2022-01-01 06:02:00      2        06:02
# 7   2022-01-01  2022-01-01 05:21:05      2        05:21
# 8   2022-01-01  2022-01-01 05:38:09      2        05:38
# 9   2022-01-01  2022-01-01 05:39:21      2        05:39
# 10  2022-01-01  2022-01-01 05:47:15      2        05:47
# 11  2022-01-01  2022-01-01 05:58:33      2        05:58
# 12  2022-01-01  2022-01-01 05:20:00      2        05:20
# 13  2022-01-01  2022-01-01 05:45:00      2        05:45
# 14  2022-01-01  2022-01-01 05:51:15      2        05:51
# 15  2022-01-01  2022-01-01 05:52:31      2        05:52
# 16  2022-01-01  2022-01-01 05:54:00      2        05:54
# 17  2022-01-01  2022-01-01 05:33:00      2        05:33
# 18  2022-01-01  2022-01-01 05:34:37      2        05:34
# 19  2022-01-01  2022-01-01 05:46:23      2        05:46
# 20  2022-01-01  2022-01-01 05:34:11      2        05:34
# 21  2022-01-01  2022-01-01 05:38:23      2        05:38
# 22  2022-01-01  2022-01-01 05:55:57      2        05:55
# 23  2022-01-01  2022-01-01 05:31:14      2        05:31
# 24  2022-01-01  2022-01-01 05:32:32      2        05:32
# 25  2022-01-01  2022-01-01 05:36:48      2        05:36
# 26  2022-01-01  2022-01-01 05:41:07      2        05:41
# 27  2022-01-01  2022-01-01 06:07:09      2        06:07
# 28  2022-01-01  2022-01-01 05:27:59      2        05:27
# 29  2022-01-01  2022-01-01 05:29:43      2        05:29
# 30  2022-01-01  2022-01-01 05:46:35      2        05:46
# 31  2022-01-01  2022-01-01 05:54:12      2        05:54
# 32  2022-01-01  2022-01-01 05:57:32      2        05:57
# 33  2022-01-01  2022-01-01 06:03:22      2        06:03
# 34  2022-01-01  2022-01-01 05:35:30      2        05:35
# 35  2022-01-01  2022-01-01 05:45:32      2        05:45
# 36  2022-01-01  2022-01-01 05:48:42      2        05:48
# 37  2022-01-01  2022-01-01 05:52:16      2        05:52
# 38  2022-01-01  2022-01-01 06:05:32      2        06:05
# 39  2022-01-01  2022-01-01 06:20:43      2        06:20
#
#               Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 0                Hagaskolan         1.0         3.0     3.0         3.0
# 1                 Norr Tull         4.0         0.0     7.0         7.0
# 2                Nya torget         1.0         1.0     7.0         7.0
# 3                Stortorget         4.0         0.0    15.0        11.0
# 4             Ljura Centrum         2.0         0.0    17.0        13.0
# 5               Atriumhusen         0.0         4.0    10.0         9.0
# 6               Kvarnberget         0.0         0.0     4.0         9.0
# 7          Heleneborgsgatan         1.0         0.0     5.0        10.0
# 8         Djäkneparksskolan         1.0         0.0     8.0        11.0
# 9              Centralbadet         3.0         0.0    11.0        14.0
# 10            Albrektsvägen         0.0         1.0    15.0        13.0
# 11      Ringdansens centrum         0.0         6.0     4.0         7.0
# 12                Fridvalla         4.0         0.0     4.0        11.0
# 13               Söder Tull         3.0         4.0    14.0        10.0
# 14     Vårdcentralen Hageby         0.0         2.0    15.0         8.0
# 15           Hageby centrum         1.0         4.0    12.0         5.0
# 16             Hyvlaregatan         2.0         0.0    14.0         7.0
# 17  Norrköpings resecentrum         2.0         0.0     9.0         9.0
# 18                 Rådhuset         0.0         2.0     7.0         7.0
# 19           Broocmans plan         3.0         1.0    16.0         9.0
# 20             Hyvlaregatan         2.0         8.0    19.0         3.0
# 21            Ljura Centrum         0.0         2.0    19.0         1.0
# 22  Norrköpings resecentrum         0.0         3.0     1.0         0.0
# 23              Atriumhusen         5.0         0.0    24.0         5.0
# 24          Trumpetaregatan         1.0         0.0    25.0         6.0
# 25     Vårdcentralen Hageby         8.0         8.0    21.0         6.0
# 26           Broocmans plan         2.0         2.0    19.0         6.0
# 27                Fridvalla         0.0         1.0    -4.0         5.0
# 28              Kvarnberget         0.0         0.0     0.0         5.0
# 29      Ringdansens centrum        19.0         0.0    19.0        24.0
# 30               Stortorget         0.0         1.0     9.0        23.0
# 31                 Rådhuset         0.0         4.0     4.0        19.0
# 32                Norr Tull         1.0         4.0    -2.0        16.0
# 33             Slåttergatan         0.0         1.0    -3.0        15.0
# 34           Hageby centrum         4.0         2.0    21.0        17.0
# 35               Söder Tull         2.0        11.0    10.0         8.0
# 36             Centralbadet         0.0         1.0     8.0         7.0
# 37               Nya torget         1.0         1.0     8.0         7.0
# 38                Fridvalla         0.0         0.0     0.0         7.0
# 39                 Rådhuset         1.0         0.0    12.0         8.0
#
#     TestOmbordDiff
# 0              0.0
# 1              0.0
# 2              0.0
# 3              4.0
# 4              4.0
# 5              1.0
# 6             -5.0
# 7             -5.0
# 8             -3.0
# 9             -3.0
# 10             2.0
# 11            -3.0
# 12            -7.0
# 13             4.0
# 14             7.0
# 15             7.0
# 16             7.0
# 17             0.0
# 18             0.0
# 19             7.0
# 20            16.0
# 21            18.0
# 22             1.0
# 23            19.0
# 24            19.0
# 25            15.0
# 26            13.0
# 27            -9.0
# 28            -5.0
# 29            -5.0
# 30           -14.0
# 31           -15.0
# 32           -18.0
# 33           -18.0
# 34             4.0
# 35             2.0
# 36             1.0
# 37             1.0
# 38            -7.0
# 39             4.0

# %%
data_ai = dataset_ATR_selection_linje_line['TestOmbord'].values.reshape(-1, 1)
data_ai
# Out:
# array([[ 3.],
#        [ 7.],
#        [ 7.],
#        ...,
#        [49.],
#        [55.],
#        [65.]])

# %%
# Scaling the training_set (use standardisation or normalization)
# Since our output signal is continous (sigmoid function)
# --> NORMALIZATION is recommended
from sklearn.preprocessing import StandardScaler

# Implement a scaler with value (range) between 0 and 1
scaler = StandardScaler()

# %%
# Apply scaler in training set
training_set_scaled = scaler.fit_transform(data_ai)
training_set_scaled
# Out:
# array([[-1.18061243],
#        [-1.02642417],
#        [-1.02642417],
#        ...,
#        [ 0.59255254],
#        [ 0.82383493],
#        [ 1.20930558]])

# %%
# Convert series to supervised learning - input predicting pollution outputs
from pandas import concat

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# Frame as supervised learning
supervised_data = series_to_supervised(training_set_scaled, 1, 1)
supervised_data
# Out:
#         var1(t-1)   var1(t)
# 1       -1.180612 -1.026424
# 2       -1.026424 -1.026424
# 3       -1.026424 -0.872236
# 4       -0.872236 -0.795142
# 5       -0.795142 -0.949330
# ...           ...       ...
# 331458  -0.756595 -0.602406
# 331459  -0.602406  0.168535
# 331460   0.168535  0.592553
# 331461   0.592553  0.823835
# 331462   0.823835  1.209306
#
# [331462 rows x 2 columns]

# %%
# 80% data for training and 20% data for test 
# Training --> 12327 * 0.8 = 9862
# Test --> 12327 - 9861 = 2465
supervised_values = supervised_data.values

# %%
# 80% data for training and 20% data for test 
# Training --> 12327 * 0.8 = 9861
# Test --> 12327 - 9861 = 2466
n_train_time = round(len(supervised_values) * 0.8)
n_train_time
# Out:
# 265170

# %%
# Trainingset --> 20210101 to 20220206
train = supervised_values[:n_train_time, :]
len(train)
# Out:
# 265170

# %%
# Testing 20% --> 1 114 476 to 1 393 094
n_test_stop = len(supervised_values)
test = supervised_values[n_train_time:n_test_stop, :]
len(test)
# Out:
# 66292

# %%
# Split into input and outputs --> all values exept the last column is X, the last column is y
train_X, train_y = train[:, :-1], train[:, -1]
len(train_y)
# Out:
# 265170

# %%
# This is where it becomes different when we dont have any data to validate our result wiht
# Then we only have text_X
test_X, test_y = test[:, :-1], test[:, -1]
len(test_X)
# Out:
# 66292

# %%
# Reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (265170, 1, 1) (265170,) (66292, 1, 1) (66292,)

# %%
# Neural network
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
'''
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
'''
neurons = 50
# Initializing the RNN 
# The output is continous value --> use regression
regressor = Sequential()

# Add the first layer to the neural network
regressor.add(LSTM(units = neurons, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))

# Dropout regulation (use to be 20%)
# --> this is the number of neurons to be ignored
regressor.add(Dropout(0.2))

# Add more layers to the neural network
# Second layer
regressor.add(LSTM(units = neurons, return_sequences = True))
regressor.add(Dropout(0.2))

# Third layer
regressor.add(LSTM(units = neurons, return_sequences = True))
regressor.add(Dropout(0.2))

# Forth layer - last layer before output  layer
regressor.add(LSTM(units = neurons))
regressor.add(Dropout(0.2))

# Output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
# NOTE: Optimizer - RMSprops is recommended for RNN but Adam was detected to 
# be a better choice for this problem
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error') #mean_squared_error

# %%
# Training the network
history = regressor.fit(train_X, train_y, epochs=20, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/20
# 8287/8287 - 91s - loss: 0.0617 - val_loss: 0.0483 - 91s/epoch - 11ms/step
# Epoch 2/20
# 8287/8287 - 76s - loss: 0.0500 - val_loss: 0.0467 - 76s/epoch - 9ms/step
# Epoch 3/20
# 8287/8287 - 74s - loss: 0.0488 - val_loss: 0.0459 - 74s/epoch - 9ms/step
# Epoch 4/20
# 8287/8287 - 74s - loss: 0.0478 - val_loss: 0.0455 - 74s/epoch - 9ms/step
# Epoch 5/20
# 8287/8287 - 53s - loss: 0.0470 - val_loss: 0.0453 - 53s/epoch - 6ms/step
# Epoch 6/20
# 8287/8287 - 56s - loss: 0.0468 - val_loss: 0.0457 - 56s/epoch - 7ms/step
# Epoch 7/20
# 8287/8287 - 51s - loss: 0.0462 - val_loss: 0.0455 - 51s/epoch - 6ms/step
# Epoch 8/20
# 8287/8287 - 49s - loss: 0.0459 - val_loss: 0.0455 - 49s/epoch - 6ms/step
# Epoch 9/20
# 8287/8287 - 51s - loss: 0.0458 - val_loss: 0.0455 - 51s/epoch - 6ms/step
# Epoch 10/20
# 8287/8287 - 50s - loss: 0.0455 - val_loss: 0.0456 - 50s/epoch - 6ms/step
# Epoch 11/20
# 8287/8287 - 50s - loss: 0.0455 - val_loss: 0.0455 - 50s/epoch - 6ms/step
# Epoch 12/20
# 8287/8287 - 52s - loss: 0.0449 - val_loss: 0.0455 - 52s/epoch - 6ms/step
# Epoch 13/20
# 8287/8287 - 51s - loss: 0.0449 - val_loss: 0.0455 - 51s/epoch - 6ms/step
# Epoch 14/20
# 8287/8287 - 52s - loss: 0.0448 - val_loss: 0.0457 - 52s/epoch - 6ms/step
# Epoch 15/20
# 8287/8287 - 50s - loss: 0.0446 - val_loss: 0.0457 - 50s/epoch - 6ms/step
# Epoch 16/20
# 8287/8287 - 49s - loss: 0.0441 - val_loss: 0.0456 - 49s/epoch - 6ms/step
# Epoch 17/20
# 8287/8287 - 50s - loss: 0.0441 - val_loss: 0.0456 - 50s/epoch - 6ms/step
# Epoch 18/20
# 8287/8287 - 68s - loss: 0.0438 - val_loss: 0.0456 - 68s/epoch - 8ms/step
# Epoch 19/20
# 8287/8287 - 100s - loss: 0.0439 - val_loss: 0.0458 - 100s/epoch - 12ms/step
# Epoch 20/20
# 8287/8287 - 100s - loss: 0.0438 - val_loss: 0.0457 - 100s/epoch - 12ms/step

# %%
# Plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
y_prediction = regressor.predict(test_X)
y_prediction
# Out:
# array([[3.0671065 ],
#        [3.1365747 ],
#        [3.1018777 ],
#        ...,
#        [0.17971915],
#        [0.55677086],
#        [0.769538  ]], dtype=float32)

# %%
y_prediction = y_prediction.reshape(-1,1)
y_prediction_retrans = scaler.inverse_transform(y_prediction).round()
y_prediction_retrans
# Out:
# array([[113.],
#        [115.],
#        [114.],
#        ...,
#        [ 38.],
#        [ 48.],
#        [ 54.]], dtype=float32)

# %%
test_y = test_y.reshape(-1,1)
test_y_retrans = scaler.inverse_transform(test_y).round()
test_y_retrans
# Out:
# array([[118.],
#        [117.],
#        [118.],
#        ...,
#        [ 49.],
#        [ 55.],
#        [ 65.]])

# %%
def plot_result_prediction(y_prediction, y_test):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(y_prediction_retrans, label='Predicted passengers')
    ax.plot((-1*test_y_retrans), label='Actual passengers')
    #ax.plot((y_prediction_retrans - test_y_retrans), label='Error')
    ax.grid(True)

    plt.title('Prediktion Antal Passagerare 2022-10-01')
    plt.xlabel('Time')
    plt.ylabel('Antal passagerare')
    plt.legend(['Prediktion passagerare', 'Faktiska passagerare', 'Error'])

plot_result_prediction(y_prediction_retrans, test_y_retrans)

# %%
errorList = []
for i in range(0, len(y_prediction_retrans)):
    y_pred = y_prediction_retrans[i]
    y_test = test_y_retrans[i]
    if y_pred < 0:
        y_pred = -1*y_pred
    if y_test < 0:
        y_test = -1*y_test
    error = y_pred - y_test
    if error < 0:
        error = error *-1
    errorList.append(error)
errorList
# Out:
# [array([5.]),
#  array([2.]),
#  array([4.]),
#  array([6.]),
#  array([28.]),
#  array([9.]),
#  array([4.]),
#  array([3.]),
#  array([14.]),
#  array([4.]),
#  array([9.]),
#  array([4.]),
#  array([21.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([0.]),
#  array([3.]),
#  array([4.]),
#  array([2.]),
#  array([4.]),
#  array([8.]),
#  array([4.]),
#  array([3.]),
#  array([9.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([4.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([9.]),
#  array([4.]),
#  array([1.]),
#  array([10.]),
#  array([21.]),
#  array([7.]),
#  array([15.]),
#  array([8.]),
#  array([12.]),
#  array([5.]),
#  array([2.]),
#  array([27.]),
#  array([5.]),
#  array([8.]),
#  array([1.]),
#  array([2.]),
#  array([53.]),
#  array([2.]),
#  array([0.]),
#  array([5.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([5.]),
#  array([1.]),
#  array([7.]),
#  array([5.]),
#  array([0.]),
#  array([6.]),
#  array([0.]),
#  array([3.]),
#  array([6.]),
#  array([3.]),
#  array([1.]),
#  array([4.]),
#  array([8.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([6.]),
#  array([4.]),
#  array([9.]),
#  array([1.]),
#  array([15.]),
#  array([1.]),
#  array([5.]),
#  array([4.]),
#  array([7.]),
#  array([5.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([1.]),
#  array([11.]),
#  array([2.]),
#  array([30.]),
#  array([5.]),
#  array([50.]),
#  array([4.]),
#  array([11.]),
#  array([13.]),
#  array([4.]),
#  array([3.]),
#  array([4.]),
#  array([3.]),
#  array([16.]),
#  array([4.]),
#  array([5.]),
#  array([4.]),
#  array([0.]),
#  array([1.]),
#  array([11.]),
#  array([12.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([4.]),
#  array([3.]),
#  array([4.]),
#  array([10.]),
#  array([7.]),
#  array([2.]),
#  array([4.]),
#  array([1.]),
#  array([11.]),
#  array([12.]),
#  array([1.]),
#  array([4.]),
#  array([7.]),
#  array([6.]),
#  array([10.]),
#  array([22.]),
#  array([24.]),
#  array([4.]),
#  array([4.]),
#  array([1.]),
#  array([4.]),
#  array([7.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([22.]),
#  array([2.]),
#  array([3.]),
#  array([5.]),
#  array([9.]),
#  array([11.]),
#  array([9.]),
#  array([4.]),
#  array([0.]),
#  array([5.]),
#  array([1.]),
#  array([5.]),
#  array([0.]),
#  array([11.]),
#  array([14.]),
#  array([3.]),
#  array([1.]),
#  array([2.]),
#  array([6.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([2.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([6.]),
#  array([9.]),
#  array([3.]),
#  array([5.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([9.]),
#  array([1.]),
#  array([0.]),
#  array([30.]),
#  array([4.]),
#  array([4.]),
#  array([1.]),
#  array([19.]),
#  array([3.]),
#  array([2.]),
#  array([11.]),
#  array([0.]),
#  array([4.]),
#  array([5.]),
#  array([14.]),
#  array([3.]),
#  array([0.]),
#  array([6.]),
#  array([7.]),
#  array([14.]),
#  array([17.]),
#  array([0.]),
#  array([0.]),
#  array([5.]),
#  array([1.]),
#  array([12.]),
#  array([2.]),
#  array([6.]),
#  array([2.]),
#  array([6.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([6.]),
#  array([4.]),
#  array([3.]),
#  array([6.]),
#  array([2.]),
#  array([0.]),
#  array([1.]),
#  array([6.]),
#  array([2.]),
#  array([6.]),
#  array([7.]),
#  array([3.]),
#  array([1.]),
#  array([3.]),
#  array([12.]),
#  array([35.]),
#  array([3.]),
#  array([3.]),
#  array([5.]),
#  array([11.]),
#  array([5.]),
#  array([9.]),
#  array([18.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([16.]),
#  array([1.]),
#  array([2.]),
#  array([6.]),
#  array([2.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([9.]),
#  array([2.]),
#  array([5.]),
#  array([7.]),
#  array([0.]),
#  array([2.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([6.]),
#  array([1.]),
#  array([6.]),
#  array([2.]),
#  array([12.]),
#  array([18.]),
#  array([4.]),
#  array([3.]),
#  array([6.]),
#  array([11.]),
#  array([4.]),
#  array([9.]),
#  array([3.]),
#  array([0.]),
#  array([10.]),
#  array([11.]),
#  array([8.]),
#  array([13.]),
#  array([1.]),
#  array([0.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([12.]),
#  array([3.]),
#  array([2.]),
#  array([8.]),
#  array([10.]),
#  array([2.]),
#  array([2.]),
#  array([4.]),
#  array([4.]),
#  array([0.]),
#  array([10.]),
#  array([27.]),
#  array([5.]),
#  array([2.]),
#  array([8.]),
#  array([15.]),
#  array([10.]),
#  array([4.]),
#  array([0.]),
#  array([2.]),
#  array([0.]),
#  array([3.]),
#  array([6.]),
#  array([1.]),
#  array([13.]),
#  array([8.]),
#  array([4.]),
#  array([4.]),
#  array([5.]),
#  array([1.]),
#  array([7.]),
#  array([24.]),
#  array([3.]),
#  array([4.]),
#  array([0.]),
#  array([2.]),
#  array([5.]),
#  array([3.]),
#  array([19.]),
#  array([19.]),
#  array([2.]),
#  array([6.]),
#  array([9.]),
#  array([3.]),
#  array([2.]),
#  array([2.]),
#  array([5.]),
#  array([9.]),
#  array([5.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([5.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([6.]),
#  array([1.]),
#  array([2.]),
#  array([5.]),
#  array([1.]),
#  array([3.]),
#  array([7.]),
#  array([3.]),
#  array([8.]),
#  array([8.]),
#  array([3.]),
#  array([2.]),
#  array([3.]),
#  array([9.]),
#  array([2.]),
#  array([7.]),
#  array([3.]),
#  array([5.]),
#  array([5.]),
#  array([5.]),
#  array([10.]),
#  array([1.]),
#  array([20.]),
#  array([0.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([0.]),
#  array([33.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([12.]),
#  array([0.]),
#  array([11.]),
#  array([5.]),
#  array([6.]),
#  array([4.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([8.]),
#  array([0.]),
#  array([4.]),
#  array([3.]),
#  array([0.]),
#  array([8.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([6.]),
#  array([2.]),
#  array([1.]),
#  array([7.]),
#  array([7.]),
#  array([0.]),
#  array([1.]),
#  array([7.]),
#  array([11.]),
#  array([2.]),
#  array([4.]),
#  array([18.]),
#  array([7.]),
#  array([2.]),
#  array([1.]),
#  array([6.]),
#  array([14.]),
#  array([2.]),
#  array([4.]),
#  array([1.]),
#  array([0.]),
#  array([10.]),
#  array([1.]),
#  array([18.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([5.]),
#  array([0.]),
#  array([4.]),
#  array([5.]),
#  array([5.]),
#  array([2.]),
#  array([6.]),
#  array([5.]),
#  array([1.]),
#  array([24.]),
#  array([9.]),
#  array([0.]),
#  array([0.]),
#  array([5.]),
#  array([4.]),
#  array([4.]),
#  array([3.]),
#  array([5.]),
#  array([9.]),
#  array([12.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([25.]),
#  array([1.]),
#  array([1.]),
#  array([7.]),
#  array([4.]),
#  array([12.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([12.]),
#  array([1.]),
#  array([10.]),
#  array([0.]),
#  array([23.]),
#  array([12.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([16.]),
#  array([2.]),
#  array([8.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([12.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([3.]),
#  array([9.]),
#  array([0.]),
#  array([9.]),
#  array([4.]),
#  array([3.]),
#  array([2.]),
#  array([4.]),
#  array([7.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([5.]),
#  array([30.]),
#  array([9.]),
#  array([6.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([2.]),
#  array([1.]),
#  array([11.]),
#  array([3.]),
#  array([4.]),
#  array([8.]),
#  array([6.]),
#  array([10.]),
#  array([0.]),
#  array([3.]),
#  array([1.]),
#  array([2.]),
#  array([18.]),
#  array([6.]),
#  array([1.]),
#  array([7.]),
#  array([4.]),
#  array([2.]),
#  array([2.]),
#  array([7.]),
#  array([5.]),
#  array([2.]),
#  array([2.]),
#  array([4.]),
#  array([2.]),
#  array([3.]),
#  array([7.]),
#  array([14.]),
#  array([1.]),
#  array([2.]),
#  array([5.]),
#  array([8.]),
#  array([2.]),
#  array([0.]),
#  array([1.]),
#  array([8.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([3.]),
#  array([2.]),
#  array([5.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([12.]),
#  array([1.]),
#  array([2.]),
#  array([6.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([0.]),
#  array([3.]),
#  array([3.]),
#  array([6.]),
#  array([1.]),
#  array([4.]),
#  array([0.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([6.]),
#  array([3.]),
#  array([6.]),
#  array([5.]),
#  array([2.]),
#  array([4.]),
#  array([3.]),
#  array([5.]),
#  array([8.]),
#  array([2.]),
#  array([5.]),
#  array([4.]),
#  array([4.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([6.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([10.]),
#  array([5.]),
#  array([6.]),
#  array([3.]),
#  array([4.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([13.]),
#  array([6.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([5.]),
#  array([1.]),
#  array([4.]),
#  array([2.]),
#  array([3.]),
#  array([3.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([11.]),
#  array([2.]),
#  array([0.]),
#  array([5.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([2.]),
#  array([6.]),
#  array([10.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([3.]),
#  array([13.]),
#  array([4.]),
#  array([2.]),
#  array([1.]),
#  array([8.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([3.]),
#  array([4.]),
#  array([3.]),
#  array([3.]),
#  array([7.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([8.]),
#  array([0.]),
#  array([2.]),
#  array([4.]),
#  array([0.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([12.]),
#  array([7.]),
#  array([4.]),
#  array([7.]),
#  array([0.]),
#  array([0.]),
#  array([2.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([8.]),
#  array([5.]),
#  array([3.]),
#  array([1.]),
#  array([7.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([6.]),
#  array([3.]),
#  array([1.]),
#  array([4.]),
#  array([1.]),
#  array([0.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([0.]),
#  array([4.]),
#  array([4.]),
#  array([3.]),
#  array([10.]),
#  array([6.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([6.]),
#  array([2.]),
#  array([0.]),
#  array([1.]),
#  array([2.]),
#  array([9.]),
#  array([2.]),
#  array([9.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([5.]),
#  array([4.]),
#  array([12.]),
#  array([6.]),
#  array([2.]),
#  array([4.]),
#  array([4.]),
#  array([4.]),
#  array([11.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([4.]),
#  array([3.]),
#  array([2.]),
#  array([3.]),
#  array([3.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([7.]),
#  array([4.]),
#  array([1.]),
#  array([7.]),
#  array([13.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([6.]),
#  array([0.]),
#  array([5.]),
#  array([2.]),
#  array([3.]),
#  array([4.]),
#  array([1.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([9.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([3.]),
#  array([14.]),
#  array([1.]),
#  array([4.]),
#  array([3.]),
#  array([2.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([2.]),
#  array([7.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([5.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([10.]),
#  array([13.]),
#  array([20.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([12.]),
#  array([3.]),
#  array([3.]),
#  array([4.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([0.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([3.]),
#  array([0.]),
#  array([2.]),
#  array([1.]),
#  array([5.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([5.]),
#  array([4.]),
#  array([9.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([0.]),
#  array([3.]),
#  array([5.]),
#  array([1.]),
#  array([3.]),
#  array([5.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([5.]),
#  array([2.]),
#  array([9.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([8.]),
#  array([1.]),
#  array([6.]),
#  array([4.]),
#  array([3.]),
#  array([6.]),
#  array([2.]),
#  array([2.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([7.]),
#  array([3.]),
#  array([3.]),
#  array([1.]),
#  array([6.]),
#  array([6.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([7.]),
#  array([0.]),
#  array([5.]),
#  array([0.]),
#  array([7.]),
#  array([2.]),
#  array([3.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([5.]),
#  array([2.]),
#  array([1.]),
#  array([4.]),
#  array([19.]),
#  array([11.]),
#  array([4.]),
#  array([0.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([0.]),
#  array([2.]),
#  array([2.]),
#  array([6.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([3.]),
#  array([0.]),
#  array([2.]),
#  array([0.]),
#  array([4.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([2.]),
#  array([2.]),
#  array([0.]),
#  array([0.]),
#  array([0.]),
#  array([5.]),
#  array([2.]),
#  array([2.]),
#  array([4.]),
#  array([8.]),
#  array([3.]),
#  array([0.]),
#  array([4.]),
#  array([1.]),
#  array([1.]),
#  array([4.]),
#  array([2.]),
#  array([4.]),
#  array([7.]),
#  array([1.]),
#  array([0.]),
#  array([4.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([3.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([3.]),
#  array([5.]),
#  array([5.]),
#  array([1.]),
#  array([4.]),
#  array([1.]),
#  array([2.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([2.]),
#  array([5.]),
#  array([7.]),
#  array([1.]),
#  array([4.]),
#  array([13.]),
#  array([1.]),
#  array([1.]),
#  array([1.]),
#  array([5.]),
#  array([6.]),
#  array([0.]),
#  array([0.]),
#  array([1.]),
#  array([4.]),
#  array([4.]),
#  array([4.]),
#  array([2.]),
#  array([3.]),
#  array([6.]),
#  array([1.]),
#  array([5.]),
#  array([4.]),
#  array([0.]),
#  array([2.]),
#  array([4.]),
#  array([8.]),
#  array([2.]),
#  array([10.]),
#  array([2.]),
#  array([5.]),
#  array([2.]),
#  array([2.]),
#  array([3.]),
#  array([1.]),
#  array([0.]),
#  array([1.]),
#  array([6.]),
#  array([1.]),
#  array([18.]),
#  array([1.]),
#  array([5.]),
#  array([2.]),
#  array([3.]),
#  array([0.]),
#  array([1.]),
#  array([1.]),
#  ...]

# %%
# Visualising the results      
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.autofmt_xdate(rotation=45)
ax.plot(errorList, label='Error')
ax.grid(True)

plt.title('Felet i uppskattat antal passagerare')
plt.xlabel('Time')
plt.ylabel('Antal passagerare')
plt.legend(['Error'])

# %%
len(y_prediction)
# Out:
# 66292

# %%
# Pick out day 13 - 14 of november as test values
day_2022_03_24 = dataset_ATR_selection_linje_line[dataset_ATR_selection_linje_line['Datum'] == "2022-03-24"]
day_2022_03_25 = dataset_ATR_selection_linje_line[dataset_ATR_selection_linje_line['Datum'] == "2022-03-25"]
frames = [day_2022_03_24, 
          day_2022_03_25,
          ]
validation_x = pd.concat(frames)
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff
# 3923170           -78.0
# 3923171           -78.0
# 3923172           -78.0
# 3923173           -78.0
# 3923174           -77.0
# ...                 ...
# 3986489             7.0
# 3986490            25.0
# 3986491           -28.0
# 3986492           -24.0
# 3986493           -55.0
#
# [8618 rows x 10 columns]

# %%
last_values = len(y_prediction_retrans) - len(validation_x)
y_pred_03_24_to_03_25 = y_prediction_retrans[last_values:]
len(y_pred_03_24_to_03_25)
# Out:
# 8618

# %%
validation_x['Prediction'] = y_pred_03_24_to_03_25 * -1
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff  Prediction
# 3923170           -78.0       -77.0
# 3923171           -78.0       -77.0
# 3923172           -78.0       -77.0
# 3923173           -78.0       -76.0
# 3923174           -77.0       -76.0
# ...                 ...         ...
# 3986489             7.0       -15.0
# 3986490            25.0       -19.0
# 3986491           -28.0       -38.0
# 3986492           -24.0       -48.0
# 3986493           -55.0       -54.0
#
# [8618 rows x 11 columns]

# %%
test_y_03_24_to_03_25 = test_y_retrans[last_values:]
len(test_y_03_24_to_03_25)
# Out:
# 8618

# %%
validation_x['test_y'] = test_y_03_24_to_03_25
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff  Prediction  test_y
# 3923170           -78.0       -77.0    78.0
# 3923171           -78.0       -77.0    78.0
# 3923172           -78.0       -77.0    77.0
# 3923173           -78.0       -76.0    77.0
# 3923174           -77.0       -76.0    77.0
# ...                 ...         ...     ...
# 3986489             7.0       -15.0    18.0
# 3986490            25.0       -19.0    38.0
# 3986491           -28.0       -38.0    49.0
# 3986492           -24.0       -48.0    55.0
# 3986493           -55.0       -54.0    65.0
#
# [8618 rows x 12 columns]

# %%
validation_x['Error'] = (-1* validation_x['Prediction']) - validation_x['test_y']
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff  Prediction  test_y  Error
# 3923170           -78.0       -77.0    78.0   -1.0
# 3923171           -78.0       -77.0    78.0   -1.0
# 3923172           -78.0       -77.0    77.0    0.0
# 3923173           -78.0       -76.0    77.0   -1.0
# 3923174           -77.0       -76.0    77.0   -1.0
# ...                 ...         ...     ...    ...
# 3986489             7.0       -15.0    18.0   -3.0
# 3986490            25.0       -19.0    38.0  -19.0
# 3986491           -28.0       -38.0    49.0  -11.0
# 3986492           -24.0       -48.0    55.0   -7.0
# 3986493           -55.0       -54.0    65.0  -11.0
#
# [8618 rows x 13 columns]

# %%
validation_x.round(decimals = 1)
validation_x
# Out:
#               Datum             Tidpunkt  Linje Hållplatstid  \
# 3923170  2022-03-24  2022-03-24 04:45:00      2        04:45
# 3923171  2022-03-24  2022-03-24 04:48:52      2        04:48
# 3923172  2022-03-24  2022-03-24 04:52:03      2        04:52
# 3923173  2022-03-24  2022-03-24 04:55:53      2        04:55
# 3923174  2022-03-24  2022-03-24 04:47:04      2        04:47
# ...             ...                  ...    ...          ...
# 3986489  2022-03-25  2022-03-25 07:36:18      2        07:36
# 3986490  2022-03-25  2022-03-25 07:42:28      2        07:42
# 3986491  2022-03-25  2022-03-25 07:34:47      2        07:34
# 3986492  2022-03-25  2022-03-25 07:37:28      2        07:37
# 3986493  2022-03-25  2022-03-25 07:33:06      2        07:33
#
#                 Hållplatsnamn  Påstigande  Avstigande  Ombord  TestOmbord  \
# 3923170            Söder Tull         0.0         0.0     0.0        78.0
# 3923171         Ljura Centrum         0.0         0.0     0.0        78.0
# 3923172        Hageby centrum         0.0         1.0    -1.0        77.0
# 3923173           Atriumhusen         0.0         0.0    -1.0        77.0
# 3923174         Albrektsvägen         0.0         0.0     0.0        77.0
# ...                       ...         ...         ...     ...         ...
# 3986489           Atriumhusen         4.0         0.0    25.0        18.0
# 3986490  Vårdcentralen Hageby        21.0         1.0    63.0        38.0
# 3986491   Ringdansens centrum        11.0         0.0    21.0        49.0
# 3986492       Trumpetaregatan         7.0         1.0    31.0        55.0
# 3986493           Kvarnberget        10.0         0.0    10.0        65.0
#
#          TestOmbordDiff  Prediction  test_y  Error
# 3923170           -78.0       -77.0    78.0   -1.0
# 3923171           -78.0       -77.0    78.0   -1.0
# 3923172           -78.0       -77.0    77.0    0.0
# 3923173           -78.0       -76.0    77.0   -1.0
# 3923174           -77.0       -76.0    77.0   -1.0
# ...                 ...         ...     ...    ...
# 3986489             7.0       -15.0    18.0   -3.0
# 3986490            25.0       -19.0    38.0  -19.0
# 3986491           -28.0       -38.0    49.0  -11.0
# 3986492           -24.0       -48.0    55.0   -7.0
# 3986493           -55.0       -54.0    65.0  -11.0
#
# [8618 rows x 13 columns]

# %%
date_time = pd.to_datetime(validation_x['Tidpunkt'])
date_time
# Out:
# 3923170   2022-03-24 04:45:00
# 3923171   2022-03-24 04:48:52
# 3923172   2022-03-24 04:52:03
# 3923173   2022-03-24 04:55:53
# 3923174   2022-03-24 04:47:04
#                   ...
# 3986489   2022-03-25 07:36:18
# 3986490   2022-03-25 07:42:28
# 3986491   2022-03-25 07:34:47
# 3986492   2022-03-25 07:37:28
# 3986493   2022-03-25 07:33:06
# Name: Tidpunkt, Length: 8618, dtype: datetime64[ns]

# %%
# Visualising the results      
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.autofmt_xdate(rotation=45)
ax.plot(date_time, validation_x['Prediction'])
ax.plot(date_time, validation_x['test_y'])
xftm = mdates.DateFormatter('%y-%m-%d %H:%M')
ax.xaxis.set_major_formatter(xftm)

ax.grid(True)

plt.title('Prediktion Antal passagerare 24-25 mars (Linje 40)')
plt.xlabel('Time')
plt.ylabel('Antal passagerare')
plt.legend(['Prediktion passagerare', 'Faktiska passagerare'])

# %%
# Visualising the results      
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.autofmt_xdate(rotation=45)
ax.plot(date_time, validation_x['Error'])
xftm = mdates.DateFormatter('%y-%m-%d %H:%M')
ax.xaxis.set_major_formatter(xftm)

ax.grid(True)

plt.title('ERROR Antal passagerare 24-25 mars (Linje 40)')
plt.xlabel('Time')
plt.ylabel('Antal passagerare')
plt.legend(['Uppskattat fel'])
