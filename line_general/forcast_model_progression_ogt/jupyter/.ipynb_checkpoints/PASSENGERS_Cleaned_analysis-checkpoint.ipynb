# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import concat
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import matplotlib.dates as mdates
# %matplotlib inline

# %%
dataset_calls = pd.read_csv('../../indata/2022-10/2022-10-Calls.csv', sep=';')
dataset_calls.head()
# Out:
#   OperatingCalendarDay  UsesPlannedBlockId  UsesPlannedJourneyId  \
# 0  2022-10-01 00:00:00            350085.0              339564.0
# 1  2022-10-01 00:00:00            350085.0              339564.0
# 2  2022-10-01 00:00:00            350085.0              339564.0
# 3  2022-10-01 00:00:00            350085.0              339564.0
# 4  2022-10-01 00:00:00            350085.0              339564.0
#
#    VehicleIdentity  SequenceInJourney  UsesStopPointId   PlannedArrivalTime  \
# 0             -1.0                1.0           6462.0                  NaN
# 1             -1.0                2.0           8456.0                  NaN
# 2             -1.0                3.0           6336.0  2022-10-02 00:20:00
# 3             -1.0                4.0           6080.0                  NaN
# 4             -1.0                5.0          10606.0                  NaN
#
#   PlannedDepartureTime  IsTimingPoint ActualArrivalTime ActualDepartureTime  \
# ...

# %%
# Filtrera bort de parametrar som inte har relevans 
dataset_calls_clean = dataset_calls[['OperatingCalendarDay', 'UsesPlannedBlockId', 'UsesPlannedJourneyId', 'UsesStopPointId', 'Id', 'UsesDestinationDisplayId']]
dataset_calls_clean
# Out:
#         OperatingCalendarDay  UsesPlannedBlockId  UsesPlannedJourneyId  \
# 0        2022-10-01 00:00:00            350085.0              339564.0
# 1        2022-10-01 00:00:00            350085.0              339564.0
# 2        2022-10-01 00:00:00            350085.0              339564.0
# 3        2022-10-01 00:00:00            350085.0              339564.0
# 4        2022-10-01 00:00:00            350085.0              339564.0
# ...                      ...                 ...                   ...
# 3004418  2022-10-31 00:00:00            503773.0              503739.0
# 3004419  2022-10-31 00:00:00            503773.0              503739.0
# 3004420  2022-10-31 00:00:00            503773.0              503739.0
# 3004421  2022-10-31 00:00:00            503773.0              503739.0
# 3004422                  NaN                 NaN                   NaN
#
#          UsesStopPointId       Id  UsesDestinationDisplayId
# ...

# %%
# Filtrera på UsesPlannedBlockId
filter_line_calls_blockId = dataset_calls_clean['UsesPlannedBlockId'].values == 350085.0
df_filtered_line_calls_blockId = dataset_calls_clean.loc[filter_line_calls_blockId]
df_filtered_line_calls_blockId

# RESULTAT: 81 rader
# Out:
#         OperatingCalendarDay  UsesPlannedBlockId  UsesPlannedJourneyId  \
# 0        2022-10-01 00:00:00            350085.0              339564.0
# 1        2022-10-01 00:00:00            350085.0              339564.0
# 2        2022-10-01 00:00:00            350085.0              339564.0
# 3        2022-10-01 00:00:00            350085.0              339564.0
# 4        2022-10-01 00:00:00            350085.0              339564.0
# ...                      ...                 ...                   ...
# 2765891  2022-10-29 00:00:00            350085.0              339564.0
# 2765892  2022-10-29 00:00:00            350085.0              339564.0
# 2765893  2022-10-29 00:00:00            350085.0              339564.0
# 2765894  2022-10-29 00:00:00            350085.0              339564.0
# 2765895  2022-10-29 00:00:00            350085.0              339564.0
#
#          UsesStopPointId       Id  UsesDestinationDisplayId
# ...

# %%
# Få ut en lista på alla "UsesDestinationDisplayId"
line_list_destinationIds = df_filtered_line_calls_blockId.groupby('UsesDestinationDisplayId').mean()
line_list_destinationIds
# Out:
#                           UsesPlannedBlockId  UsesPlannedJourneyId  \
# UsesDestinationDisplayId
# 226.0                               350085.0              339564.0
# 233.0                               350085.0              339564.0
# 234.0                               350085.0              339564.0
# 235.0                               350085.0              339564.0
#
#                           UsesStopPointId            Id
# UsesDestinationDisplayId
# 226.0                         6697.111111  35887.888889
# 233.0                         6697.111111  67565.111111
# 234.0                         6697.111111  40739.259259
# 235.0                         6697.111111  45725.638889

# %%
# Få ut en lista på alla "UsesDestinationDisplayId"
line_list_destinationIds = dataset_calls_clean.groupby('UsesDestinationDisplayId').mean()
line_list_destinationIds
# Out:
#                           UsesPlannedBlockId  UsesPlannedJourneyId  \
# UsesDestinationDisplayId
# 1.0                            500727.338627         466557.382321
# 2.0                            499829.739467         486888.476133
# 3.0                            500334.856862         487360.967597
# 4.0                            499104.872973         497113.640360
# 5.0                            495486.888803         468788.107858
# ...                                      ...                   ...
# 275.0                          499386.739571         486798.932539
# 276.0                          497658.682068         475808.690447
# 277.0                          498355.872031         481669.519581
# 278.0                          497518.020968         477958.496989
# 279.0                          502964.000000         502700.000000
#
#                           UsesStopPointId            Id
# UsesDestinationDisplayId
# ...

# %%
# Få ut en lista på alla "UsesDestinationDisplayId"
line_list_destinationIds__ = dataset_calls_clean.groupby('UsesPlannedBlockId').mean()
line_list_destinationIds__
# Out:
#                     UsesPlannedJourneyId  UsesStopPointId            Id  \
# UsesPlannedBlockId
# 350023.0                   348316.000000      5759.333333  50271.777778
# 350028.0                   343803.000000      6137.636364  27959.000000
# 350085.0                   339564.000000      6697.111111  45397.037037
# 350105.0                   336227.000000      6137.636364  34584.436364
# 350154.0                   349324.000000      6697.111111  31656.066667
# ...                                  ...              ...           ...
# 503769.0                   503742.200000      3208.271429  58683.850000
# 503770.0                   503738.000000      7090.000000  48333.666667
# 503771.0                   502242.527132      4900.164341  55287.006202
# 503772.0                   503725.000000      7088.666667  47990.666667
# 503773.0                   502206.120795      4885.932722  55761.396024
#
#                     UsesDestinationDisplayId
# UsesPlannedBlockId
# ...

# %%
# Filtrera på UsesDestinationDisplayId
filter_line_calls_blockId_DestinationId = df_filtered_line_calls_blockId['UsesDestinationDisplayId'].values == 234
df_filtered_line_calls_blockId_DestinationId = df_filtered_line_calls_blockId.loc[filter_line_calls_blockId_DestinationId]
df_filtered_line_calls_blockId_DestinationId

# RESULTAT: 27 rader
# Out:
#         OperatingCalendarDay  UsesPlannedBlockId  UsesPlannedJourneyId  \
# 0        2022-10-01 00:00:00            350085.0              339564.0
# 1        2022-10-01 00:00:00            350085.0              339564.0
# 2        2022-10-01 00:00:00            350085.0              339564.0
# 3        2022-10-01 00:00:00            350085.0              339564.0
# 4        2022-10-01 00:00:00            350085.0              339564.0
# 5        2022-10-01 00:00:00            350085.0              339564.0
# 6        2022-10-01 00:00:00            350085.0              339564.0
# 7        2022-10-01 00:00:00            350085.0              339564.0
# 8        2022-10-01 00:00:00            350085.0              339564.0
# 575919   2022-10-07 00:00:00            350085.0              339564.0
# 575920   2022-10-07 00:00:00            350085.0              339564.0
# 575921   2022-10-07 00:00:00            350085.0              339564.0
# ...

# %%
# Filtrera en dag för att se en linje och dess hållplatser
filter_line_calls_blockId_DestinationId_day = df_filtered_line_calls_blockId_DestinationId['OperatingCalendarDay'].values == '2022-10-01 00:00:00'
df_filtered_line_calls_blockId_DestinationId_day = df_filtered_line_calls_blockId_DestinationId.loc[filter_line_calls_blockId_DestinationId_day]
df_filtered_line_calls_blockId_DestinationId_day
# Out:
#   OperatingCalendarDay  UsesPlannedBlockId  UsesPlannedJourneyId  \
# 0  2022-10-01 00:00:00            350085.0              339564.0
# 1  2022-10-01 00:00:00            350085.0              339564.0
# 2  2022-10-01 00:00:00            350085.0              339564.0
# 3  2022-10-01 00:00:00            350085.0              339564.0
# 4  2022-10-01 00:00:00            350085.0              339564.0
# 5  2022-10-01 00:00:00            350085.0              339564.0
# 6  2022-10-01 00:00:00            350085.0              339564.0
# 7  2022-10-01 00:00:00            350085.0              339564.0
# 8  2022-10-01 00:00:00            350085.0              339564.0
#
#    UsesStopPointId       Id  UsesDestinationDisplayId
# 0           6462.0  14828.0                     234.0
# 1           8456.0  32812.0                     234.0
# 2           6336.0  32252.0                     234.0
# 3           6080.0  59108.0                     234.0
# ...

# %%
dataset_plannedJourneys = pd.read_csv('../../indata/2022-10/2022-10-PlannedJourneys.csv', sep=';')
dataset_plannedJourneys.head()
# Out:
#   OperatingCalendarDay      Id        ExternalId  JourneyName  \
# 0  2022-10-01 00:00:00  331509  9015005063000604          604
# 1  2022-10-01 00:00:00  331943  9015005008108721         8721
# 2  2022-10-01 00:00:00  331969  9015005063000602          602
# 3  2022-10-01 00:00:00  332067  9015005008118856        18856
# 4  2022-10-01 00:00:00  332089  9015005008108751         8751
#
#       JourneyStartTime       JourneyEndTime  BelongsToCompanyId  \
# 0  2022-10-01 11:05:00  2022-10-01 11:45:00                9067
# 1  2022-10-01 09:18:00  2022-10-01 10:25:00                9014
# 2  2022-10-01 09:05:00  2022-10-01 09:45:00                9067
# 3  2022-10-01 17:55:00  2022-10-01 18:15:00                9014
# 4  2022-10-01 16:48:00  2022-10-01 17:55:00                9014
#
#    BelongsToLineId    DirectionCode  HasJourneyTypeId  \
# 0              183           Tranås                 1
# 1              166  Motala / Tranås                 1
# ...

# %%
# calls(UsesPlannedJourneyId) mappar med Id i plannedJourney
filter_line_test_jorneyName = dataset_plannedJourneys['Id'].values == 339564
df_filter_line_test_jorneyName = dataset_plannedJourneys.loc[filter_line_test_jorneyName]
df_filter_line_test_jorneyName.sort_values(by=['JourneyStartTime'])
df_filter_line_test_jorneyName
# Out:
#        OperatingCalendarDay      Id        ExternalId  JourneyName  \
# 55      2022-10-01 00:00:00  339564  9015005008108780         8780
# 26670   2022-10-07 00:00:00  339564  9015005008108780         8780
# 31985   2022-10-08 00:00:00  339564  9015005008108780         8780
# 58596   2022-10-14 00:00:00  339564  9015005008108780         8780
# 63911   2022-10-15 00:00:00  339564  9015005008108780         8780
# 90526   2022-10-21 00:00:00  339564  9015005008108780         8780
# 95841   2022-10-22 00:00:00  339564  9015005008108780         8780
# 122456  2022-10-28 00:00:00  339564  9015005008108780         8780
# 127769  2022-10-29 00:00:00  339564  9015005008108780         8780
#
#            JourneyStartTime       JourneyEndTime  BelongsToCompanyId  \
# 55      2022-10-02 00:05:00  2022-10-02 01:12:00                9014
# 26670   2022-10-08 00:05:00  2022-10-08 01:12:00                9014
# 31985   2022-10-09 00:05:00  2022-10-09 01:12:00                9014
# ...

# %%
# Test - finns detta JourneyName? 350085 (UsedPlannedBlockId från Calls)
filter_line_test_jorneyName = dataset_plannedJourneys['Id'].values == 350085
df_filter_line_test_jorneyName = dataset_plannedJourneys.loc[filter_line_test_jorneyName]
df_filter_line_test_jorneyName.sort_values(by=['JourneyStartTime'])
df_filter_line_test_jorneyName
# Out:
# Empty DataFrame
# Columns: [OperatingCalendarDay, Id, ExternalId, JourneyName, JourneyStartTime, JourneyEndTime, BelongsToCompanyId, BelongsToLineId, DirectionCode, HasJourneyTypeId, RouteIdentifier]
# Index: []

# %%
# Välj alla linjer som går mot Norrköping för att få en överblick av datamängden
filter_line_lineId = dataset_plannedJourneys['DirectionCode'].values == 'Norrköping'
df_filtered_line_lineId = dataset_plannedJourneys.loc[filter_line_lineId]
df_filtered_line_lineId.sort_values(by=['JourneyStartTime'])
df_filtered_line_lineId
# Out:
#        OperatingCalendarDay      Id        ExternalId  JourneyName  \
# 3       2022-10-01 00:00:00  332067  9015005008118856        18856
# 8       2022-10-01 00:00:00  333262  9015005008108734         8734
# 10      2022-10-01 00:00:00  333381  9015005008108772         8772
# 15      2022-10-01 00:00:00  333993  9015005008108760         8760
# 17      2022-10-01 00:00:00  334130  9015005008118864        18864
# ...                     ...     ...               ...          ...
# 138144  2022-10-31 00:00:00  501615  9015005044000040           40
# 138145  2022-10-31 00:00:00  501617  9015005044000048           48
# 138149  2022-10-31 00:00:00  501629  9015005044000002            2
# 138151  2022-10-31 00:00:00  501635  9015005044000022           22
# 138152  2022-10-31 00:00:00  501636  9015005044000016           16
#
#            JourneyStartTime       JourneyEndTime  BelongsToCompanyId  \
# 3       2022-10-01 17:55:00  2022-10-01 18:15:00                9014
# ...

# %%
# Få ut en lista på alla "BelongToLineId" i Norrköping
line_list = dataset_plannedJourneys.groupby('BelongsToLineId').mean()
line_list = line_list.drop(['Id', 'ExternalId', 'HasJourneyTypeId'], axis=1)
line_list
# Out:
#                  JourneyName  BelongsToCompanyId
# BelongsToLineId
# 1                   5.000000              9174.0
# 4                  11.333333              9201.0
# 12                191.341837              9173.0
# 14                 15.606557              9999.0
# 15                228.515078              9003.0
# ...                      ...                 ...
# 590               652.500000              9999.0
# 591               655.250000              9999.0
# 592               652.500000              9999.0
# 593               652.500000              9999.0
# 594               998.000000              9204.0
#
# [220 rows x 2 columns]

# %%
# Filtrerar ut en linje (både fram och tillbaka)
filter_line_TEST = dataset_plannedJourneys['BelongsToLineId'].values == 233
df_filtered_line_TEST = dataset_plannedJourneys.loc[filter_line_TEST]
df_filtered_line_TEST.sort_values(by=['JourneyStartTime'])
df_filtered_line_TEST
# Out:
#        OperatingCalendarDay      Id        ExternalId  JourneyName  \
# 6157    2022-10-03 00:00:00  438713  9015005066400001            1
# 6630    2022-10-03 00:00:00  475944  9015005066400003            3
# 6661    2022-10-03 00:00:00  475989  9015005066400002            2
# 11383   2022-10-04 00:00:00  438713  9015005066400001            1
# 11856   2022-10-04 00:00:00  475944  9015005066400003            3
# ...                     ...     ...               ...          ...
# 123345  2022-10-28 00:00:00  475944  9015005066400003            3
# 123376  2022-10-28 00:00:00  475989  9015005066400002            2
# 133874  2022-10-31 00:00:00  438713  9015005066400001            1
# 134332  2022-10-31 00:00:00  475944  9015005066400003            3
# 138287  2022-10-31 00:00:00  502034  9015005066400004            4
#
#            JourneyStartTime       JourneyEndTime  BelongsToCompanyId  \
# 6157    2022-10-03 07:10:00  2022-10-03 08:04:00                9174
# ...

# %%
# Filtrerar ut en linje (både fram och tillbaka)
filter_line = dataset_plannedJourneys['BelongsToLineId'].values == 166
df_filtered_line = dataset_plannedJourneys.loc[filter_line]
df_filtered_line.sort_values(by=['JourneyStartTime'])
df_filtered_line
# Out:
#        OperatingCalendarDay      Id        ExternalId  JourneyName  \
# 1       2022-10-01 00:00:00  331943  9015005008108721         8721
# 3       2022-10-01 00:00:00  332067  9015005008118856        18856
# 4       2022-10-01 00:00:00  332089  9015005008108751         8751
# 6       2022-10-01 00:00:00  332880  9015005008118807        18807
# 8       2022-10-01 00:00:00  333262  9015005008108734         8734
# ...                     ...     ...               ...          ...
# 136094  2022-10-31 00:00:00  478595  9015005008108837         8837
# 136130  2022-10-31 00:00:00  478643  9015005008108853         8853
# 136488  2022-10-31 00:00:00  479174  9015005008108850         8850
# 136624  2022-10-31 00:00:00  479371  9015005008108852         8852
# 136688  2022-10-31 00:00:00  479475  9015005008108846         8846
#
#            JourneyStartTime       JourneyEndTime  BelongsToCompanyId  \
# 1       2022-10-01 09:18:00  2022-10-01 10:25:00                9014
# ...

# %%
# Filtrera på Direction och titta bara på turerna som går till Norrköping
filter_line_direction = df_filtered_line['DirectionCode'].values == 'Norrköping'
df_filtered_line_direction = df_filtered_line.loc[filter_line_direction]
df_filtered_line_direction
# Out:
#        OperatingCalendarDay      Id        ExternalId  JourneyName  \
# 3       2022-10-01 00:00:00  332067  9015005008118856        18856
# 8       2022-10-01 00:00:00  333262  9015005008108734         8734
# 10      2022-10-01 00:00:00  333381  9015005008108772         8772
# 15      2022-10-01 00:00:00  333993  9015005008108760         8760
# 17      2022-10-01 00:00:00  334130  9015005008118864        18864
# ...                     ...     ...               ...          ...
# 134544  2022-10-31 00:00:00  476259  9015005008108844         8844
# 135936  2022-10-31 00:00:00  478359  9015005008108848         8848
# 136488  2022-10-31 00:00:00  479174  9015005008108850         8850
# 136624  2022-10-31 00:00:00  479371  9015005008108852         8852
# 136688  2022-10-31 00:00:00  479475  9015005008108846         8846
#
#            JourneyStartTime       JourneyEndTime  BelongsToCompanyId  \
# 3       2022-10-01 17:55:00  2022-10-01 18:15:00                9014
# ...

# %%
# Filtrera på Id
filter_line_id = dataset_plannedJourneys['ExternalId'].values == 9015005008118856
df_filtered_line_id = dataset_plannedJourneys.loc[filter_line_id]
df_filtered_line_id
# Out:
#        OperatingCalendarDay      Id        ExternalId  JourneyName  \
# 3       2022-10-01 00:00:00  332067  9015005008118856        18856
# 3003    2022-10-02 00:00:00  332067  9015005008118856        18856
# 5877    2022-10-03 00:00:00  349024  9015005008118856        18856
# 11104   2022-10-04 00:00:00  349024  9015005008118856        18856
# 16330   2022-10-05 00:00:00  349024  9015005008118856        18856
# 21558   2022-10-06 00:00:00  349024  9015005008118856        18856
# 26792   2022-10-07 00:00:00  349024  9015005008118856        18856
# 31933   2022-10-08 00:00:00  332067  9015005008118856        18856
# 34933   2022-10-09 00:00:00  332067  9015005008118856        18856
# 37807   2022-10-10 00:00:00  349024  9015005008118856        18856
# 43033   2022-10-11 00:00:00  349024  9015005008118856        18856
# 48258   2022-10-12 00:00:00  349024  9015005008118856        18856
# 53485   2022-10-13 00:00:00  349024  9015005008118856        18856
# ...

# %%
# Filtrera ut ett datum på månaden
filter_line_direction_day = df_filtered_line_direction['OperatingCalendarDay'].values == '2022-10-01 00:00:00'
df_filtered_line_direction_day = df_filtered_line_direction.loc[filter_line_direction_day].sort_values(by=['JourneyStartTime'])
df_filtered_line_direction_day
# Out:
#     OperatingCalendarDay      Id        ExternalId  JourneyName  \
# 48   2022-10-01 00:00:00  337724  9015005008118806        18806
# 105  2022-10-01 00:00:00  346991  9015005008108700         8700
# 90   2022-10-01 00:00:00  344714  9015005008108712         8712
# 199  2022-10-01 00:00:00  409922  9015005008118816        18816
# 56   2022-10-01 00:00:00  339756  9015005008108716         8716
# 115  2022-10-01 00:00:00  348756  9015005008108720         8720
# 121  2022-10-01 00:00:00  349605  9015005008108722         8722
# 101  2022-10-01 00:00:00  346305  9015005008118824        18824
# 118  2022-10-01 00:00:00  349149  9015005008108724         8724
# 20   2022-10-01 00:00:00  334437  9015005008108726         8726
# 57   2022-10-01 00:00:00  339861  9015005008108728         8728
# 53   2022-10-01 00:00:00  338702  9015005008108730         8730
# 195  2022-10-01 00:00:00  408574  9015005008118832        18832
# 60   2022-10-01 00:00:00  339998  9015005008108732         8732
# ...

# %%
# Nu har vi data för en dag som visar en TUR för denna buss.
# LINJEN är inkluderat båda riktningar. Nu har vi bara en riktning och räknar det som en TUR
# Vi har X antal stopp (hållplatser) på turen/linjen
# Är det dessa stopp som identifieras med HappensAtCallId?

# %%
dataset_passengerCount = pd.read_csv('../../indata/2022-10/2022-10-PassengerCount.csv', sep=';')
dataset_passengerCount.head()
# Out:
#   OperatingCalendarDay        Id  HappensAtCallId  PassengersOnboard  totalIn  \
# 0  2022-10-01 00:00:00  99265544             2050                  6        1
# 1  2022-10-01 00:00:00  99265545            17729                  1        1
# 2  2022-10-01 00:00:00  99265546            26596                  3        3
# 3  2022-10-01 00:00:00  99265547             1657                  1        1
# 4  2022-10-01 00:00:00  99265548            52836                  0        0
#
#    totalOut            TimeStamp  PassengersFromLastJourney  IsValid
# 0         0  2022-10-01 16:18:41                        NaN        1
# 1         0  2022-10-01 19:10:38                        NaN        1
# 2         0  2022-10-01 14:42:14                        NaN        1
# 3         0  2022-10-01 16:11:46                        NaN        1
# 4         0  2022-10-01 22:10:48                        NaN        1

# %%
dataset_passengerCount = dataset_passengerCount.sort_values(by=['TimeStamp'])
dataset_passengerCount
# Out:
#         OperatingCalendarDay         Id  HappensAtCallId  PassengersOnboard  \
# 8580     2022-10-01 00:00:00   99274124            38093                  0
# 29728    2022-10-01 00:00:00   99295272            52601                  0
# 19603    2022-10-01 00:00:00   99285147            39156                  0
# 19283    2022-10-01 00:00:00   99284827            49538                 -1
# 2403     2022-10-01 00:00:00   99267947            24009                  2
# ...                      ...        ...              ...                ...
# 1371417  2022-10-31 00:00:00  103229216            89892                  1
# 1393018  2022-10-31 00:00:00  103250817            54648                  2
# 1358068  2022-10-31 00:00:00  103215867            58252                  1
# 1384375  2022-10-31 00:00:00  103242174           112034                  0
# 1346030  2022-10-31 00:00:00  103203829            55754                  0
#
# ...

# %%
# Följande parametrar ansers kunna vara "identifiers":
# Id ELLER HappensAtCallId
# Kan vi via dessa parametrar koppla hållplatser till tur/linje?

# %%
# Filtrera på Id
filter_line_id = dataset_passengerCount['HappensAtCallId'].values == 6462
df_filtered_line_id = dataset_passengerCount.loc[filter_line_id]
df_filtered_line_id
# Out:
#         OperatingCalendarDay         Id  HappensAtCallId  PassengersOnboard  \
# 196654   2022-10-05 00:00:00   99698401             6462                 40
# 252987   2022-10-06 00:00:00   99861285             6462                 11
# 345874   2022-10-08 00:00:00  100092316             6462                 23
# 404135   2022-10-10 00:00:00  100332734             6462                  1
# 550932   2022-10-13 00:00:00  100801661             6462                  0
# 640648   2022-10-14 00:00:00  100976491             6462                 22
# 704843   2022-10-17 00:00:00  101274145             6462                 13
# 792814   2022-10-18 00:00:00  101468111             6462                  1
# 825635   2022-10-19 00:00:00  101608532             6462                  1
# 914610   2022-10-21 00:00:00  101890916             6462                  6
# 1022289  2022-10-24 00:00:00  102234074             6462                  5
# ...

# %%
# Raden ovan visar att Id:t är unikt och endast representerar en rad i datamängden.

# %%
# Filtrera på HappensAtCallId
filter_line_callId = dataset_passengerCount['HappensAtCallId'].values == 6462
df_filtered_line_callId = dataset_passengerCount.loc[filter_line_callId]
df_filtered_line_callId
# Out:
#         OperatingCalendarDay         Id  HappensAtCallId  PassengersOnboard  \
# 196654   2022-10-05 00:00:00   99698401             6462                 40
# 252987   2022-10-06 00:00:00   99861285             6462                 11
# 345874   2022-10-08 00:00:00  100092316             6462                 23
# 404135   2022-10-10 00:00:00  100332734             6462                  1
# 550932   2022-10-13 00:00:00  100801661             6462                  0
# 640648   2022-10-14 00:00:00  100976491             6462                 22
# 704843   2022-10-17 00:00:00  101274145             6462                 13
# 792814   2022-10-18 00:00:00  101468111             6462                  1
# 825635   2022-10-19 00:00:00  101608532             6462                  1
# 914610   2022-10-21 00:00:00  101890916             6462                  6
# 1022289  2022-10-24 00:00:00  102234074             6462                  5
# ...

# %%
# Filtrera på HappensAtCallId
filter_line_callId_1 = dataset_passengerCount['HappensAtCallId'].values == 52601
df_filtered_line_callId_1 = dataset_passengerCount.loc[filter_line_callId_1]
df_filtered_line_callId_1
# Out:
#         OperatingCalendarDay         Id  HappensAtCallId  PassengersOnboard  \
# 29728    2022-10-01 00:00:00   99295272            52601                  0
# 46730    2022-10-02 00:00:00   99388709            52601                  5
# 91980    2022-10-03 00:00:00   99433959            52601                  5
# 136408   2022-10-04 00:00:00   99531955            52601                  5
# 180002   2022-10-05 00:00:00   99681749            52601                  6
# 223986   2022-10-06 00:00:00   99832284            52601                 39
# 308110   2022-10-07 00:00:00  100000573            52601                  7
# 387889   2022-10-10 00:00:00  100316488            52601                 12
# 442322   2022-10-11 00:00:00  100477269            52601                 37
# 576667   2022-10-13 00:00:00  100827396            52601                  0
# 630899   2022-10-14 00:00:00  100966742            52601                  0
# ...

# %%
# Parametrar att analysera är:
# UsesPlannedBlockId
# UsesPlannedJourneyId
# UsesStopPointId
# Id

# %%
test = pd.read_csv('../../indata/2022-10/2022-10-DestinationDisplay.csv', sep=';')
test
# Out:
#      OperatingCalendarDay   id  Destination1Id  Destination2Id  Via1Id  Via2Id
# 0     2022-10-01 00:00:00    1            5012             NaN  6004.0     NaN
# 1     2022-10-01 00:00:00    2            4026             NaN     NaN     NaN
# 2     2022-10-01 00:00:00    3            4037             NaN  4036.0     NaN
# 3     2022-10-01 00:00:00    4            3039             NaN     NaN     NaN
# 4     2022-10-01 00:00:00    5            5014             NaN     NaN     NaN
# ...                   ...  ...             ...             ...     ...     ...
# 8595  2022-10-31 00:00:00  274            5013             NaN  6045.0     NaN
# 8596  2022-10-31 00:00:00  275             102             NaN     NaN     NaN
# 8597  2022-10-31 00:00:00  276            5014             NaN  5012.0     NaN
# 8598  2022-10-31 00:00:00  277            6076             NaN   107.0     NaN
# 8599  2022-10-31 00:00:00  278            6088             NaN     NaN     NaN
#
# [8600 rows x 6 columns]

# %%
test_filter = test['id'].values == 234
df_test_filtered = test.loc[test_filter]
df_test_filtered
# Out:
#      OperatingCalendarDay   id  Destination1Id  Destination2Id  Via1Id  Via2Id
# 233   2022-10-01 00:00:00  234            4100             NaN  3009.0     NaN
# 510   2022-10-02 00:00:00  234            4100             NaN  3009.0     NaN
# 787   2022-10-03 00:00:00  234            4100             NaN  3009.0     NaN
# 1064  2022-10-04 00:00:00  234            4100             NaN  3009.0     NaN
# 1341  2022-10-05 00:00:00  234            4100             NaN  3009.0     NaN
# 1618  2022-10-06 00:00:00  234            4100             NaN  3009.0     NaN
# 1895  2022-10-07 00:00:00  234            4100             NaN  3009.0     NaN
# 2172  2022-10-08 00:00:00  234            5081             NaN     NaN     NaN
# 2449  2022-10-09 00:00:00  234             762             NaN     NaN     NaN
# 2726  2022-10-10 00:00:00  234            6032             NaN  5013.0     NaN
# 3003  2022-10-11 00:00:00  234            4100             NaN  3009.0     NaN
# ...

# %%
# BelongsToCompanyId 9205
# Filtrera på CompanyId
filter_line_companyId = dataset_vehicle['ExternalId'].values == 9015005022600607
df_filtered_line_companyId = dataset_vehicle.loc[filter_line_companyId]
df_filtered_line_companyId
# Out:
# Empty DataFrame
# Columns: [VehicleIdentity, CompanyId, DisplayName, ExternalId, RegNo, NodeName, ModifiedTimeUtc, Vin]
# Index: []

# %%
def plot_passengersOnboard(dataset):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(dataset['PassengersOnboard'].values)
    ax.grid(True)

    plt.title('Passengers Onboard 2022-10-01')
    #plt.xlabel(dataset['Id'].values)
    plt.ylabel('Antal Passagerare')

plot_passengersOnboard(df_filtered_line_day)

# %%
print(dataset['PassengersOnboardBalanced'].max())
# Out:
# 179.0

# %%
supervied_indata = dataset.drop(columns=['TimeStamp'])
supervied_indata
# Out:
#          PassengersOnboardBalanced
# 0                              0.0
# 1                              2.0
# 2                              3.0
# 3                              5.0
# 4                              9.0
# ...                            ...
# 1393091                        4.0
# 1393092                        3.0
# 1393093                        1.0
# 1393094                        0.0
# 1393095                        NaN
#
# [1393096 rows x 1 columns]

# %%
# Convert series to supervised learning - input predicting pollution outputs
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
supervised_data = series_to_supervised(supervied_indata.values, 1, 1)
supervised_data
# Out:
#          var1(t-1)  var1(t)
# 1              0.0      2.0
# 2              2.0      3.0
# 3              3.0      5.0
# 4              5.0      9.0
# 5              9.0      8.0
# ...            ...      ...
# 1393090       11.0      9.0
# 1393091        9.0      4.0
# 1393092        4.0      3.0
# 1393093        3.0      1.0
# 1393094        1.0      0.0
#
# [1393094 rows x 2 columns]

# %%
supervised_values = supervised_data.values
supervised_values
# Out:
# array([[0., 2.],
#        [2., 3.],
#        [3., 5.],
#        ...,
#        [4., 3.],
#        [3., 1.],
#        [1., 0.]])

# %%
# Training 80% --> 0 to 1 114 475
# Testing 20% --> 1 114 476 to 1 393 094
n_train_time = round(len(supervised_values) * 0.8)
n_train_time
# Out:
# 1114475

# %%
# Trainingset --> 20210101 to 20220206
train = supervised_values[:n_train_time, :]
len(train)
# Out:
# 1114475

# %%
# Testing 20% --> 1 114 476 to 1 393 094
n_test_stop = len(supervised_values)
test = supervised_values[n_train_time:n_test_stop, :]
len(test)
# Out:
# 278619

# %%
# Split into input and outputs --> all values exept the last column is X, the last column is y
train_X, train_y = train[:, :-1], train[:, -1]
len(train_y)
# Out:
# 1114475

# %%
# This is where it becomes different when we dont have any data to validate our result wiht
# Then we only have text_X
test_X, test_y = test[:, :-1], test[:, -1]
len(test_X)
# Out:
# 278619

# %%
# Reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (1114475, 1, 1) (1114475,) (278619, 1, 1) (278619,)

# %%
# Neural network
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

#model = Sequential()
#model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dense(1))
#model.compile(loss='mae', optimizer='adam')

neurons = 50
# Initializing the RNN 
# The output is continous value --> use regression
regressor = Sequential()

# Add the first layer to the neural network
regressor.add(LSTM(units = neurons, return_sequences = True, input_shape=(train_X.shape[1], train_X.shape[2])))

# Dropout regulation (use to be 20%)
# --> this is the number of neurons to be ignored
regressor.add(Dropout(0.2))

# Add more layers to the neural network
# Second layer
regressor.add(LSTM(units = neurons, return_sequences = True))
regressor.add(Dropout(0.2))

# Third layer
regressor.add(LSTM(units = neurons, return_sequences = True))
regressor.add(Dropout(0.2))

# Forth layer - last layer before output  layer
regressor.add(LSTM(units = neurons))
regressor.add(Dropout(0.2))

# Output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
# NOTE: Optimizer - RMSprops is recommended for RNN but Adam was detected to 
# be a better choice for this problem
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Training the network
history = regressor.fit(train_X, train_y, epochs=15, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/15
# 34828/34828 - 213s - loss: 28.1994 - val_loss: 25.9845 - 213s/epoch - 6ms/step
# Epoch 2/15
# 34828/34828 - 210s - loss: 25.8449 - val_loss: 25.3359 - 210s/epoch - 6ms/step
# Epoch 3/15
# 34828/34828 - 204s - loss: 25.4766 - val_loss: 24.8026 - 204s/epoch - 6ms/step
# Epoch 4/15
# 34828/34828 - 210s - loss: 25.3227 - val_loss: 25.1065 - 210s/epoch - 6ms/step
# Epoch 5/15
# 34828/34828 - 204s - loss: 25.2440 - val_loss: 24.6729 - 204s/epoch - 6ms/step
# Epoch 6/15
# 34828/34828 - 199s - loss: 24.9962 - val_loss: 25.3176 - 199s/epoch - 6ms/step
# Epoch 7/15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_12432/208403463.py in <module>
#       1 # Training the network
# ----> 2 history = regressor.fit(train_X, train_y, epochs=15, batch_size=32, validation_data=(test_X, test_y), verbose=2, shuffle=False)
#
# ...

# %%
# Plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
y_prediction = regressor.predict(test_X)
y_prediction
# Out:
# array([[8.608523 ],
#        [7.720794 ],
#        [5.8243933],
#        ...,
#        [4.1223116],
#        [3.3857841],
#        [2.208726 ]], dtype=float32)

# %%
def plot_result_prediction(y_prediction):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(y_prediction)
    ax.grid(True)

    plt.title('Prediktion Antal Passagerare 2022-10-01')
    plt.xlabel('Time')
    plt.ylabel('Antal passagerare')

plot_result_prediction(y_prediction)

# %%
len(y_prediction)
# Out:
# 278619

# %%
# Pick out day 7 - 13 of februari as test values
day_2022_02_07 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-07"]
day_2022_02_08 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-08"]
day_2022_02_09 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-09"]
day_2022_02_10 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-10"]
day_2022_02_11 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-11"]
day_2022_02_12 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-12"]
day_2022_02_13 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-13"]
frames = [day_2022_02_07, 
          day_2022_02_08,
          day_2022_02_09,
          day_2022_02_10,
          day_2022_02_11,
          day_2022_02_12,
          day_2022_02_13]
validation_x = pd.concat(frames)
validation_x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\USER88~1\AppData\Local\Temp/ipykernel_12432/485445858.py in <module>
#       1 # Pick out day 7 - 13 of februari as test values
# ----> 2 day_2022_02_07 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-07"]
#       3 day_2022_02_08 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-08"]
#       4 day_2022_02_09 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-09"]
#       5 day_2022_02_10 = datafram_indata[datafram_indata['Datum Ford'] == "2022-02-10"]
#
# NameError: name 'datafram_indata' is not defined

# %%
date_time = pd.to_datetime(validation_x['Datum Ford'] + ' ' + validation_x['Tid Ford'])
date_time
# Out:
# 272736   2022-02-07 05:00:00
# 272737   2022-02-07 05:05:00
# 272738   2022-02-07 05:10:00
# 272739   2022-02-07 05:15:00
# 272740   2022-02-07 05:20:00
#                  ...
# 274747   2022-02-13 04:35:00
# 274748   2022-02-13 04:40:00
# 274749   2022-02-13 04:45:00
# 274750   2022-02-13 04:50:00
# 274751   2022-02-13 04:55:00
# Length: 2016, dtype: datetime64[ns]

# %%
 # Prepare data for the plots
# We want to show predicted stops as 1 and actual stops as -1
# We want all other valus to be nan --> not shown in the plot
# This is because we are only interested in stops - not movment
y_pred_booking = []
for i in range(0, len(y_prediction)):
    if y_prediction[i] > 0.1:
        y_pred_booking.append(-1)
    else:
        y_pred_booking.append(0)

y = validation_x['AntalBokadeFramkörning'].values
y_validation_booking = []
for i in range(0, len(y)):
    if y[i] == 0:
        y_validation_booking.append(0)
    else:
        y_validation_booking.append(1)
        
start = 1560
stop = 2016
        
# Visualising the results      
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
fig.autofmt_xdate(rotation=45)
ax.plot(date_time[start:stop], y_validation_booking[start:])
ax.plot(date_time[start:stop], y_pred_booking[start:stop])
xftm = mdates.DateFormatter('%y-%m-%d %H:%M')
ax.xaxis.set_major_formatter(xftm)

ax.grid(True)

plt.title('Prediktion Antal Bokningar och Framkörningar')
plt.xlabel('Time')
plt.ylabel('Antal Bokningar/Framkörningar')
plt.legend(['Faktiskt bokning/framkörning', 'Predikterad bokning/framkörning'])
